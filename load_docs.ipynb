# %%
import requests
from bs4 import BeautifulSoup
import pickle
import os


def fetch_or_load_content(url, pickle_filename="response.pkl"):
    """
    Fetches content from the URL if the pickle file does not exist. 
    Otherwise, loads content from the pickle file.
    
    Args:
        url (str): The URL to fetch content from.
        pickle_filename (str): The filename of the pickle file to save/load the content.
    
    Returns:
        BeautifulSoup: Parsed HTML content as a BeautifulSoup object.
        str: Page title.
    """
    # Check if the pickle file exists
    if os.path.exists(pickle_filename):
        # Load the saved HTML content from the pickle file
        with open(pickle_filename, "rb") as file:
            response_text = pickle.load(file)
        print("Loaded content from pickle.")
    else:
        # Make the HTTP request
        response = requests.get(url)
        response_text = response.text

        # Save the response to the pickle file
        with open(pickle_filename, "wb") as file:
            pickle.dump(response_text, file)
        print("Fetched content from the web and saved to pickle.")

    # Parse HTML content
    soup = BeautifulSoup(response_text, "html.parser")
    title = soup.title.string if soup.title else "Documentation"
    
    return soup, title

# %%
def html_to_markdown(element):
    # Replace certain tags with markdown equivalents
    text = element.get_text(separator="\n")
    text = re.sub(r'\n+', '\n', text) 
    return f"# {title}\n\n{text}"

# %%
import os

def load_page_generator(docs_uris):
    for uri in docs_uris:
        url = host + uri

        file_path = f"docs/{uri.split('.')[0]}.json"

        if os.path.exists(file_path):
            print(f"{uri} exists.")
            continue

        print(url)

        soup, title = fetch_or_load_content(url, f"req/{uri}.pkl")
        
        # Extract relevant parts by targeting main body
        main_content = soup.find("div", {"id": "content"})        
        
        soup = BeautifulSoup(response.text, "html.parser")
        plain_text = soup.get_text(separator="\n")

        main_content = soup.find(id="content")
        main_content
    
        yield plain_text

    # Save to file
    # with open(f"{uri}.txt", "w") as f:
    #     f.write(plain_text)

# %%
def generate_tags(text):
    raise Exception("")

def generate_target_outcomes(text):
    raise Exception("")

def generate_summary(text):
    raise Exception("")

def generate_questions_this_answers(text):
    raise Exception("")

# %%
from datetime import datetime
import json
import re


def extract_text_between_markers(text):
    match = re.search(r'\[\[(.*?)\]\]', text)
    return match.group(1) if match else "_"

def extract_role(text):
    return re.findall(r'\[role="([^"]+)"\]', text)

def includes_code(text):
    return "--------------------------------------------------" in text


elastic_host = "https://www.elastic.co/guide/en/elasticsearch/reference/current/"

def transform_documentation_page_to_doc(source):
    doc_title = extract_text_between_markers(source),
    
    doc = {
        "meta": {
            "timestamp": datetime.utcnow().isoformat(),
            "size": len(source),
            
            "url": elastic_host + doc_title[0] + ".html",
            # "hash": hash_text(source),
            "type": "documentation",
            "role": extract_role(source),
            "has_code": includes_code(source),
            "title": doc_title[0],
            "version": "8.15",

            # "tag": generate_tags(source),
            # "outcomes": generate_target_outcomes(source),
            # "summary": generate_summary(source),
            # "questions": generate_questions_this_answers(source)
        },
        "doc": source,
    }
    
    return json.dumps(doc, indent=4)


def define_documentation_doc_title(content):
    return extract_text_between_markers(content)

# %%
import json
from datetime import datetime
import os


api_specification_details = """

The specification contains:

* The _name_ of the API (`indices.create`), which usually corresponds to the client calls
* Link to the documentation at the <http://elastic.co> website.

  **IMPORANT:** This should be a _live_ link. Several downstream ES clients use
  this link to generate their documentation. Using a broken link or linking to
  yet-to-be-created doc pages can break the [Elastic docs
  build](https://github.com/elastic/docs#building-documentation).
* `stability` indicating the state of the API, has to be declared explicitly or YAML tests will fail
    * `experimental` highly likely to break in the near future (minor/patch), no bwc guarantees.
    Possibly removed in the future.
    * `beta` less likely to break or be removed but still reserve the right to do so
    * `stable` No backwards breaking changes in a minor
* Request URL: HTTP method, path and parts
* Request parameters
* Request body specification

**NOTE**
If an API is stable but it response should be treated as an arbitrary map of key values please notate this as followed

```json
{
  "api.name": {
    "stability" : "stable",
    "response": {
      "treat_json_as_key_value" : true
    }
  }
}
```

## Type definition
In the documentation, you will find the `type` field, which documents which type every parameter will accept.

#### Querystring parameters
| Type  | Description  |
|---|---|
| `list`  | An array of strings *(represented as a comma separated list in the querystring)* |
| `date` | A string representing a date formatted in ISO8601 or a number representing milliseconds since the epoch *(used only in ML)*   |
| `time` | A numeric or string value representing duration |
| `string` | A string value  |
| `enum` | A set of named constants *(a single value should be sent in the querystring)*  |
| `int` | A signed 32-bit integer with a minimum value of -2<sup>31</sup> and a maximum value of 2<sup>31</sup>-1.  |
| `double` | A [double-precision 64-bit IEEE 754](https://en.wikipedia.org/wiki/Floating-point_arithmetic) floating point number, restricted to finite values.  |
| `long` | A signed 64-bit integer with a minimum value of -2<sup>63</sup> and a maximum value of 2<sup>63</sup>-1. *(Note: the max safe integer for JSON is 2<sup>53</sup>-1)* |
| `number` | Alias for `double`. *(deprecated, a more specific type should be used)*  |
| `boolean` | Boolean fields accept JSON true and false values  |

{
  "documentation" : {
    "description": "Parameters that are accepted by all API endpoints.",
    "url": "https://www.elastic.co/guide/en/elasticsearch/reference/current/common-options.html"
  },
  "params": {
    "pretty": {
      "type": "boolean",
      "description": "Pretty format the returned JSON response.",
      "default": false
    },
    "human": {
      "type": "boolean",
      "description": "Return human readable values for statistics.",
      "default": true
    },
    "error_trace": {
      "type": "boolean",
      "description": "Include the stack trace of returned errors.",
      "default": false
    },
    "source": {
      "type": "string",
      "description": "The URL-encoded request definition. Useful for libraries that do not accept a request body for non-POST requests."
    },
    "filter_path": {
      "type": "list",
      "description": "A comma-separated list of filters used to reduce the response."
    }
  }
}



"""





def transform_api_spec_to_doc(api_spec, elastic_host="https://www.elastic.co"):
    """Extracts relevant info from an API specification JSON file."""

    spec_as_json = json.loads(api_spec)
    
    api_name = list(spec_as_json.keys())[0]
    source = spec_as_json[api_name]
    
    # Extracting main details
    doc_title = source.get("documentation", {}).get("description", "")
    doc_url = source.get("documentation", {}).get("url", "")
    stability = source.get("stability", "")
    response_key_value = source.get("response", {}).get("treat_json_as_key_value", False)
    visibility = source.get("visibility", "public")
    url_paths = source.get("url", {}).get("paths", [])
    params = source.get("params", {})

    
    # Organizing parameters with their type descriptions
    param_types = {param: params[param].get("type", "unknown") for param in params}
    
    # Structuring the output document
    doc = {
        "meta": {
            "timestamp": datetime.utcnow().isoformat(),
            "api_name": api_name,
            "stability": stability,
            "visibility": visibility,
            "main_component": api_name if len(api_name.split(".")) == 1 else api_name.split(".")[0],
            "url": doc_url,
            "elastic_url": f"{elastic_host}/{api_name.replace('.', '/')}.html",
            "treat_json_as_key_value": response_key_value,
            "title": doc_title,
            "paths": url_paths,
            "parameter_types": param_types,
            "doc_version": "8.15",
        },
        "doc": source,
    }
    
    return json.dumps(doc, indent=4)


def define_api_spec_doc_title(content):
    spec_as_json = json.loads(content)
    return list(spec_as_json.keys())[0]

# %%
import os



def read_file_with_fallback(file_path):
    try:
        # Attempt reading with UTF-8 encoding
        with open(file_path, 'r', encoding='utf-8') as f:
            return f.read()
    except UnicodeDecodeError:
        # Fallback to reading as binary and decoding manually
        with open(file_path, 'rb') as f:
            return f.read().decode('utf-8', errors='replace')  # Replace un-decodable chars

def create_doc_from_file(filepath, transform, create_doc_filemame):
    content = read_file_with_fallback(filepath)
    processed_content = transform(content)
    doc_filename = create_doc_filemame(content)

    output_path = f"docs/{doc_filename}.json"
    with open(output_path, 'w') as output_file:
        output_file.write(processed_content)

def process_files(folder_path, transform, create_doc_filemame):
    for root, _, files in os.walk(folder_path):
        for each in files:
            file_path = os.path.join(root, each)
            create_doc_from_file(file_path, transform, create_doc_filemame)


documentation_folder_path = "data/documentation"
process_files(
    documentation_folder_path, 
    transform_documentation_page_to_doc,
    define_documentation_doc_title,
)

rest_api_doc_folder_path = "data/documentation/rest-api"
process_files(
    rest_api_doc_folder_path,
    transform_api_spec_to_doc,
    define_api_spec_doc_title,
)

# %%
import requests
from bs4 import BeautifulSoup
import pickle
import os


host = "https://www.elastic.co/guide/en/elasticsearch/reference/current/"


docs_uris = [each[1] for each in toc_links]


for plain_text, uri in zip(load_page_generator(docs_uris), docs_uris):
    file_path = f"docs/{uri.split('.')[0]}.json"
    
    content = parse_content_to_docs(plain_text, f"{host}/{uri}")

    with open(file_path, "w") as file:
        file.write(content)
    # break
# Out:
# elasticsearch-intro.html exists.
# elasticsearch-intro-what-is-es.html exists.
# elasticsearch-intro-deploy.html exists.
# documents-indices.html exists.
# es-ingestion-overview.html exists.
# search-analyze.html exists.
# scalability.html exists.
# quickstart.html exists.
# getting-started.html exists.
# full-text-filter-tutorial.html exists.
# setup.html exists.
# run-elasticsearch-locally.html exists.
# install-elasticsearch.html exists.
# targz.html exists.
# zip-windows.html exists.
# deb.html exists.
# rpm.html exists.
# docker.html exists.
# settings.html exists.
# important-settings.html exists.
# secure-settings.html exists.
# auditing-settings.html exists.
# circuit-breaker.html exists.
# modules-cluster.html exists.
# misc-cluster-settings.html exists.
# ccr-settings.html exists.
# modules-discovery-settings.html exists.
# modules-fielddata.html exists.
# health-diagnostic-settings.html exists.
# ilm-settings.html exists.
# data-stream-lifecycle-settings.html exists.
# index-management-settings.html exists.
# recovery.html exists.
# indexing-buffer.html exists.
# license-settings.html exists.
# modules-gateway.html exists.
# logging.html exists.
# ml-settings.html exists.
# inference-settings.html exists.
# monitoring-settings.html exists.
# modules-node.html exists.
# modules-network.html exists.
# query-cache.html exists.
# search-settings.html exists.
# security-settings.html exists.
# shard-allocation-relocation-recovery.html exists.
# shard-request-cache.html exists.
# snapshot-settings.html exists.
# transform-settings.html exists.
# modules-threadpool.html exists.
# notification-settings.html exists.
# advanced-configuration.html exists.
# system-config.html exists.
# setting-system-settings.html exists.
# setup-configuration-memory.html exists.
# file-descriptors.html exists.
# vm-max-map-count.html exists.
# max-number-of-threads.html exists.
# networkaddress-cache-ttl.html exists.
# executable-jna-tmpdir.html exists.
# system-config-tcpretries.html exists.
# bootstrap-checks.html exists.
# _heap_size_check.html exists.
# _file_descriptor_check.html exists.
# _memory_lock_check.html exists.
# max-number-threads-check.html exists.
# _max_file_size_check.html exists.
# max-size-virtual-memory-check.html exists.
# _maximum_map_count_check.html exists.
# _client_jvm_check.html exists.
# _use_serial_collector_check.html exists.
# _system_call_filter_check.html exists.
# _onerror_and_onoutofmemoryerror_checks.html exists.
# _early_access_check.html exists.
# _all_permission_check.html exists.
# _discovery_configuration_check.html exists.
# bootstrap-checks-xpack.html exists.
# starting-elasticsearch.html exists.
# stopping-elasticsearch.html exists.
# modules-discovery.html exists.
# discovery-hosts-providers.html exists.
# modules-discovery-quorums.html exists.
# modules-discovery-voting.html exists.
# modules-discovery-bootstrap-cluster.html exists.
# cluster-state-publishing.html exists.
# cluster-fault-detection.html exists.
# add-elasticsearch-nodes.html exists.
# restart-cluster.html exists.
# remote-clusters.html exists.
# remote-clusters-api-key.html exists.
# remote-clusters-cert.html exists.
# remote-clusters-migrate.html exists.
# remote-clusters-settings.html exists.
# remote-clusters-troubleshooting.html exists.
# modules-plugins.html exists.
# search-with-elasticsearch.html exists.
# search-your-data.html exists.
# sort-search-results.html exists.
# paginate-search-results.html exists.
# search-fields.html exists.
# search-multiple-indices.html exists.
# collapse-search-results.html exists.
# filter-search-results.html exists.
# highlighting.html exists.
# async-search-intro.html exists.
# near-real-time.html exists.
# inner-hits.html exists.
# search-shard-routing.html exists.
# search-using-query-rules.html exists.
# search-template.html exists.
# retrievers-overview.html exists.
# knn-search.html exists.
# semantic-search.html exists.
# semantic-search-semantic-text.html exists.
# semantic-text-hybrid-search.html exists.
# semantic-search-inference.html exists.
# semantic-search-elser.html exists.
# cohere-es.html exists.
# semantic-search-deployed-nlp-model.html exists.
# bring-your-own-vectors.html exists.
# modules-cross-cluster-search.html exists.
# search-with-synonyms.html exists.
# search-application-overview.html exists.
# search-application-api.html exists.
# search-application-security.html exists.
# search-application-client.html exists.
# behavioral-analytics-overview.html exists.
# behavioral-analytics-start.html exists.
# behavioral-analytics-cors.html exists.
# behavioral-analytics-event.html exists.
# behavioral-analytics-event-reference.html exists.
# behavioral-analytics-api.html exists.
# re-ranking-overview.html exists.
# semantic-reranking.html exists.
# learning-to-rank.html exists.
# learning-to-rank-model-training.html exists.
# learning-to-rank-search-usage.html exists.
# index-modules.html exists.
# index-modules-analysis.html exists.
# index-modules-allocation.html exists.
# shard-allocation-filtering.html exists.
# delayed-allocation.html exists.
# recovery-prioritization.html exists.
# allocation-total-shards.html exists.
# data-tier-shard-filtering.html exists.
# index-modules-blocks.html exists.
# index-modules-mapper.html exists.
# index-modules-merge.html exists.
# index-modules-similarity.html exists.
# index-modules-slowlog.html exists.
# index-modules-store.html exists.
# preload-data-to-file-system-cache.html exists.
# index-modules-translog.html exists.
# index-modules-history-retention.html exists.
# index-modules-index-sorting.html exists.
# index-modules-index-sorting-conjunctions.html exists.
# index-modules-indexing-pressure.html exists.
# index-templates.html exists.
# simulate-multi-component-templates.html exists.
# ignore_missing_component_templates.html exists.
# _usage_example.html exists.
# aliases.html exists.
# mapping.html exists.
# dynamic-mapping.html exists.
# dynamic-field-mapping.html exists.
# dynamic-templates.html exists.
# explicit-mapping.html exists.
# runtime.html exists.
# runtime-mapping-fields.html exists.
# runtime-search-request.html exists.
# runtime-override-values.html exists.
# runtime-retrieving-fields.html exists.
# runtime-indexed.html exists.
# runtime-examples.html exists.
# mapping-types.html exists.
# aggregate-metric-double.html exists.
# field-alias.html exists.
# array.html exists.
# binary.html exists.
# boolean.html exists.
# completion.html exists.
# date.html exists.
# date_nanos.html exists.
# dense-vector.html exists.
# flattened.html exists.
# geo-point.html exists.
# geo-shape.html exists.
# histogram.html exists.
# ip.html exists.
# parent-join.html exists.
# keyword.html exists.
# nested.html exists.
# number.html exists.
# object.html exists.
# percolator.html exists.
# point.html exists.
# range.html exists.
# rank-feature.html exists.
# rank-features.html exists.
# search-as-you-type.html exists.
# semantic-text.html exists.
# shape.html exists.
# sparse-vector.html exists.
# text.html exists.
# token-count.html exists.
# unsigned-long.html exists.
# version.html exists.
# mapping-fields.html exists.
# mapping-doc-count-field.html exists.
# mapping-field-names-field.html exists.
# mapping-ignored-field.html exists.
# mapping-id-field.html exists.
# mapping-index-field.html exists.
# mapping-meta-field.html exists.
# mapping-routing-field.html exists.
# mapping-source-field.html exists.
# mapping-tier-field.html exists.
# mapping-params.html exists.
# analyzer.html exists.
# coerce.html exists.
# copy-to.html exists.
# doc-values.html exists.
# dynamic.html exists.
# eager-global-ordinals.html exists.
# enabled.html exists.
# mapping-date-format.html exists.
# ignore-above.html exists.
# ignore-malformed.html exists.
# mapping-index.html exists.
# index-options.html exists.
# index-phrases.html exists.
# index-prefixes.html exists.
# mapping-field-meta.html exists.
# multi-fields.html exists.
# normalizer.html exists.
# norms.html exists.
# null-value.html exists.
# position-increment-gap.html exists.
# properties.html exists.
# search-analyzer.html exists.
# similarity.html exists.
# mapping-store.html exists.
# subobjects.html exists.
# term-vector.html exists.
# mapping-settings-limit.html exists.
# removal-of-types.html exists.
# analysis.html exists.
# analysis-overview.html exists.
# analysis-concepts.html exists.
# analyzer-anatomy.html exists.
# analysis-index-search-time.html exists.
# stemming.html exists.
# token-graphs.html exists.
# configure-text-analysis.html exists.
# test-analyzer.html exists.
# configuring-analyzers.html exists.
# analysis-custom-analyzer.html exists.
# specify-analyzer.html exists.
# analysis-analyzers.html exists.
# analysis-fingerprint-analyzer.html exists.
# analysis-keyword-analyzer.html exists.
# analysis-lang-analyzer.html exists.
# analysis-pattern-analyzer.html exists.
# analysis-simple-analyzer.html exists.
# analysis-standard-analyzer.html exists.
# analysis-stop-analyzer.html exists.
# analysis-whitespace-analyzer.html exists.
# analysis-tokenizers.html exists.
# analysis-chargroup-tokenizer.html exists.
# analysis-classic-tokenizer.html exists.
# analysis-edgengram-tokenizer.html exists.
# analysis-keyword-tokenizer.html exists.
# analysis-letter-tokenizer.html exists.
# analysis-lowercase-tokenizer.html exists.
# analysis-ngram-tokenizer.html exists.
# analysis-pathhierarchy-tokenizer.html exists.
# analysis-pattern-tokenizer.html exists.
# analysis-simplepattern-tokenizer.html exists.
# analysis-simplepatternsplit-tokenizer.html exists.
# analysis-standard-tokenizer.html exists.
# analysis-thai-tokenizer.html exists.
# analysis-uaxurlemail-tokenizer.html exists.
# analysis-whitespace-tokenizer.html exists.
# analysis-tokenfilters.html exists.
# analysis-apostrophe-tokenfilter.html exists.
# analysis-asciifolding-tokenfilter.html exists.
# analysis-cjk-bigram-tokenfilter.html exists.
# analysis-cjk-width-tokenfilter.html exists.
# analysis-classic-tokenfilter.html exists.
# analysis-common-grams-tokenfilter.html exists.
# analysis-condition-tokenfilter.html exists.
# analysis-decimal-digit-tokenfilter.html exists.
# analysis-delimited-payload-tokenfilter.html exists.
# analysis-dict-decomp-tokenfilter.html exists.
# analysis-edgengram-tokenfilter.html exists.
# analysis-elision-tokenfilter.html exists.
# analysis-fingerprint-tokenfilter.html exists.
# analysis-flatten-graph-tokenfilter.html exists.
# analysis-hunspell-tokenfilter.html exists.
# analysis-hyp-decomp-tokenfilter.html exists.
# analysis-keep-types-tokenfilter.html exists.
# analysis-keep-words-tokenfilter.html exists.
# analysis-keyword-marker-tokenfilter.html exists.
# analysis-keyword-repeat-tokenfilter.html exists.
# analysis-kstem-tokenfilter.html exists.
# analysis-length-tokenfilter.html exists.
# analysis-limit-token-count-tokenfilter.html exists.
# analysis-lowercase-tokenfilter.html exists.
# analysis-minhash-tokenfilter.html exists.
# analysis-multiplexer-tokenfilter.html exists.
# analysis-ngram-tokenfilter.html exists.
# analysis-normalization-tokenfilter.html exists.
# analysis-pattern-capture-tokenfilter.html exists.
# analysis-pattern_replace-tokenfilter.html exists.
# analysis-phonetic-tokenfilter.html exists.
# analysis-porterstem-tokenfilter.html exists.
# analysis-predicatefilter-tokenfilter.html exists.
# analysis-remove-duplicates-tokenfilter.html exists.
# analysis-reverse-tokenfilter.html exists.
# analysis-shingle-tokenfilter.html exists.
# analysis-snowball-tokenfilter.html exists.
# analysis-stemmer-tokenfilter.html exists.
# analysis-stemmer-override-tokenfilter.html exists.
# analysis-stop-tokenfilter.html exists.
# analysis-synonym-tokenfilter.html exists.
# analysis-synonym-graph-tokenfilter.html exists.
# analysis-trim-tokenfilter.html exists.
# analysis-truncate-tokenfilter.html exists.
# analysis-unique-tokenfilter.html exists.
# analysis-uppercase-tokenfilter.html exists.
# analysis-word-delimiter-tokenfilter.html exists.
# analysis-word-delimiter-graph-tokenfilter.html exists.
# analysis-charfilters.html exists.
# analysis-htmlstrip-charfilter.html exists.
# analysis-mapping-charfilter.html exists.
# analysis-pattern-replace-charfilter.html exists.
# analysis-normalizers.html exists.
# ingest.html exists.
# common-log-format-example.html exists.
# ingest-enriching-data.html exists.
# enrich-setup.html exists.
# geo-match-enrich-policy-type.html exists.
# match-enrich-policy-type.html exists.
# range-enrich-policy-type.html exists.
# processors.html exists.
# append-processor.html exists.
# attachment.html exists.
# bytes-processor.html exists.
# ingest-circle-processor.html exists.
# community-id-processor.html exists.
# convert-processor.html exists.
# csv-processor.html exists.
# date-processor.html exists.
# date-index-name-processor.html exists.
# dissect-processor.html exists.
# dot-expand-processor.html exists.
# drop-processor.html exists.
# enrich-processor.html exists.
# fail-processor.html exists.
# fingerprint-processor.html exists.
# foreach-processor.html exists.
# ingest-geo-grid-processor.html exists.
# geoip-processor.html exists.
# grok-processor.html exists.
# gsub-processor.html exists.
# htmlstrip-processor.html exists.
# inference-processor.html exists.
# join-processor.html exists.
# json-processor.html exists.
# kv-processor.html exists.
# lowercase-processor.html exists.
# network-direction-processor.html exists.
# pipeline-processor.html exists.
# redact-processor.html exists.
# registered-domain-processor.html exists.
# remove-processor.html exists.
# rename-processor.html exists.
# reroute-processor.html exists.
# script-processor.html exists.
# set-processor.html exists.
# ingest-node-set-security-user-processor.html exists.
# sort-processor.html exists.
# split-processor.html exists.
# trim-processor.html exists.
# uppercase-processor.html exists.
# urldecode-processor.html exists.
# uri-parts-processor.html exists.
# user-agent-processor.html exists.
# ingest-pipeline-search.html exists.
# ingest-pipeline-search-inference.html exists.
# nlp-example.html exists.
# data-streams.html exists.
# set-up-a-data-stream.html exists.
# use-a-data-stream.html exists.
# modify-data-streams.html exists.
# tsds.html exists.
# set-up-tsds.html exists.
# tsds-index-settings.html exists.
# downsampling.html exists.
# downsampling-ilm.html exists.
# downsampling-manual.html exists.
# tsds-reindex.html exists.
# logs-data-stream.html exists.
# data-stream-lifecycle.html exists.
# tutorial-manage-new-data-stream.html exists.
# tutorial-manage-existing-data-stream.html exists.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/tutorial-migrate-data-stream-from-ilm-to-dsl.html
# Loaded content from pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/data-management.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/index-lifecycle-management.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/example-using-index-lifecycle-policy.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/getting-started-index-lifecycle-management.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/index-mgmt.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/overview-index-lifecycle-management.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-concepts.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-index-lifecycle.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/index-rollover.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/update-lifecycle-policy.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-actions.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-allocate.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-delete.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-forcemerge.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-migrate.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-readonly.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-rollover.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-downsample.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-searchable-snapshot.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-set-priority.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-shrink.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-unfollow.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-wait-for-snapshot.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/set-up-lifecycle-policy.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrate-index-allocation-filters.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/index-lifecycle-error-handling.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/start-stop-ilm.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ilm-with-existing-indices.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/skipping-rollover.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/index-lifecycle-and-snapshots.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/data-tiers.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/data-rollup-transform.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/xpack-rollup.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/rollup-overview.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/rollup-api-quickref.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/rollup-getting-started.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/rollup-understanding-groups.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/rollup-agg-limitations.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/rollup-search-limitations.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/rollup-migrating-to-downsampling.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/transforms.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/transform-overview.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/transform-setup.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/transform-usage.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/transform-alerts.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/transform-scale.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/transform-checkpoints.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/transform-api-quickref.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/ecommerce-transforms.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/transform-examples.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/transform-painless-examples.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/transform-limitations.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-filter-context.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/compound-queries.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-bool-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-boosting-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-constant-score-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-dis-max-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-function-score-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/full-text-queries.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-intervals-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-match-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-match-bool-prefix-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-match-query-phrase.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-match-query-phrase-prefix.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-combined-fields-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-multi-match-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-query-string-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-simple-query-string-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/geo-queries.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-geo-bounding-box-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-geo-distance-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-geo-grid-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-geo-polygon-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-geo-shape-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/shape-queries.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-shape-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/joining-queries.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-nested-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-has-child-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-has-parent-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-parent-id-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-match-all-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/span-queries.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-span-containing-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-span-field-masking-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-span-first-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-span-multi-term-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-span-near-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-span-not-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-span-or-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-span-term-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-span-within-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/vector-queries.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-knn-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-sparse-vector-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-semantic-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-text-expansion-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-weighted-tokens-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/specialized-queries.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-distance-feature-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-mlt-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-percolate-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-rank-feature-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-script-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-script-score-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-wrapper-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-pinned-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-rule-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/term-level-queries.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-exists-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-fuzzy-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-ids-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-prefix-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-range-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-regexp-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-term-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-terms-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-terms-set-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-wildcard-query.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-minimum-should-match.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-multi-term-rewrite.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/regexp-syntax.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/eql.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/eql-syntax.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/eql-function-ref.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/eql-pipe-ref.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/eql-ex-threat-detection.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-getting-started.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-language.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-syntax.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-commands.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-functions-operators.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-metadata-fields.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-multivalued-fields.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-process-data-with-dissect-and-grok.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-enrich-data.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-implicit-casting.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-using.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-rest.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-kibana.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-elastic-security.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-multi-index.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-cross-clusters.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-task-management.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-limitations.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/esql-examples.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/xpack-sql.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-overview.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-getting-started.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-concepts.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/_mapping_concepts_across_sql_and_elasticsearch.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-security.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-rest.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-rest-overview.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-rest-format.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-pagination.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-rest-filtering.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-rest-columnar.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-rest-params.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-runtime-fields.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-async.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-translate.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-cli.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-jdbc.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/_api_usage.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-odbc.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-odbc-installation.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-odbc-setup.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-client-apps.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-client-apps-dbeaver.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-client-apps-dbvis.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-client-apps-excel.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-client-apps-powerbi.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-client-apps-ps1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-client-apps-microstrat.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-client-apps-qlik.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-client-apps-squirrel.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-client-apps-workbench.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-client-apps-tableau-desktop.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-client-apps-tableau-server.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-spec.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-lexical-structure.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-commands.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-syntax-describe-table.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-syntax-select.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-syntax-show-catalogs.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-syntax-show-columns.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-syntax-show-functions.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-syntax-show-tables.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-data-types.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-index-patterns.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-index-frozen.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-functions.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-operators.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-operators-logical.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-operators-math.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-operators-cast.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-like-rlike-operators.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-functions-aggs.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-functions-grouping.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-functions-datetime.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-functions-search.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-functions-math.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-functions-string.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-functions-type-conversion.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-functions-geo.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-functions-conditional.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-functions-system.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-syntax-reserved.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/sql-limitations.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/modules-scripting.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/modules-scripting-painless.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/modules-scripting-using.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/scripts-and-search-speed.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/dissect.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/grok.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/script-fields-api.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/common-script-uses.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/scripting-field-extraction.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/modules-scripting-fields.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/modules-scripting-security.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/modules-scripting-expression.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/modules-scripting-engine.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-adjacency-matrix-aggregation.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-autodatehistogram-aggregation.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-categorize-text-aggregation.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-children-aggregation.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-composite-aggregation.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-datehistogram-aggregation.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-daterange-aggregation.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-diversified-sampler-aggregation.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-filter-aggregation.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-filters-aggregation.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-frequent-item-sets-aggregation.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-geodistance-aggregation.html
# Fetched content from the web and saved to pickle.
# ...
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/corruption-troubleshooting.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/fix-data-node-out-of-disk.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/increase-capacity-data-node.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/decrease-disk-usage-data-node.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/fix-master-node-out-of-disk.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/fix-other-node-out-of-disk.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/start-ilm.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/start-slm.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/restore-from-snapshot.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/add-repository.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/diagnosing-corrupted-repositories.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/diagnosing-unknown-repositories.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/diagnosing-invalid-repositories.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/repeated-snapshot-failures.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/troubleshooting-unstable-cluster.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/discovery-troubleshooting.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/monitoring-troubleshooting.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/transform-troubleshooting.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/watcher-troubleshooting.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/troubleshooting-searches.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/troubleshooting-shards-capacity-issues.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/troubleshooting-unbalanced-cluster.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/diagnostic.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/setup-upgrade.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/archived-settings.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/archive-indices.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/breaking-changes.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.15.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.14.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.13.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.12.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.11.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.10.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.9.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.8.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.7.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.6.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.5.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.4.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.3.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrating-8.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/migrate-to-java-time.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/transient-settings-migration-guide.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-highlights.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/es-release-notes.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.15.3.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.15.2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.15.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.15.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.14.3.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.14.2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.14.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.14.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.13.4.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.13.3.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.13.2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/_bug_fixes.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.13.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/_bug_fixes_2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.13.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.12.2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.12.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.12.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.11.4.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.11.3.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.11.2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.11.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.11.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.10.4.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.10.3.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.10.2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.10.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.10.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.9.2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.9.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.9.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.8.2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.8.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.8.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.7.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.7.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.6.2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.6.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.6.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.5.3.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.5.2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.5.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.5.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.4.3.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.4.2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.4.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.4.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.3.3.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.3.2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.3.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.3.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.2.3.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.2.2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.2.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.2.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.1.3.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.1.2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.1.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.1.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.0.1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.0.0.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.0.0-rc2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.0.0-rc1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.0.0-beta1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.0.0-alpha2.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/release-notes-8.0.0-alpha1.html
# Fetched content from the web and saved to pickle.
# https://www.elastic.co/guide/en/elasticsearch/reference/current/dependencies-versions.html
# Fetched content from the web and saved to pickle.

# %%
len(docs_uris)
# Out:
# 1584

# %%
from bs4 import BeautifulSoup
import requests

# Example HTML content or fetch from a URL
url = "https://www.elastic.co/guide/en/elasticsearch/reference/current/paginate-search-results.html"
html_content = requests.get(url).text

# Parse the HTML content
soup = BeautifulSoup(html_content, "html.parser")

# %%
print(soup.html)
# Out:
# <html lang="en-us">
# <head>
# <meta charset="utf-8"/>
# <title>Paginate search results | Elasticsearch Guide [8.15] | Elastic</title>
# <meta class="elastic" content="Paginate search results | Elasticsearch Guide [8.15]" name="content"/>
# <link href="index.html" rel="home" title="Elasticsearch Guide [8.15]"/>
# <link href="search-your-data.html" rel="up" title="The search API"/>
# <link href="sort-search-results.html" rel="prev" title="Sort search results"/>
# <link href="search-fields.html" rel="next" title="Retrieve selected fields from a search"/>
# <meta class="elastic" content="8.15" name="product_version">
# <meta class="elastic" content="Elasticsearch" name="product_name">
# <meta class="elastic" content="documentation" name="website_area"/>
# <meta content="Learn/Docs/Elasticsearch/Reference/8.15" name="DC.type"/>
# <meta content="Elasticsearch" name="DC.subject"/>
# <meta content="8.15" name="DC.identifier"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script src="https://cdn.optimizely.com/js/18132920325.js"></script>
# <link href="/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="Elastic" name="apple-mobile-web-app-title"/>
# <meta content="Elastic" name="application-name"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="936882c1853b701b3cef3721758d80535413dbfd" name="naver-site-verification">
# <meta content="d8a47e95d0972434" name="yandex-verification">
# <meta content="true" name="localized">
# <meta content="follow,index" name="st:robots">
# <meta content="https://static-www.elastic.co/v3/assets/bltefdd0b53724fa2ce/blt280217a63b82a734/6202d3378b1f312528798412/elastic-logo.svg" property="og:image">
# <meta content="500" property="og:image:width">
# <meta content="172" property="og:image:height">
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/favicon_64x64_16bit.png" rel="apple-touch-icon-precomposed" sizes="64x64"/>
# <link href="/favicon_32x32.png" rel="apple-touch-icon-precomposed" sizes="32x32"/>
# <link href="/favicon_16x16.png" rel="apple-touch-icon-precomposed" sizes="16x16"/>
# <!-- Give IE8 a fighting chance -->
# <!--[if lt IE 9]>
#     <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#     <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
# <link href="/guide/static/styles-v1.css" rel="stylesheet" type="text/css">
# </link></meta></meta></meta></meta></meta></meta></meta></meta></meta></head>
# <!--© 2015-2025 Elasticsearch B.V. -->
# <!-- All Elastic documentation is licensed under a Creative Commons Attribution-NonCommercial-NoDerivatives 4.0 International License. -->
# <!-- http://creativecommons.org/licenses/by-nc-nd/4.0/ -->
# <body>
# <!-- Google Tag Manager -->
# <script>dataLayer = [];</script><noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-58RLH5" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-58RLH5');</script>
# <!-- End Google Tag Manager -->
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-12395217-16"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#       gtag('config', 'UA-12395217-16');
#     </script>
# <!-- Google Tag Manager for GA4 -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-KNJMG2M');</script>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KNJMG2M" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager for GA4-->
# <div id="elastic-nav" style="display:none;"></div>
# <script src="https://www.elastic.co/elastic-nav.js"></script>
# <div class="main-container">
# <section id="content">
# <div class="content-wrapper">
# <section id="guide" lang="en">
# <div class="container-fluid">
# <div class="row pb-3">
# <div class="col-12 order-2 col-md-4 order-md-1 col-lg-3 h-almost-full-md sticky-top-md" id="left_col">
# <!-- The TOC is appended here -->
# </div>
# <div class="col-12 order-1 col-md-8 order-md-2 col-lg-7 order-lg-2 guide-section" id="middle_col">
# <!-- start body -->
# <div class="navheader">
# <span class="prev">
# <a href="sort-search-results.html">« Sort search results</a>
# </span>
# <span class="next">
# <a href="search-fields.html">Retrieve selected fields from a search »</a>
# </span>
# </div>
# <div class="book" lang="en">
# <div class="titlepage">
# <div class="breadcrumbs">
# <span class="breadcrumb-link"><a href="/guide/">Elastic Docs</a></span>
# <span class="chevron-right">›</span><span class="breadcrumb-link"><a href="index.html">Elasticsearch Guide [8.15]</a></span>
# <span class="chevron-right">›</span><span class="breadcrumb-link"><a href="search-with-elasticsearch.html">Search your data</a></span>
# <span class="chevron-right">›</span><span class="breadcrumb-link"><a href="search-your-data.html">The search API</a></span>
# </div>
# <div>
# <div><h1 class="title"><a id="id-1"></a>Paginate search results</h1><a class="edit_me" href="https://github.com/elastic/elasticsearch/edit/8.15/docs/reference/search/search-your-data/paginate-search-results.asciidoc" rel="nofollow" title="Edit this page on GitHub">edit</a></div>
# </div>
# <!--EXTRA-->
# </div>
# <div id="content">
# <div class="section">
# <div class="titlepage"><div><div>
# <div class="position-relative"><h2 class="title"><a id="paginate-search-results"></a>Paginate search results</h2><a class="edit_me" href="https://github.com/elastic/elasticsearch/edit/8.15/docs/reference/search/search-your-data/paginate-search-results.asciidoc" rel="nofollow" title="Edit this page on GitHub">edit</a></div>
# </div></div></div>
# <p>By default, searches return the top 10 matching hits. To page through a larger
# set of results, you can use the <a class="xref" href="search-search.html" title="Search API">search API</a>'s <code class="literal">from</code> and <code class="literal">size</code>
# parameters. The <code class="literal">from</code> parameter defines the number of hits to skip, defaulting
# to <code class="literal">0</code>. The <code class="literal">size</code> parameter is the maximum number of hits to return. Together,
# these two parameters define a page of results.</p>
# <div class="pre_wrapper lang-python alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#     from_=5,
#     size=20,
#     query={
#         "match": {
#             "user.id": "kimchy"
#         }
#     },
# )
# print(resp)</pre>
# </div>
# <div class="pre_wrapper lang-ruby alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-ruby alternative">response = client.search(
#   body: {
#     from: 5,
#     size: 20,
#     query: {
#       match: {
#         'user.id' =&gt; 'kimchy'
#       }
#     }
#   }
# )
# puts response</pre>
# </div>
# <div class="pre_wrapper lang-go alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-go alternative">res, err := es.Search(
# 	es.Search.WithBody(strings.NewReader(`{
# 	  "from": 5,
# 	  "size": 20,
# 	  "query": {
# 	    "match": {
# 	      "user.id": "kimchy"
# 	    }
# 	  }
# 	}`)),
# 	es.Search.WithPretty(),
# )
# fmt.Println(res, err)</pre>
# </div>
# <div class="pre_wrapper lang-js alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#   from: 5,
#   size: 20,
#   query: {
#     match: {
#       "user.id": "kimchy",
#     },
#   },
# });
# console.log(response);</pre>
# </div>
# <a id="820f689eaaef15fc07abd1073fa880f8"></a>
# <div class="pre_wrapper lang-console default has-python has-ruby has-go has-js">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console default has-python has-ruby has-go has-js">GET /_search
# {
#   "from": 5,
#   "size": 20,
#   "query": {
#     "match": {
#       "user.id": "kimchy"
#     }
#   }
# }</pre>
# </div>
# <div class="console_widget has-python has-ruby has-go has-js" data-snippet="snippets/123.console"></div>
# <p>Avoid using <code class="literal">from</code> and <code class="literal">size</code> to page too deeply or request too many results at
# once. Search requests usually span multiple shards. Each shard must load its
# requested hits and the hits for any previous pages into memory. For deep pages
# or large sets of results, these operations can significantly increase memory and
# CPU usage, resulting in degraded performance or node failures.</p>
# <p>By default, you cannot use <code class="literal">from</code> and <code class="literal">size</code> to page through more than 10,000
# hits. This limit is a safeguard set by the
# <a class="xref" href="index-modules.html#index-max-result-window"><code class="literal">index.max_result_window</code></a> index setting. If you need
# to page through more than 10,000 hits, use the <a class="xref" href="paginate-search-results.html#search-after" title="Search after"><code class="literal">search_after</code></a>
# parameter instead.</p>
# <div class="warning admon">
# <div class="icon"></div>
# <div class="admon_content">
# <p>Elasticsearch uses Lucene’s internal doc IDs as tie-breakers. These internal doc
# IDs can be completely different across replicas of the same data. When paging
# search hits, you might occasionally see that documents with the same sort values
# are not ordered consistently.</p>
# </div>
# </div>
# <div class="position-relative"><h3><a id="search-after"></a>Search after</h3><a class="edit_me" href="https://github.com/elastic/elasticsearch/edit/8.15/docs/reference/search/search-your-data/paginate-search-results.asciidoc" rel="nofollow" title="Edit this page on GitHub">edit</a></div>
# <p>You can use the <code class="literal">search_after</code> parameter to retrieve the next page of hits
# using a set of <a class="xref" href="sort-search-results.html" title="Sort search results">sort values</a> from the previous page.</p>
# <p>Using <code class="literal">search_after</code> requires multiple search requests with the same <code class="literal">query</code> and
# <code class="literal">sort</code> values. The first step is to run an initial request. The following
# example sorts the results by two fields (<code class="literal">date</code> and <code class="literal">tie_breaker_id</code>):</p>
# <div class="pre_wrapper lang-python alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#     index="twitter",
#     query={
#         "match": {
#             "title": "elasticsearch"
#         }
#     },
#     sort=[
#         {
#             "date": "asc"
#         },
#         {
#             "tie_breaker_id": "asc"
#         }
#     ],
# )
# print(resp)</pre>
# </div>
# <div class="pre_wrapper lang-ruby alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-ruby alternative">response = client.search(
#   index: 'twitter',
#   body: {
#     query: {
#       match: {
#         title: 'elasticsearch'
#       }
#     },
#     sort: [
#       {
#         date: 'asc'
#       },
#       {
#         tie_breaker_id: 'asc'
#       }
#     ]
#   }
# )
# puts response</pre>
# </div>
# <div class="pre_wrapper lang-js alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#   index: "twitter",
#   query: {
#     match: {
#       title: "elasticsearch",
#     },
#   },
#   sort: [
#     {
#       date: "asc",
#     },
#     {
#       tie_breaker_id: "asc",
#     },
#   ],
# });
# console.log(response);</pre>
# </div>
# <a id="91750571c195718f0ff246e058e4bc63"></a>
# <div class="pre_wrapper lang-console default has-python has-ruby has-js">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console default has-python has-ruby has-js">GET twitter/_search
# {
#     "query": {
#         "match": {
#             "title": "elasticsearch"
#         }
#     },
#     "sort": [
#         {"date": "asc"},
#         {"tie_breaker_id": "asc"}      <a id="CO51-1"></a><i class="conum" data-value="1"></i>
#     ]
# }</pre>
# </div>
# <div class="console_widget has-python has-ruby has-js" data-snippet="snippets/124.console"></div>
# <div class="calloutlist default has-python has-ruby has-js lang-console">
# <table border="0" summary="Callout list">
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO51-1"><i class="conum" data-value="1"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>A copy of the <code class="literal">_id</code> field with <code class="literal">doc_values</code> enabled</p>
# </td>
# </tr>
# </table>
# </div>
# <p>The search response includes an array of <code class="literal">sort</code> values for each hit:</p>
# <a id="8a501f4a6e6de6ce8d467125400eabb8"></a>
# <div class="pre_wrapper lang-console-result">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console-result">{
#   "took" : 17,
#   "timed_out" : false,
#   "_shards" : ...,
#   "hits" : {
#     "total" : ...,
#     "max_score" : null,
#     "hits" : [
#       ...
#       {
#         "_index" : "twitter",
#         "_id" : "654322",
#         "_score" : null,
#         "_source" : ...,
#         "sort" : [
#           1463538855,
#           "654322"
#         ]
#       },
#       {
#         "_index" : "twitter",
#         "_id" : "654323",
#         "_score" : null,
#         "_source" : ...,
#         "sort" : [                                <a id="CO52-1"></a><i class="conum" data-value="1"></i>
#           1463538857,
#           "654323"
#         ]
#       }
#     ]
#   }
# }</pre>
# </div>
# <div class="calloutlist">
# <table border="0" summary="Callout list">
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO52-1"><i class="conum" data-value="1"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>Sort values for the last returned hit.</p>
# </td>
# </tr>
# </table>
# </div>
# <p>To retrieve the next page of results, repeat the request, take the <code class="literal">sort</code> values from the
# last hit, and insert those into the <code class="literal">search_after</code> array:</p>
# <div class="pre_wrapper lang-python alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#     index="twitter",
#     query={
#         "match": {
#             "title": "elasticsearch"
#         }
#     },
#     search_after=[
#         1463538857,
#         "654323"
#     ],
#     sort=[
#         {
#             "date": "asc"
#         },
#         {
#             "tie_breaker_id": "asc"
#         }
#     ],
# )
# print(resp)</pre>
# </div>
# <div class="pre_wrapper lang-ruby alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-ruby alternative">response = client.search(
#   index: 'twitter',
#   body: {
#     query: {
#       match: {
#         title: 'elasticsearch'
#       }
#     },
#     search_after: [
#       1_463_538_857,
#       '654323'
#     ],
#     sort: [
#       {
#         date: 'asc'
#       },
#       {
#         tie_breaker_id: 'asc'
#       }
#     ]
#   }
# )
# puts response</pre>
# </div>
# <div class="pre_wrapper lang-js alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#   index: "twitter",
#   query: {
#     match: {
#       title: "elasticsearch",
#     },
#   },
#   search_after: [1463538857, "654323"],
#   sort: [
#     {
#       date: "asc",
#     },
#     {
#       tie_breaker_id: "asc",
#     },
#   ],
# });
# console.log(response);</pre>
# </div>
# <a id="d851282dba548251d10db5954a339307"></a>
# <div class="pre_wrapper lang-console default has-python has-ruby has-js">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console default has-python has-ruby has-js">GET twitter/_search
# {
#     "query": {
#         "match": {
#             "title": "elasticsearch"
#         }
#     },
#     "search_after": [1463538857, "654323"],
#     "sort": [
#         {"date": "asc"},
#         {"tie_breaker_id": "asc"}
#     ]
# }</pre>
# </div>
# <div class="console_widget has-python has-ruby has-js" data-snippet="snippets/125.console"></div>
# <p>Repeat this process by updating the <code class="literal">search_after</code> array every time you retrieve a
# new page of results. If a <a class="xref" href="near-real-time.html" title="Near real-time search">refresh</a> occurs between these requests,
# the order of your results may change, causing inconsistent results across pages. To
# prevent this, you can create a <a class="xref" href="point-in-time-api.html" title="Point in time API">point in time (PIT)</a> to
# preserve the current index state over your searches.</p>
# <div class="pre_wrapper lang-python alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-python alternative">resp = client.open_point_in_time(
#     index="my-index-000001",
#     keep_alive="1m",
# )
# print(resp)</pre>
# </div>
# <div class="pre_wrapper lang-ruby alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-ruby alternative">response = client.open_point_in_time(
#   index: 'my-index-000001',
#   keep_alive: '1m'
# )
# puts response</pre>
# </div>
# <div class="pre_wrapper lang-js alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-js alternative">const response = await client.openPointInTime({
#   index: "my-index-000001",
#   keep_alive: "1m",
# });
# console.log(response);</pre>
# </div>
# <a id="5987afb2c17c73fe3d860937565ef115"></a>
# <div class="pre_wrapper lang-console default has-python has-ruby has-js">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console default has-python has-ruby has-js">POST /my-index-000001/_pit?keep_alive=1m</pre>
# </div>
# <div class="console_widget has-python has-ruby has-js" data-snippet="snippets/126.console"></div>
# <p>The API returns a PIT ID.</p>
# <a id="0ff873f3acf223856340dabff57e4ce8"></a>
# <div class="pre_wrapper lang-console-result">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console-result">{
#   "id": "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA=="
# }</pre>
# </div>
# <p>To get the first page of results, submit a search request with a <code class="literal">sort</code>
# argument. If using a PIT, specify the PIT ID in the <code class="literal">pit.id</code> parameter and omit
# the target data stream or index from the request path.</p>
# <div class="important admon">
# <div class="icon"></div>
# <div class="admon_content">
# <p>All PIT search requests add an implicit sort tiebreaker field called <code class="literal">_shard_doc</code>,
# which can also be provided explicitly.
# If you cannot use a PIT, we recommend that you include a tiebreaker field
# in your <code class="literal">sort</code>. This tiebreaker field should contain a unique value for each document.
# If you don’t include a tiebreaker field, your paged results could miss or duplicate hits.</p>
# </div>
# </div>
# <div class="note admon">
# <div class="icon"></div>
# <div class="admon_content">
# <p>Search after requests have optimizations that make them faster when the sort
# order is <code class="literal">_shard_doc</code> and total hits are not tracked. If you want to iterate over all documents regardless of the
# order, this is the most efficient option.</p>
# </div>
# </div>
# <div class="important admon">
# <div class="icon"></div>
# <div class="admon_content">
# <p>If the <code class="literal">sort</code> field is a <a class="xref" href="date.html" title="Date field type"><code class="literal">date</code></a> in some target data streams or indices
# but a <a class="xref" href="date_nanos.html" title="Date nanoseconds field type"><code class="literal">date_nanos</code></a> field in other targets, use the <code class="literal">numeric_type</code> parameter
# to convert the values to a single resolution and the <code class="literal">format</code> parameter to specify a
# <a class="xref" href="mapping-date-format.html" title="format">date format</a> for the <code class="literal">sort</code> field. Otherwise, Elasticsearch won’t interpret
# the search after parameter correctly in each request.</p>
# </div>
# </div>
# <div class="pre_wrapper lang-python alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#     size=10000,
#     query={
#         "match": {
#             "user.id": "elkbee"
#         }
#     },
#     pit={
#         "id": "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
#         "keep_alive": "1m"
#     },
#     sort=[
#         {
#             "@timestamp": {
#                 "order": "asc",
#                 "format": "strict_date_optional_time_nanos",
#                 "numeric_type": "date_nanos"
#             }
#         }
#     ],
# )
# print(resp)</pre>
# </div>
# <div class="pre_wrapper lang-js alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#   size: 10000,
#   query: {
#     match: {
#       "user.id": "elkbee",
#     },
#   },
#   pit: {
#     id: "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
#     keep_alive: "1m",
#   },
#   sort: [
#     {
#       "@timestamp": {
#         order: "asc",
#         format: "strict_date_optional_time_nanos",
#         numeric_type: "date_nanos",
#       },
#     },
#   ],
# });
# console.log(response);</pre>
# </div>
# <a id="47909e194d10743093f4a22c27a85925"></a>
# <div class="pre_wrapper lang-console default has-python has-js">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console default has-python has-js">GET /_search
# {
#   "size": 10000,
#   "query": {
#     "match" : {
#       "user.id" : "elkbee"
#     }
#   },
#   "pit": {
#     "id":  "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==", <a id="CO53-1"></a><i class="conum" data-value="1"></i>
#     "keep_alive": "1m"
#   },
#   "sort": [ <a id="CO53-2"></a><i class="conum" data-value="2"></i>
#     {"@timestamp": {"order": "asc", "format": "strict_date_optional_time_nanos", "numeric_type" : "date_nanos" }}
#   ]
# }</pre>
# </div>
# <div class="console_widget has-python has-js" data-snippet="snippets/127.console"></div>
# <div class="calloutlist default has-python has-js lang-console">
# <table border="0" summary="Callout list">
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO53-1"><i class="conum" data-value="1"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>PIT ID for the search.</p>
# </td>
# </tr>
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO53-2"><i class="conum" data-value="2"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>Sorts hits for the search with an implicit tiebreak on <code class="literal">_shard_doc</code> ascending.</p>
# </td>
# </tr>
# </table>
# </div>
# <p>The search response includes an array of <code class="literal">sort</code> values for each hit. If you used
# a PIT, a tiebreaker is included as the last <code class="literal">sort</code> values for each hit.
# This tiebreaker called <code class="literal">_shard_doc</code> is added automatically on every search requests that use a PIT.
# The <code class="literal">_shard_doc</code> value is the combination of the shard index within the PIT and the Lucene’s internal doc ID,
# it is unique per document and constant within a PIT.
# You can also add the tiebreaker explicitly in the search request to customize the order:</p>
# <div class="pre_wrapper lang-python alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#     size=10000,
#     query={
#         "match": {
#             "user.id": "elkbee"
#         }
#     },
#     pit={
#         "id": "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
#         "keep_alive": "1m"
#     },
#     sort=[
#         {
#             "@timestamp": {
#                 "order": "asc",
#                 "format": "strict_date_optional_time_nanos"
#             }
#         },
#         {
#             "_shard_doc": "desc"
#         }
#     ],
# )
# print(resp)</pre>
# </div>
# <div class="pre_wrapper lang-js alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#   size: 10000,
#   query: {
#     match: {
#       "user.id": "elkbee",
#     },
#   },
#   pit: {
#     id: "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
#     keep_alive: "1m",
#   },
#   sort: [
#     {
#       "@timestamp": {
#         order: "asc",
#         format: "strict_date_optional_time_nanos",
#       },
#     },
#     {
#       _shard_doc: "desc",
#     },
#   ],
# });
# console.log(response);</pre>
# </div>
# <a id="4e50d9d25bfb07ac73e3a2be5d2fbbf7"></a>
# <div class="pre_wrapper lang-console default has-python has-js">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console default has-python has-js">GET /_search
# {
#   "size": 10000,
#   "query": {
#     "match" : {
#       "user.id" : "elkbee"
#     }
#   },
#   "pit": {
#     "id":  "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==", <a id="CO54-1"></a><i class="conum" data-value="1"></i>
#     "keep_alive": "1m"
#   },
#   "sort": [ <a id="CO54-2"></a><i class="conum" data-value="2"></i>
#     {"@timestamp": {"order": "asc", "format": "strict_date_optional_time_nanos"}},
#     {"_shard_doc": "desc"}
#   ]
# }</pre>
# </div>
# <div class="console_widget has-python has-js" data-snippet="snippets/128.console"></div>
# <div class="calloutlist default has-python has-js lang-console">
# <table border="0" summary="Callout list">
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO54-1"><i class="conum" data-value="1"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>PIT ID for the search.</p>
# </td>
# </tr>
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO54-2"><i class="conum" data-value="2"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>Sorts hits for the search with an explicit tiebreak on <code class="literal">_shard_doc</code> descending.</p>
# </td>
# </tr>
# </table>
# </div>
# <a id="2938ccebfbc8550cc49016a68d8ef032"></a>
# <div class="pre_wrapper lang-console-result">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console-result">{
#   "pit_id" : "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==", <a id="CO55-1"></a><i class="conum" data-value="1"></i>
#   "took" : 17,
#   "timed_out" : false,
#   "_shards" : ...,
#   "hits" : {
#     "total" : ...,
#     "max_score" : null,
#     "hits" : [
#       ...
#       {
#         "_index" : "my-index-000001",
#         "_id" : "FaslK3QBySSL_rrj9zM5",
#         "_score" : null,
#         "_source" : ...,
#         "sort" : [                                <a id="CO55-2"></a><i class="conum" data-value="2"></i>
#           "2021-05-20T05:30:04.832Z",
#           4294967298                              <a id="CO55-3"></a><i class="conum" data-value="3"></i>
#         ]
#       }
#     ]
#   }
# }</pre>
# </div>
# <div class="calloutlist">
# <table border="0" summary="Callout list">
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO55-1"><i class="conum" data-value="1"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>Updated <code class="literal">id</code> for the point in time.</p>
# </td>
# </tr>
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO55-2"><i class="conum" data-value="2"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>Sort values for the last returned hit.</p>
# </td>
# </tr>
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO55-3"><i class="conum" data-value="3"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>The tiebreaker value, unique per document within the <code class="literal">pit_id</code>.</p>
# </td>
# </tr>
# </table>
# </div>
# <p>To get the next page of results, rerun the previous search using the last hit’s
# sort values (including the tiebreaker) as the <code class="literal">search_after</code> argument. If using a PIT, use the latest PIT
# ID in the <code class="literal">pit.id</code> parameter. The search’s <code class="literal">query</code> and <code class="literal">sort</code> arguments must
# remain unchanged. If provided, the <code class="literal">from</code> argument must be <code class="literal">0</code> (default) or <code class="literal">-1</code>.</p>
# <div class="pre_wrapper lang-python alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#     size=10000,
#     query={
#         "match": {
#             "user.id": "elkbee"
#         }
#     },
#     pit={
#         "id": "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
#         "keep_alive": "1m"
#     },
#     sort=[
#         {
#             "@timestamp": {
#                 "order": "asc",
#                 "format": "strict_date_optional_time_nanos"
#             }
#         }
#     ],
#     search_after=[
#         "2021-05-20T05:30:04.832Z",
#         4294967298
#     ],
#     track_total_hits=False,
# )
# print(resp)</pre>
# </div>
# <div class="pre_wrapper lang-js alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#   size: 10000,
#   query: {
#     match: {
#       "user.id": "elkbee",
#     },
#   },
#   pit: {
#     id: "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
#     keep_alive: "1m",
#   },
#   sort: [
#     {
#       "@timestamp": {
#         order: "asc",
#         format: "strict_date_optional_time_nanos",
#       },
#     },
#   ],
#   search_after: ["2021-05-20T05:30:04.832Z", 4294967298],
#   track_total_hits: false,
# });
# console.log(response);</pre>
# </div>
# <a id="7846974b47a3eab1832a475663d23ad9"></a>
# <div class="pre_wrapper lang-console default has-python has-js">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console default has-python has-js">GET /_search
# {
#   "size": 10000,
#   "query": {
#     "match" : {
#       "user.id" : "elkbee"
#     }
#   },
#   "pit": {
#     "id":  "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==", <a id="CO56-1"></a><i class="conum" data-value="1"></i>
#     "keep_alive": "1m"
#   },
#   "sort": [
#     {"@timestamp": {"order": "asc", "format": "strict_date_optional_time_nanos"}}
#   ],
#   "search_after": [                                <a id="CO56-2"></a><i class="conum" data-value="2"></i>
#     "2021-05-20T05:30:04.832Z",
#     4294967298
#   ],
#   "track_total_hits": false                        <a id="CO56-3"></a><i class="conum" data-value="3"></i>
# }</pre>
# </div>
# <div class="console_widget has-python has-js" data-snippet="snippets/129.console"></div>
# <div class="calloutlist default has-python has-js lang-console">
# <table border="0" summary="Callout list">
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO56-1"><i class="conum" data-value="1"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>PIT ID returned by the previous search.</p>
# </td>
# </tr>
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO56-2"><i class="conum" data-value="2"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>Sort values from the previous search’s last hit.</p>
# </td>
# </tr>
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO56-3"><i class="conum" data-value="3"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>Disable the tracking of total hits to speed up pagination.</p>
# </td>
# </tr>
# </table>
# </div>
# <p>You can repeat this process to get additional pages of results. If using a PIT,
# you can extend the PIT’s retention period using the
# <code class="literal">keep_alive</code> parameter of each search request.</p>
# <p>When you’re finished, you should delete your PIT.</p>
# <div class="pre_wrapper lang-python alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-python alternative">resp = client.close_point_in_time(
#     id="46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
# )
# print(resp)</pre>
# </div>
# <div class="pre_wrapper lang-ruby alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-ruby alternative">response = client.close_point_in_time(
#   body: {
#     id: '46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA=='
#   }
# )
# puts response</pre>
# </div>
# <div class="pre_wrapper lang-js alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-js alternative">const response = await client.closePointInTime({
#   id: "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
# });
# console.log(response);</pre>
# </div>
# <a id="9ff9b2a73419a6c82f17a358b4991499"></a>
# <div class="pre_wrapper lang-console default has-python has-ruby has-js">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console default has-python has-ruby has-js">DELETE /_pit
# {
#     "id" : "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA=="
# }</pre>
# </div>
# <div class="console_widget has-python has-ruby has-js" data-snippet="snippets/130.console"></div>
# <div class="position-relative"><h3><a id="scroll-search-results"></a>Scroll search results</h3><a class="edit_me" href="https://github.com/elastic/elasticsearch/edit/8.15/docs/reference/search/search-your-data/paginate-search-results.asciidoc" rel="nofollow" title="Edit this page on GitHub">edit</a></div>
# <div class="important admon">
# <div class="icon"></div>
# <div class="admon_content">
# <p>We no longer recommend using the scroll API for deep pagination. If
# you need to preserve the index state while paging through more than 10,000 hits,
# use the <a class="xref" href="paginate-search-results.html#search-after" title="Search after"><code class="literal">search_after</code></a> parameter with a point in time (PIT).</p>
# </div>
# </div>
# <p>While a <code class="literal">search</code> request returns a single “page” of results, the <code class="literal">scroll</code>
# API can be used to retrieve large numbers of results (or even all results)
# from a single search request, in much the same way as you would use a cursor
# on a traditional database.</p>
# <p>Scrolling is not intended for real time user requests, but rather for
# processing large amounts of data, e.g. in order to reindex the contents of one
# data stream or index into a new data stream or index with a different
# configuration.</p>
# <div class="sidebar">
# <div class="titlepage"><div><div>
# <p class="title"><strong>Client support for scrolling and reindexing</strong></p>
# </div></div></div>
# <p>Some of the officially supported clients provide helpers to assist with
# scrolled searches and reindexing:</p>
# <div class="variablelist">
# <dl class="variablelist">
# <dt>
# <span class="term">
# Perl
# </span>
# </dt>
# <dd>
# See <a class="ulink" href="https://metacpan.org/pod/Search::Elasticsearch::Client::5_0::Bulk" target="_top">Search::Elasticsearch::Client::5_0::Bulk</a>
# and <a class="ulink" href="https://metacpan.org/pod/Search::Elasticsearch::Client::5_0::Scroll" target="_top">Search::Elasticsearch::Client::5_0::Scroll</a>
# </dd>
# <dt>
# <span class="term">
# Python
# </span>
# </dt>
# <dd>
# See <a class="ulink" href="https://elasticsearch-py.readthedocs.io/en/stable/helpers.html" target="_top">elasticsearch.helpers.*</a>
# </dd>
# <dt>
# <span class="term">
# JavaScript
# </span>
# </dt>
# <dd>
# See <a class="ulink" href="/guide/en/elasticsearch/client/javascript-api/current/client-helpers.html" target="_top">client.helpers.*</a>
# </dd>
# </dl>
# </div>
# </div>
# <div class="note admon">
# <div class="icon"></div>
# <div class="admon_content">
# <p>The results that are returned from a scroll request reflect the state of
# the data stream or index at the time that the initial <code class="literal">search</code> request was made, like a
# snapshot in time. Subsequent changes to documents (index, update or delete)
# will only affect later search requests.</p>
# </div>
# </div>
# <p>In order to use scrolling, the initial search request should specify the
# <code class="literal">scroll</code> parameter in the query string, which tells Elasticsearch how long it
# should keep the “search context” alive (see <a class="xref" href="paginate-search-results.html#scroll-search-context" title="Keeping the search context alive">Keeping the search context alive</a>), eg <code class="literal">?scroll=1m</code>.</p>
# <div class="pre_wrapper lang-python alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#     index="my-index-000001",
#     scroll="1m",
#     size=100,
#     query={
#         "match": {
#             "message": "foo"
#         }
#     },
# )
# print(resp)</pre>
# </div>
# <div class="pre_wrapper lang-ruby alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-ruby alternative">response = client.search(
#   index: 'my-index-000001',
#   scroll: '1m',
#   body: {
#     size: 100,
#     query: {
#       match: {
#         message: 'foo'
#       }
#     }
#   }
# )
# puts response</pre>
# </div>
# <div class="pre_wrapper lang-js alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#   index: "my-index-000001",
#   scroll: "1m",
#   size: 100,
#   query: {
#     match: {
#       message: "foo",
#     },
#   },
# });
# console.log(response);</pre>
# </div>
# <a id="24f4dfdf9922d5aa79151675b7767742"></a>
# <div class="pre_wrapper lang-console default has-python has-ruby has-js">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console default has-python has-ruby has-js">POST /my-index-000001/_search?scroll=1m
# {
#   "size": 100,
#   "query": {
#     "match": {
#       "message": "foo"
#     }
#   }
# }</pre>
# </div>
# <div class="console_widget has-python has-ruby has-js" data-snippet="snippets/131.console"></div>
# <p>The result from the above request includes a <code class="literal">_scroll_id</code>, which should
# be passed to the <code class="literal">scroll</code> API in order to retrieve the next batch of
# results.</p>
# <div class="pre_wrapper lang-python alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-python alternative">resp = client.scroll(
#     scroll="1m",
#     scroll_id="DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==",
# )
# print(resp)</pre>
# </div>
# <div class="pre_wrapper lang-go alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-go alternative">res, err := es.Scroll(
# 	es.Scroll.WithBody(strings.NewReader(`{
# 	  "scroll": "1m",
# 	  "scroll_id": "DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ=="
# 	}`)),
# 	es.Scroll.WithPretty(),
# )
# fmt.Println(res, err)</pre>
# </div>
# <div class="pre_wrapper lang-js alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-js alternative">const response = await client.scroll({
#   scroll: "1m",
#   scroll_id: "DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==",
# });
# console.log(response);</pre>
# </div>
# <a id="add240aa149d8b11139947502b279ee0"></a>
# <div class="pre_wrapper lang-console default has-python has-go has-js">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console default has-python has-go has-js">POST /_search/scroll                                                               <a id="CO57-1"></a><i class="conum" data-value="1"></i>
# {
#   "scroll" : "1m",                                                                 <a id="CO57-2"></a><i class="conum" data-value="2"></i>
#   "scroll_id" : "DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==" <a id="CO57-3"></a><i class="conum" data-value="3"></i>
# }</pre>
# </div>
# <div class="console_widget has-python has-go has-js" data-snippet="snippets/132.console"></div>
# <div class="calloutlist default has-python has-go has-js lang-console">
# <table border="0" summary="Callout list">
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO57-1"><i class="conum" data-value="1"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p><code class="literal">GET</code> or <code class="literal">POST</code> can be used and the URL should not include the <code class="literal">index</code>
# name — this is specified in the original <code class="literal">search</code> request instead.</p>
# </td>
# </tr>
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO57-2"><i class="conum" data-value="2"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>The <code class="literal">scroll</code> parameter tells Elasticsearch to keep the search context open
# for another <code class="literal">1m</code>.</p>
# </td>
# </tr>
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO57-3"><i class="conum" data-value="3"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>The <code class="literal">scroll_id</code> parameter</p>
# </td>
# </tr>
# </table>
# </div>
# <p>The <code class="literal">size</code> parameter allows you to configure the maximum number of hits to be
# returned with each batch of results. Each call to the <code class="literal">scroll</code> API returns the
# next batch of results until there are no more results left to return, ie the
# <code class="literal">hits</code> array is empty.</p>
# <div class="important admon">
# <div class="icon"></div>
# <div class="admon_content">
# <p>The initial search request and each subsequent scroll request each
# return a <code class="literal">_scroll_id</code>. While the <code class="literal">_scroll_id</code> may change between requests, it doesn’t
# always change — in any case, only the most recently received <code class="literal">_scroll_id</code> should be used.</p>
# </div>
# </div>
# <div class="note admon">
# <div class="icon"></div>
# <div class="admon_content">
# <p>If the request specifies aggregations, only the initial search response
# will contain the aggregations results.</p>
# </div>
# </div>
# <div class="note admon">
# <div class="icon"></div>
# <div class="admon_content">
# <p>Scroll requests have optimizations that make them faster when the sort
# order is <code class="literal">_doc</code>. If you want to iterate over all documents regardless of the
# order, this is the most efficient option:</p>
# </div>
# </div>
# <div class="pre_wrapper lang-php alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-php alternative">$params = [
#     'body' =&gt; [
#         'sort' =&gt; [
#             '_doc',
#         ],
#     ],
# ];
# $response = $client-&gt;search($params);</pre>
# </div>
# <div class="pre_wrapper lang-python alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#     scroll="1m",
#     sort=[
#         "_doc"
#     ],
# )
# print(resp)</pre>
# </div>
# <div class="pre_wrapper lang-ruby alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-ruby alternative">response = client.search(
#   scroll: '1m',
#   body: {
#     sort: [
#       '_doc'
#     ]
#   }
# )
# puts response</pre>
# </div>
# <div class="pre_wrapper lang-go alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-go alternative">res, err := es.Search(
# 	es.Search.WithBody(strings.NewReader(`{
# 	  "sort": [
# 	    "_doc"
# 	  ]
# 	}`)),
# 	es.Search.WithScroll(time.Duration(60000000000)),
# 	es.Search.WithPretty(),
# )
# fmt.Println(res, err)</pre>
# </div>
# <div class="pre_wrapper lang-js alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#   scroll: "1m",
#   sort: ["_doc"],
# });
# console.log(response);</pre>
# </div>
# <a id="d5dcddc6398b473b6ad9bce5c6adf986"></a>
# ...
# {
#   "scroll_id" : [
#     "DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==",
#     "DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAAABFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAAAxZrUllkUVlCa1NqNmRMaUhiQlZkMWFBAAAAAAAAAAIWa1JZZFFZQmtTajZkTGlIYkJWZDFhQQAAAAAAAAAFFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAABBZrUllkUVlCa1NqNmRMaUhiQlZkMWFB"
#   ]
# }</pre>
# </div>
# <div class="console_widget has-python has-ruby has-go has-js" data-snippet="snippets/136.console"></div>
# <p>All search contexts can be cleared with the <code class="literal">_all</code> parameter:</p>
# <div class="pre_wrapper lang-php alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-php alternative">$params = [
#     'scroll_id' =&gt; '_all',
# ];
# $response = $client-&gt;clearScroll($params);</pre>
# </div>
# <div class="pre_wrapper lang-python alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-python alternative">resp = client.clear_scroll(
#     scroll_id="_all",
# )
# print(resp)</pre>
# </div>
# <div class="pre_wrapper lang-ruby alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-ruby alternative">response = client.clear_scroll(
#   scroll_id: '_all'
# )
# puts response</pre>
# </div>
# <div class="pre_wrapper lang-go alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-go alternative">res, err := es.ClearScroll(
# 	es.ClearScroll.WithScrollID("_all"),
# )
# fmt.Println(res, err)</pre>
# </div>
# <div class="pre_wrapper lang-js alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-js alternative">const response = await client.clearScroll({
#   scroll_id: "_all",
# });
# console.log(response);</pre>
# </div>
# <a id="c2c21e2824fbf6b7198ede30419da82b"></a>
# <div class="pre_wrapper lang-console default has-php has-python has-ruby has-go has-js">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console default has-php has-python has-ruby has-go has-js">DELETE /_search/scroll/_all</pre>
# </div>
# <div class="console_widget has-php has-python has-ruby has-go has-js" data-snippet="snippets/137.console"></div>
# <p>The <code class="literal">scroll_id</code> can also be passed as a query string parameter or in the request body.
# Multiple scroll IDs can be passed as comma separated values:</p>
# <div class="pre_wrapper lang-php alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-php alternative">$params = [
#     'scroll_id' =&gt; 'DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==,DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAAABFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAAAxZrUllkUVlCa1NqNmRMaUhiQlZkMWFBAAAAAAAAAAIWa1JZZFFZQmtTajZkTGlIYkJWZDFhQQAAAAAAAAAFFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAABBZrUllkUVlCa1NqNmRMaUhiQlZkMWFB',
# ];
# $response = $client-&gt;clearScroll($params);</pre>
# </div>
# <div class="pre_wrapper lang-python alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-python alternative">resp = client.clear_scroll(
#     scroll_id="DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==,DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAAABFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAAAxZrUllkUVlCa1NqNmRMaUhiQlZkMWFBAAAAAAAAAAIWa1JZZFFZQmtTajZkTGlIYkJWZDFhQQAAAAAAAAAFFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAABBZrUllkUVlCa1NqNmRMaUhiQlZkMWFB",
# )
# print(resp)</pre>
# </div>
# <div class="pre_wrapper lang-ruby alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-ruby alternative">response = client.clear_scroll(
#   scroll_id: 'DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==,DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAAABFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAAAxZrUllkUVlCa1NqNmRMaUhiQlZkMWFBAAAAAAAAAAIWa1JZZFFZQmtTajZkTGlIYkJWZDFhQQAAAAAAAAAFFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAABBZrUllkUVlCa1NqNmRMaUhiQlZkMWFB'
# )
# puts response</pre>
# </div>
# <div class="pre_wrapper lang-go alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-go alternative">res, err := es.ClearScroll(
# 	es.ClearScroll.WithScrollID("DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==", "DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAAABFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAAAxZrUllkUVlCa1NqNmRMaUhiQlZkMWFBAAAAAAAAAAIWa1JZZFFZQmtTajZkTGlIYkJWZDFhQQAAAAAAAAAFFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAABBZrUllkUVlCa1NqNmRMaUhiQlZkMWFB"),
# )
# fmt.Println(res, err)</pre>
# </div>
# <div class="pre_wrapper lang-js alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-js alternative">const response = await client.clearScroll({
#   scroll_id:
#     "DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==,DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAAABFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAAAxZrUllkUVlCa1NqNmRMaUhiQlZkMWFBAAAAAAAAAAIWa1JZZFFZQmtTajZkTGlIYkJWZDFhQQAAAAAAAAAFFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAABBZrUllkUVlCa1NqNmRMaUhiQlZkMWFB",
# });
# console.log(response);</pre>
# </div>
# <a id="b94cee0f74f57742b3948f9b784dfdd4"></a>
# <div class="pre_wrapper lang-console default has-php has-python has-ruby has-go has-js">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console default has-php has-python has-ruby has-go has-js">DELETE /_search/scroll/DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==,DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAAABFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAAAxZrUllkUVlCa1NqNmRMaUhiQlZkMWFBAAAAAAAAAAIWa1JZZFFZQmtTajZkTGlIYkJWZDFhQQAAAAAAAAAFFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAABBZrUllkUVlCa1NqNmRMaUhiQlZkMWFB</pre>
# </div>
# <div class="console_widget has-php has-python has-ruby has-go has-js" data-snippet="snippets/138.console"></div>
# <div class="position-relative"><h4><a id="slice-scroll"></a>Sliced scroll</h4><a class="edit_me" href="https://github.com/elastic/elasticsearch/edit/8.15/docs/reference/search/search-your-data/paginate-search-results.asciidoc" rel="nofollow" title="Edit this page on GitHub">edit</a></div>
# <p>When paging through a large number of documents, it can be helpful to split the search into multiple slices
# to consume them independently:</p>
# <div class="pre_wrapper lang-python alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#     index="my-index-000001",
#     scroll="1m",
#     slice={
#         "id": 0,
#         "max": 2
#     },
#     query={
#         "match": {
#             "message": "foo"
#         }
#     },
# )
# print(resp)
#
# resp1 = client.search(
#     index="my-index-000001",
#     scroll="1m",
#     slice={
#         "id": 1,
#         "max": 2
#     },
#     query={
#         "match": {
#             "message": "foo"
#         }
#     },
# )
# print(resp1)</pre>
# </div>
# <div class="pre_wrapper lang-ruby alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-ruby alternative">response = client.search(
#   index: 'my-index-000001',
#   scroll: '1m',
#   body: {
#     slice: {
#       id: 0,
#       max: 2
#     },
#     query: {
#       match: {
#         message: 'foo'
#       }
#     }
#   }
# )
# puts response
#
# response = client.search(
#   index: 'my-index-000001',
#   scroll: '1m',
#   body: {
#     slice: {
#       id: 1,
#       max: 2
#     },
#     query: {
#       match: {
#         message: 'foo'
#       }
#     }
#   }
# )
# puts response</pre>
# </div>
# <div class="pre_wrapper lang-js alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#   index: "my-index-000001",
#   scroll: "1m",
#   slice: {
#     id: 0,
#     max: 2,
#   },
#   query: {
#     match: {
#       message: "foo",
#     },
#   },
# });
# console.log(response);
#
# const response1 = await client.search({
#   index: "my-index-000001",
#   scroll: "1m",
#   slice: {
#     id: 1,
#     max: 2,
#   },
#   query: {
#     match: {
#       message: "foo",
#     },
#   },
# });
# console.log(response1);</pre>
# </div>
# <a id="3758b8f2ab9f6f28a764ee6c42c85766"></a>
# <div class="pre_wrapper lang-console default has-python has-ruby has-js">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console default has-python has-ruby has-js">GET /my-index-000001/_search?scroll=1m
# {
#   "slice": {
#     "id": 0,                      <a id="CO58-1"></a><i class="conum" data-value="1"></i>
#     "max": 2                      <a id="CO58-2"></a><i class="conum" data-value="2"></i>
#   },
#   "query": {
#     "match": {
#       "message": "foo"
#     }
#   }
# }
# GET /my-index-000001/_search?scroll=1m
# {
#   "slice": {
#     "id": 1,
#     "max": 2
#   },
#   "query": {
#     "match": {
#       "message": "foo"
#     }
#   }
# }</pre>
# </div>
# <div class="console_widget has-python has-ruby has-js" data-snippet="snippets/139.console"></div>
# <div class="calloutlist default has-python has-ruby has-js lang-console">
# <table border="0" summary="Callout list">
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO58-1"><i class="conum" data-value="1"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>The id of the slice</p>
# </td>
# </tr>
# <tr>
# <td align="left" valign="top" width="5%">
# <p><a href="#CO58-2"><i class="conum" data-value="2"></i></a></p>
# </td>
# <td align="left" valign="top">
# <p>The maximum number of slices</p>
# </td>
# </tr>
# </table>
# </div>
# <p>The result from the first request returned documents that belong to the first slice (id: 0) and
# the result from the second request returned documents that belong to the second slice. Since the
# maximum number of slices is set to 2 the union of the results of the two requests is equivalent
# to the results of a scroll query without slicing. By default the splitting is done first on the
# shards, then locally on each shard using the <code class="literal">_id</code> field. The local splitting follows the formula
# <code class="literal">slice(doc) = floorMod(hashCode(doc._id), max))</code>.</p>
# <p>Each scroll is independent and can be processed in parallel like any scroll request.</p>
# <div class="note admon">
# <div class="icon"></div>
# <div class="admon_content">
# <p>If the number of slices is bigger than the number of shards the slice filter is very slow on
# the first calls, it has a complexity of O(N) and a memory cost equals to N bits per slice where N
# is the total number of documents in the shard. After few calls the filter should be cached and
# subsequent calls should be faster but you should limit the number of sliced query you perform in
# parallel to avoid the memory explosion.</p>
# </div>
# </div>
# <p>The <a class="xref" href="point-in-time-api.html" title="Point in time API">point-in-time</a> API supports a more efficient partitioning strategy and
# does not suffer from this problem. When possible, it’s recommended to use a point-in-time search
# with slicing instead of a scroll.</p>
# <p>Another way to avoid this high cost is to use the <code class="literal">doc_values</code> of another field to do the slicing.
# The field must have the following properties:</p>
# <div class="ulist itemizedlist">
# <ul class="itemizedlist">
# <li class="listitem">
# The field is numeric.
# </li>
# <li class="listitem">
# <code class="literal">doc_values</code> are enabled on that field
# </li>
# <li class="listitem">
# Every document should contain a single value. If a document has multiple values for the specified field, the first value is used.
# </li>
# <li class="listitem">
# The value for each document should be set once when the document is created and never updated. This ensures that each
# slice gets deterministic results.
# </li>
# <li class="listitem">
# The cardinality of the field should be high. This ensures that each slice gets approximately the same amount of documents.
# </li>
# </ul>
# </div>
# <div class="pre_wrapper lang-python alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#     index="my-index-000001",
#     scroll="1m",
#     slice={
#         "field": "@timestamp",
#         "id": 0,
#         "max": 10
#     },
#     query={
#         "match": {
#             "message": "foo"
#         }
#     },
# )
# print(resp)</pre>
# </div>
# <div class="pre_wrapper lang-ruby alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-ruby alternative">response = client.search(
#   index: 'my-index-000001',
#   scroll: '1m',
#   body: {
#     slice: {
#       field: '@timestamp',
#       id: 0,
#       max: 10
#     },
#     query: {
#       match: {
#         message: 'foo'
#       }
#     }
#   }
# )
# puts response</pre>
# </div>
# <div class="pre_wrapper lang-js alternative">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#   index: "my-index-000001",
#   scroll: "1m",
#   slice: {
#     field: "@timestamp",
#     id: 0,
#     max: 10,
#   },
#   query: {
#     match: {
#       message: "foo",
#     },
#   },
# });
# console.log(response);</pre>
# </div>
# <a id="187733e50c60350f3f75921bea3b72c2"></a>
# <div class="pre_wrapper lang-console default has-python has-ruby has-js">
# <div class="console_code_copy" title="Copy to clipboard"></div>
# <pre class="programlisting prettyprint lang-console default has-python has-ruby has-js">GET /my-index-000001/_search?scroll=1m
# {
#   "slice": {
#     "field": "@timestamp",
#     "id": 0,
#     "max": 10
#   },
#   "query": {
#     "match": {
#       "message": "foo"
#     }
#   }
# }</pre>
# </div>
# <div class="console_widget has-python has-ruby has-js" data-snippet="snippets/140.console"></div>
# <p>For append only time-based indices, the <code class="literal">timestamp</code> field can be used safely.</p>
# </div>
# </div>
# </div><div class="navfooter">
# <span class="prev">
# <a href="sort-search-results.html">« Sort search results</a>
# </span>
# <span class="next">
# <a href="search-fields.html">Retrieve selected fields from a search »</a>
# </span>
# </div>
# <!-- end body -->
# </div>
# <div class="col-12 order-3 col-lg-2 order-lg-3 h-almost-full-lg sticky-top-lg" id="right_col">
# <div id="sticky_content">
# <!-- The OTP is appended here -->
# <div class="row">
# <div class="col-0 col-md-4 col-lg-0" id="bottom_left_col"></div>
# <div class="col-12 col-md-8 col-lg-12">
# <div id="rtpcontainer">
# <div class="mktg-promo" id="most-popular">
# <p class="aside-heading">Most Popular</p>
# <div class="pb-2">
# <p class="media-type">Video</p>
# <a href="https://www.elastic.co/webinars/getting-started-elasticsearch?page=docs&amp;placement=top-video">
# <p class="mb-0">Get Started with Elasticsearch</p>
# </a>
# </div>
# <div class="pb-2">
# <p class="media-type">Video</p>
# <a href="https://www.elastic.co/webinars/getting-started-kibana?page=docs&amp;placement=top-video">
# <p class="mb-0">Intro to Kibana</p>
# </a>
# </div>
# <div class="pb-2">
# <p class="media-type">Video</p>
# <a href="https://www.elastic.co/webinars/introduction-elk-stack?page=docs&amp;placement=top-video">
# <p class="mb-0">ELK for Logs &amp; Metrics</p>
# </a>
# </div>
# </div>
# </div>
# <!-- Feedback widget -->
# <div id="feedbackWidgetContainer"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# </div>
# <div id="elastic-footer"></div>
# <script src="https://www.elastic.co/elastic-footer.js"></script>
# <!-- Footer Section end-->
# </section>
# </div>
# <!-- Feedback modal -->
# <div id="feedbackModalContainer"></div>
# <script src="/guide/static/jquery.js"></script>
# <script src="/guide/static/docs-v1.js" type="text/javascript"></script>
# <script type="text/javascript">
#   window.initial_state = {"alternatives":{"console":{"php":{"hasAny":true},"python":{"hasAny":true},"ruby":{"hasAny":true},"go":{"hasAny":true},"js":{"hasAny":true}}}}</script>
# </body>
# </html>

# %%
main_content = soup.find(id="content")
main_content.contents

# soup2.text
# Out:
# ['\n',
#  <div class="content-wrapper">
#  <section id="guide" lang="en">
#  <div class="container-fluid">
#  <div class="row pb-3">
#  <div class="col-12 order-2 col-md-4 order-md-1 col-lg-3 h-almost-full-md sticky-top-md" id="left_col">
#  <!-- The TOC is appended here -->
#  </div>
#  <div class="col-12 order-1 col-md-8 order-md-2 col-lg-7 order-lg-2 guide-section" id="middle_col">
#  <!-- start body -->
#  <div class="navheader">
#  <span class="prev">
#  <a href="sort-search-results.html">« Sort search results</a>
#  </span>
#  <span class="next">
#  <a href="search-fields.html">Retrieve selected fields from a search »</a>
#  </span>
#  </div>
#  <div class="book" lang="en">
#  <div class="titlepage">
#  <div class="breadcrumbs">
#  <span class="breadcrumb-link"><a href="/guide/">Elastic Docs</a></span>
#  <span class="chevron-right">›</span><span class="breadcrumb-link"><a href="index.html">Elasticsearch Guide [8.15]</a></span>
#  <span class="chevron-right">›</span><span class="breadcrumb-link"><a href="search-with-elasticsearch.html">Search your data</a></span>
#  <span class="chevron-right">›</span><span class="breadcrumb-link"><a href="search-your-data.html">The search API</a></span>
#  </div>
#  <div>
#  <div><h1 class="title"><a id="id-1"></a>Paginate search results</h1><a class="edit_me" href="https://github.com/elastic/elasticsearch/edit/8.15/docs/reference/search/search-your-data/paginate-search-results.asciidoc" rel="nofollow" title="Edit this page on GitHub">edit</a></div>
#  </div>
#  <!--EXTRA-->
#  </div>
#  <div id="content">
#  <div class="section">
#  <div class="titlepage"><div><div>
#  <div class="position-relative"><h2 class="title"><a id="paginate-search-results"></a>Paginate search results</h2><a class="edit_me" href="https://github.com/elastic/elasticsearch/edit/8.15/docs/reference/search/search-your-data/paginate-search-results.asciidoc" rel="nofollow" title="Edit this page on GitHub">edit</a></div>
#  </div></div></div>
#  <p>By default, searches return the top 10 matching hits. To page through a larger
#  set of results, you can use the <a class="xref" href="search-search.html" title="Search API">search API</a>'s <code class="literal">from</code> and <code class="literal">size</code>
#  parameters. The <code class="literal">from</code> parameter defines the number of hits to skip, defaulting
#  to <code class="literal">0</code>. The <code class="literal">size</code> parameter is the maximum number of hits to return. Together,
#  these two parameters define a page of results.</p>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#      from_=5,
#      size=20,
#      query={
#          "match": {
#              "user.id": "kimchy"
#          }
#      },
#  )
#  print(resp)</pre>
#  </div>
#  <div class="pre_wrapper lang-ruby alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-ruby alternative">response = client.search(
#    body: {
#      from: 5,
#      size: 20,
#      query: {
#        match: {
#          'user.id' =&gt; 'kimchy'
#        }
#      }
#    }
#  )
#  puts response</pre>
#  </div>
#  <div class="pre_wrapper lang-go alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-go alternative">res, err := es.Search(
#  	es.Search.WithBody(strings.NewReader(`{
#  	  "from": 5,
#  	  "size": 20,
#  	  "query": {
#  	    "match": {
#  	      "user.id": "kimchy"
#  	    }
#  	  }
#  	}`)),
#  	es.Search.WithPretty(),
#  )
#  fmt.Println(res, err)</pre>
#  </div>
#  <div class="pre_wrapper lang-js alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#    from: 5,
#    size: 20,
#    query: {
#      match: {
#        "user.id": "kimchy",
#      },
#    },
#  });
#  console.log(response);</pre>
#  </div>
#  <a id="820f689eaaef15fc07abd1073fa880f8"></a>
#  <div class="pre_wrapper lang-console default has-python has-ruby has-go has-js">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console default has-python has-ruby has-go has-js">GET /_search
#  {
#    "from": 5,
#    "size": 20,
#    "query": {
#      "match": {
#        "user.id": "kimchy"
#      }
#    }
#  }</pre>
#  </div>
#  <div class="console_widget has-python has-ruby has-go has-js" data-snippet="snippets/123.console"></div>
#  <p>Avoid using <code class="literal">from</code> and <code class="literal">size</code> to page too deeply or request too many results at
#  once. Search requests usually span multiple shards. Each shard must load its
#  requested hits and the hits for any previous pages into memory. For deep pages
#  or large sets of results, these operations can significantly increase memory and
#  CPU usage, resulting in degraded performance or node failures.</p>
#  <p>By default, you cannot use <code class="literal">from</code> and <code class="literal">size</code> to page through more than 10,000
#  hits. This limit is a safeguard set by the
#  <a class="xref" href="index-modules.html#index-max-result-window"><code class="literal">index.max_result_window</code></a> index setting. If you need
#  to page through more than 10,000 hits, use the <a class="xref" href="paginate-search-results.html#search-after" title="Search after"><code class="literal">search_after</code></a>
#  parameter instead.</p>
#  <div class="warning admon">
#  <div class="icon"></div>
#  <div class="admon_content">
#  <p>Elasticsearch uses Lucene’s internal doc IDs as tie-breakers. These internal doc
#  IDs can be completely different across replicas of the same data. When paging
#  search hits, you might occasionally see that documents with the same sort values
#  are not ordered consistently.</p>
#  </div>
#  </div>
#  <div class="position-relative"><h3><a id="search-after"></a>Search after</h3><a class="edit_me" href="https://github.com/elastic/elasticsearch/edit/8.15/docs/reference/search/search-your-data/paginate-search-results.asciidoc" rel="nofollow" title="Edit this page on GitHub">edit</a></div>
#  <p>You can use the <code class="literal">search_after</code> parameter to retrieve the next page of hits
#  using a set of <a class="xref" href="sort-search-results.html" title="Sort search results">sort values</a> from the previous page.</p>
#  <p>Using <code class="literal">search_after</code> requires multiple search requests with the same <code class="literal">query</code> and
#  <code class="literal">sort</code> values. The first step is to run an initial request. The following
#  example sorts the results by two fields (<code class="literal">date</code> and <code class="literal">tie_breaker_id</code>):</p>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#      index="twitter",
#      query={
#          "match": {
#              "title": "elasticsearch"
#          }
#      },
#      sort=[
#          {
#              "date": "asc"
#          },
#          {
#              "tie_breaker_id": "asc"
#          }
#      ],
#  )
#  print(resp)</pre>
#  </div>
#  <div class="pre_wrapper lang-ruby alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-ruby alternative">response = client.search(
#    index: 'twitter',
#    body: {
#      query: {
#        match: {
#          title: 'elasticsearch'
#        }
#      },
#      sort: [
#        {
#          date: 'asc'
#        },
#        {
#          tie_breaker_id: 'asc'
#        }
#      ]
#    }
#  )
#  puts response</pre>
#  </div>
#  <div class="pre_wrapper lang-js alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#    index: "twitter",
#    query: {
#      match: {
#        title: "elasticsearch",
#      },
#    },
#    sort: [
#      {
#        date: "asc",
#      },
#      {
#        tie_breaker_id: "asc",
#      },
#    ],
#  });
#  console.log(response);</pre>
#  </div>
#  <a id="91750571c195718f0ff246e058e4bc63"></a>
#  <div class="pre_wrapper lang-console default has-python has-ruby has-js">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console default has-python has-ruby has-js">GET twitter/_search
#  {
#      "query": {
#          "match": {
#              "title": "elasticsearch"
#          }
#      },
#      "sort": [
#          {"date": "asc"},
#          {"tie_breaker_id": "asc"}      <a id="CO51-1"></a><i class="conum" data-value="1"></i>
#      ]
#  }</pre>
#  </div>
#  <div class="console_widget has-python has-ruby has-js" data-snippet="snippets/124.console"></div>
#  <div class="calloutlist default has-python has-ruby has-js lang-console">
#  <table border="0" summary="Callout list">
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO51-1"><i class="conum" data-value="1"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>A copy of the <code class="literal">_id</code> field with <code class="literal">doc_values</code> enabled</p>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <p>The search response includes an array of <code class="literal">sort</code> values for each hit:</p>
#  <a id="8a501f4a6e6de6ce8d467125400eabb8"></a>
#  <div class="pre_wrapper lang-console-result">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console-result">{
#    "took" : 17,
#    "timed_out" : false,
#    "_shards" : ...,
#    "hits" : {
#      "total" : ...,
#      "max_score" : null,
#      "hits" : [
#        ...
#        {
#          "_index" : "twitter",
#          "_id" : "654322",
#          "_score" : null,
#          "_source" : ...,
#          "sort" : [
#            1463538855,
#            "654322"
#          ]
#        },
#        {
#          "_index" : "twitter",
#          "_id" : "654323",
#          "_score" : null,
#          "_source" : ...,
#          "sort" : [                                <a id="CO52-1"></a><i class="conum" data-value="1"></i>
#            1463538857,
#            "654323"
#          ]
#        }
#      ]
#    }
#  }</pre>
#  </div>
#  <div class="calloutlist">
#  <table border="0" summary="Callout list">
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO52-1"><i class="conum" data-value="1"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>Sort values for the last returned hit.</p>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <p>To retrieve the next page of results, repeat the request, take the <code class="literal">sort</code> values from the
#  last hit, and insert those into the <code class="literal">search_after</code> array:</p>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#      index="twitter",
#      query={
#          "match": {
#              "title": "elasticsearch"
#          }
#      },
#      search_after=[
#          1463538857,
#          "654323"
#      ],
#      sort=[
#          {
#              "date": "asc"
#          },
#          {
#              "tie_breaker_id": "asc"
#          }
#      ],
#  )
#  print(resp)</pre>
#  </div>
#  <div class="pre_wrapper lang-ruby alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-ruby alternative">response = client.search(
#    index: 'twitter',
#    body: {
#      query: {
#        match: {
#          title: 'elasticsearch'
#        }
#      },
#      search_after: [
#        1_463_538_857,
#        '654323'
#      ],
#      sort: [
#        {
#          date: 'asc'
#        },
#        {
#          tie_breaker_id: 'asc'
#        }
#      ]
#    }
#  )
#  puts response</pre>
#  </div>
#  <div class="pre_wrapper lang-js alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#    index: "twitter",
#    query: {
#      match: {
#        title: "elasticsearch",
#      },
#    },
#    search_after: [1463538857, "654323"],
#    sort: [
#      {
#        date: "asc",
#      },
#      {
#        tie_breaker_id: "asc",
#      },
#    ],
#  });
#  console.log(response);</pre>
#  </div>
#  <a id="d851282dba548251d10db5954a339307"></a>
#  <div class="pre_wrapper lang-console default has-python has-ruby has-js">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console default has-python has-ruby has-js">GET twitter/_search
#  {
#      "query": {
#          "match": {
#              "title": "elasticsearch"
#          }
#      },
#      "search_after": [1463538857, "654323"],
#      "sort": [
#          {"date": "asc"},
#          {"tie_breaker_id": "asc"}
#      ]
#  }</pre>
#  </div>
#  <div class="console_widget has-python has-ruby has-js" data-snippet="snippets/125.console"></div>
#  <p>Repeat this process by updating the <code class="literal">search_after</code> array every time you retrieve a
#  new page of results. If a <a class="xref" href="near-real-time.html" title="Near real-time search">refresh</a> occurs between these requests,
#  the order of your results may change, causing inconsistent results across pages. To
#  prevent this, you can create a <a class="xref" href="point-in-time-api.html" title="Point in time API">point in time (PIT)</a> to
#  preserve the current index state over your searches.</p>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.open_point_in_time(
#      index="my-index-000001",
#      keep_alive="1m",
#  )
#  print(resp)</pre>
#  </div>
#  <div class="pre_wrapper lang-ruby alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-ruby alternative">response = client.open_point_in_time(
#    index: 'my-index-000001',
#    keep_alive: '1m'
#  )
#  puts response</pre>
#  </div>
#  <div class="pre_wrapper lang-js alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-js alternative">const response = await client.openPointInTime({
#    index: "my-index-000001",
#    keep_alive: "1m",
#  });
#  console.log(response);</pre>
#  </div>
#  <a id="5987afb2c17c73fe3d860937565ef115"></a>
#  <div class="pre_wrapper lang-console default has-python has-ruby has-js">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console default has-python has-ruby has-js">POST /my-index-000001/_pit?keep_alive=1m</pre>
#  </div>
#  <div class="console_widget has-python has-ruby has-js" data-snippet="snippets/126.console"></div>
#  <p>The API returns a PIT ID.</p>
#  <a id="0ff873f3acf223856340dabff57e4ce8"></a>
#  <div class="pre_wrapper lang-console-result">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console-result">{
#    "id": "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA=="
#  }</pre>
#  </div>
#  <p>To get the first page of results, submit a search request with a <code class="literal">sort</code>
#  argument. If using a PIT, specify the PIT ID in the <code class="literal">pit.id</code> parameter and omit
#  the target data stream or index from the request path.</p>
#  <div class="important admon">
#  <div class="icon"></div>
#  <div class="admon_content">
#  <p>All PIT search requests add an implicit sort tiebreaker field called <code class="literal">_shard_doc</code>,
#  which can also be provided explicitly.
#  If you cannot use a PIT, we recommend that you include a tiebreaker field
#  in your <code class="literal">sort</code>. This tiebreaker field should contain a unique value for each document.
#  If you don’t include a tiebreaker field, your paged results could miss or duplicate hits.</p>
#  </div>
#  </div>
#  <div class="note admon">
#  <div class="icon"></div>
#  <div class="admon_content">
#  <p>Search after requests have optimizations that make them faster when the sort
#  order is <code class="literal">_shard_doc</code> and total hits are not tracked. If you want to iterate over all documents regardless of the
#  order, this is the most efficient option.</p>
#  </div>
#  </div>
#  <div class="important admon">
#  <div class="icon"></div>
#  <div class="admon_content">
#  <p>If the <code class="literal">sort</code> field is a <a class="xref" href="date.html" title="Date field type"><code class="literal">date</code></a> in some target data streams or indices
#  but a <a class="xref" href="date_nanos.html" title="Date nanoseconds field type"><code class="literal">date_nanos</code></a> field in other targets, use the <code class="literal">numeric_type</code> parameter
#  to convert the values to a single resolution and the <code class="literal">format</code> parameter to specify a
#  <a class="xref" href="mapping-date-format.html" title="format">date format</a> for the <code class="literal">sort</code> field. Otherwise, Elasticsearch won’t interpret
#  the search after parameter correctly in each request.</p>
#  </div>
#  </div>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#      size=10000,
#      query={
#          "match": {
#              "user.id": "elkbee"
#          }
#      },
#      pit={
#          "id": "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
#          "keep_alive": "1m"
#      },
#      sort=[
#          {
#              "@timestamp": {
#                  "order": "asc",
#                  "format": "strict_date_optional_time_nanos",
#                  "numeric_type": "date_nanos"
#              }
#          }
#      ],
#  )
#  print(resp)</pre>
#  </div>
#  <div class="pre_wrapper lang-js alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#    size: 10000,
#    query: {
#      match: {
#        "user.id": "elkbee",
#      },
#    },
#    pit: {
#      id: "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
#      keep_alive: "1m",
#    },
#    sort: [
#      {
#        "@timestamp": {
#          order: "asc",
#          format: "strict_date_optional_time_nanos",
#          numeric_type: "date_nanos",
#        },
#      },
#    ],
#  });
#  console.log(response);</pre>
#  </div>
#  <a id="47909e194d10743093f4a22c27a85925"></a>
#  <div class="pre_wrapper lang-console default has-python has-js">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console default has-python has-js">GET /_search
#  {
#    "size": 10000,
#    "query": {
#      "match" : {
#        "user.id" : "elkbee"
#      }
#    },
#    "pit": {
#      "id":  "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==", <a id="CO53-1"></a><i class="conum" data-value="1"></i>
#      "keep_alive": "1m"
#    },
#    "sort": [ <a id="CO53-2"></a><i class="conum" data-value="2"></i>
#      {"@timestamp": {"order": "asc", "format": "strict_date_optional_time_nanos", "numeric_type" : "date_nanos" }}
#    ]
#  }</pre>
#  </div>
#  <div class="console_widget has-python has-js" data-snippet="snippets/127.console"></div>
#  <div class="calloutlist default has-python has-js lang-console">
#  <table border="0" summary="Callout list">
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO53-1"><i class="conum" data-value="1"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>PIT ID for the search.</p>
#  </td>
#  </tr>
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO53-2"><i class="conum" data-value="2"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>Sorts hits for the search with an implicit tiebreak on <code class="literal">_shard_doc</code> ascending.</p>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <p>The search response includes an array of <code class="literal">sort</code> values for each hit. If you used
#  a PIT, a tiebreaker is included as the last <code class="literal">sort</code> values for each hit.
#  This tiebreaker called <code class="literal">_shard_doc</code> is added automatically on every search requests that use a PIT.
#  The <code class="literal">_shard_doc</code> value is the combination of the shard index within the PIT and the Lucene’s internal doc ID,
#  it is unique per document and constant within a PIT.
#  You can also add the tiebreaker explicitly in the search request to customize the order:</p>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#      size=10000,
#      query={
#          "match": {
#              "user.id": "elkbee"
#          }
#      },
#      pit={
#          "id": "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
#          "keep_alive": "1m"
#      },
#      sort=[
#          {
#              "@timestamp": {
#                  "order": "asc",
#                  "format": "strict_date_optional_time_nanos"
#              }
#          },
#          {
#              "_shard_doc": "desc"
#          }
#      ],
#  )
#  print(resp)</pre>
#  </div>
#  <div class="pre_wrapper lang-js alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#    size: 10000,
#    query: {
#      match: {
#        "user.id": "elkbee",
#      },
#    },
#    pit: {
#      id: "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
#      keep_alive: "1m",
#    },
#    sort: [
#      {
#        "@timestamp": {
#          order: "asc",
#          format: "strict_date_optional_time_nanos",
#        },
#      },
#      {
#        _shard_doc: "desc",
#      },
#    ],
#  });
#  console.log(response);</pre>
#  </div>
#  <a id="4e50d9d25bfb07ac73e3a2be5d2fbbf7"></a>
#  <div class="pre_wrapper lang-console default has-python has-js">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console default has-python has-js">GET /_search
#  {
#    "size": 10000,
#    "query": {
#      "match" : {
#        "user.id" : "elkbee"
#      }
#    },
#    "pit": {
#      "id":  "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==", <a id="CO54-1"></a><i class="conum" data-value="1"></i>
#      "keep_alive": "1m"
#    },
#    "sort": [ <a id="CO54-2"></a><i class="conum" data-value="2"></i>
#      {"@timestamp": {"order": "asc", "format": "strict_date_optional_time_nanos"}},
#      {"_shard_doc": "desc"}
#    ]
#  }</pre>
#  </div>
#  <div class="console_widget has-python has-js" data-snippet="snippets/128.console"></div>
#  <div class="calloutlist default has-python has-js lang-console">
#  <table border="0" summary="Callout list">
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO54-1"><i class="conum" data-value="1"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>PIT ID for the search.</p>
#  </td>
#  </tr>
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO54-2"><i class="conum" data-value="2"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>Sorts hits for the search with an explicit tiebreak on <code class="literal">_shard_doc</code> descending.</p>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <a id="2938ccebfbc8550cc49016a68d8ef032"></a>
#  <div class="pre_wrapper lang-console-result">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console-result">{
#    "pit_id" : "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==", <a id="CO55-1"></a><i class="conum" data-value="1"></i>
#    "took" : 17,
#    "timed_out" : false,
#    "_shards" : ...,
#    "hits" : {
#      "total" : ...,
#      "max_score" : null,
#      "hits" : [
#        ...
#        {
#          "_index" : "my-index-000001",
#          "_id" : "FaslK3QBySSL_rrj9zM5",
#          "_score" : null,
#          "_source" : ...,
#          "sort" : [                                <a id="CO55-2"></a><i class="conum" data-value="2"></i>
#            "2021-05-20T05:30:04.832Z",
#            4294967298                              <a id="CO55-3"></a><i class="conum" data-value="3"></i>
#          ]
#        }
#      ]
#    }
#  }</pre>
#  </div>
#  <div class="calloutlist">
#  <table border="0" summary="Callout list">
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO55-1"><i class="conum" data-value="1"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>Updated <code class="literal">id</code> for the point in time.</p>
#  </td>
#  </tr>
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO55-2"><i class="conum" data-value="2"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>Sort values for the last returned hit.</p>
#  </td>
#  </tr>
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO55-3"><i class="conum" data-value="3"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>The tiebreaker value, unique per document within the <code class="literal">pit_id</code>.</p>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <p>To get the next page of results, rerun the previous search using the last hit’s
#  sort values (including the tiebreaker) as the <code class="literal">search_after</code> argument. If using a PIT, use the latest PIT
#  ID in the <code class="literal">pit.id</code> parameter. The search’s <code class="literal">query</code> and <code class="literal">sort</code> arguments must
#  remain unchanged. If provided, the <code class="literal">from</code> argument must be <code class="literal">0</code> (default) or <code class="literal">-1</code>.</p>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#      size=10000,
#      query={
#          "match": {
#              "user.id": "elkbee"
#          }
#      },
#      pit={
#          "id": "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
#          "keep_alive": "1m"
#      },
#      sort=[
#          {
#              "@timestamp": {
#                  "order": "asc",
#                  "format": "strict_date_optional_time_nanos"
#              }
#          }
#      ],
#      search_after=[
#          "2021-05-20T05:30:04.832Z",
#          4294967298
#      ],
#      track_total_hits=False,
#  )
#  print(resp)</pre>
#  </div>
#  <div class="pre_wrapper lang-js alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#    size: 10000,
#    query: {
#      match: {
#        "user.id": "elkbee",
#      },
#    },
#    pit: {
#      id: "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
#      keep_alive: "1m",
#    },
#    sort: [
#      {
#        "@timestamp": {
#          order: "asc",
#          format: "strict_date_optional_time_nanos",
#        },
#      },
#    ],
#    search_after: ["2021-05-20T05:30:04.832Z", 4294967298],
#    track_total_hits: false,
#  });
#  console.log(response);</pre>
#  </div>
#  <a id="7846974b47a3eab1832a475663d23ad9"></a>
#  <div class="pre_wrapper lang-console default has-python has-js">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console default has-python has-js">GET /_search
#  {
#    "size": 10000,
#    "query": {
#      "match" : {
#        "user.id" : "elkbee"
#      }
#    },
#    "pit": {
#      "id":  "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==", <a id="CO56-1"></a><i class="conum" data-value="1"></i>
#      "keep_alive": "1m"
#    },
#    "sort": [
#      {"@timestamp": {"order": "asc", "format": "strict_date_optional_time_nanos"}}
#    ],
#    "search_after": [                                <a id="CO56-2"></a><i class="conum" data-value="2"></i>
#      "2021-05-20T05:30:04.832Z",
#      4294967298
#    ],
#    "track_total_hits": false                        <a id="CO56-3"></a><i class="conum" data-value="3"></i>
#  }</pre>
#  </div>
#  <div class="console_widget has-python has-js" data-snippet="snippets/129.console"></div>
#  <div class="calloutlist default has-python has-js lang-console">
#  <table border="0" summary="Callout list">
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO56-1"><i class="conum" data-value="1"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>PIT ID returned by the previous search.</p>
#  </td>
#  </tr>
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO56-2"><i class="conum" data-value="2"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>Sort values from the previous search’s last hit.</p>
#  </td>
#  </tr>
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO56-3"><i class="conum" data-value="3"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>Disable the tracking of total hits to speed up pagination.</p>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <p>You can repeat this process to get additional pages of results. If using a PIT,
#  you can extend the PIT’s retention period using the
#  <code class="literal">keep_alive</code> parameter of each search request.</p>
#  <p>When you’re finished, you should delete your PIT.</p>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.close_point_in_time(
#      id="46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
#  )
#  print(resp)</pre>
#  </div>
#  <div class="pre_wrapper lang-ruby alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-ruby alternative">response = client.close_point_in_time(
#    body: {
#      id: '46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA=='
#    }
#  )
#  puts response</pre>
#  </div>
#  <div class="pre_wrapper lang-js alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-js alternative">const response = await client.closePointInTime({
#    id: "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA==",
#  });
#  console.log(response);</pre>
#  </div>
#  <a id="9ff9b2a73419a6c82f17a358b4991499"></a>
#  <div class="pre_wrapper lang-console default has-python has-ruby has-js">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console default has-python has-ruby has-js">DELETE /_pit
#  {
#      "id" : "46ToAwMDaWR5BXV1aWQyKwZub2RlXzMAAAAAAAAAACoBYwADaWR4BXV1aWQxAgZub2RlXzEAAAAAAAAAAAEBYQADaWR5BXV1aWQyKgZub2RlXzIAAAAAAAAAAAwBYgACBXV1aWQyAAAFdXVpZDEAAQltYXRjaF9hbGw_gAAAAA=="
#  }</pre>
#  </div>
#  <div class="console_widget has-python has-ruby has-js" data-snippet="snippets/130.console"></div>
#  <div class="position-relative"><h3><a id="scroll-search-results"></a>Scroll search results</h3><a class="edit_me" href="https://github.com/elastic/elasticsearch/edit/8.15/docs/reference/search/search-your-data/paginate-search-results.asciidoc" rel="nofollow" title="Edit this page on GitHub">edit</a></div>
#  <div class="important admon">
#  <div class="icon"></div>
#  <div class="admon_content">
#  <p>We no longer recommend using the scroll API for deep pagination. If
#  you need to preserve the index state while paging through more than 10,000 hits,
#  use the <a class="xref" href="paginate-search-results.html#search-after" title="Search after"><code class="literal">search_after</code></a> parameter with a point in time (PIT).</p>
#  </div>
#  </div>
#  <p>While a <code class="literal">search</code> request returns a single “page” of results, the <code class="literal">scroll</code>
#  API can be used to retrieve large numbers of results (or even all results)
#  from a single search request, in much the same way as you would use a cursor
#  on a traditional database.</p>
#  <p>Scrolling is not intended for real time user requests, but rather for
#  processing large amounts of data, e.g. in order to reindex the contents of one
#  data stream or index into a new data stream or index with a different
#  configuration.</p>
#  <div class="sidebar">
#  <div class="titlepage"><div><div>
#  <p class="title"><strong>Client support for scrolling and reindexing</strong></p>
#  </div></div></div>
#  <p>Some of the officially supported clients provide helpers to assist with
#  scrolled searches and reindexing:</p>
#  <div class="variablelist">
#  <dl class="variablelist">
#  <dt>
#  <span class="term">
#  Perl
#  </span>
#  </dt>
#  <dd>
#  See <a class="ulink" href="https://metacpan.org/pod/Search::Elasticsearch::Client::5_0::Bulk" target="_top">Search::Elasticsearch::Client::5_0::Bulk</a>
#  and <a class="ulink" href="https://metacpan.org/pod/Search::Elasticsearch::Client::5_0::Scroll" target="_top">Search::Elasticsearch::Client::5_0::Scroll</a>
#  </dd>
#  <dt>
#  <span class="term">
#  Python
#  </span>
#  </dt>
#  <dd>
#  See <a class="ulink" href="https://elasticsearch-py.readthedocs.io/en/stable/helpers.html" target="_top">elasticsearch.helpers.*</a>
#  </dd>
#  <dt>
#  <span class="term">
#  JavaScript
#  </span>
#  </dt>
#  <dd>
#  See <a class="ulink" href="/guide/en/elasticsearch/client/javascript-api/current/client-helpers.html" target="_top">client.helpers.*</a>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="note admon">
#  <div class="icon"></div>
#  <div class="admon_content">
#  <p>The results that are returned from a scroll request reflect the state of
#  the data stream or index at the time that the initial <code class="literal">search</code> request was made, like a
#  snapshot in time. Subsequent changes to documents (index, update or delete)
#  will only affect later search requests.</p>
#  </div>
#  </div>
#  <p>In order to use scrolling, the initial search request should specify the
#  <code class="literal">scroll</code> parameter in the query string, which tells Elasticsearch how long it
#  should keep the “search context” alive (see <a class="xref" href="paginate-search-results.html#scroll-search-context" title="Keeping the search context alive">Keeping the search context alive</a>), eg <code class="literal">?scroll=1m</code>.</p>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#      index="my-index-000001",
#      scroll="1m",
#      size=100,
#      query={
#          "match": {
#              "message": "foo"
#          }
#      },
#  )
#  print(resp)</pre>
#  </div>
#  <div class="pre_wrapper lang-ruby alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-ruby alternative">response = client.search(
#    index: 'my-index-000001',
#    scroll: '1m',
#    body: {
#      size: 100,
#      query: {
#        match: {
#          message: 'foo'
#        }
#      }
#    }
#  )
#  puts response</pre>
#  </div>
#  <div class="pre_wrapper lang-js alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#    index: "my-index-000001",
#    scroll: "1m",
#    size: 100,
#    query: {
#      match: {
#        message: "foo",
#      },
#    },
#  });
#  console.log(response);</pre>
#  </div>
#  <a id="24f4dfdf9922d5aa79151675b7767742"></a>
#  <div class="pre_wrapper lang-console default has-python has-ruby has-js">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console default has-python has-ruby has-js">POST /my-index-000001/_search?scroll=1m
#  {
#    "size": 100,
#    "query": {
#      "match": {
#        "message": "foo"
#      }
#    }
#  }</pre>
#  </div>
#  <div class="console_widget has-python has-ruby has-js" data-snippet="snippets/131.console"></div>
#  <p>The result from the above request includes a <code class="literal">_scroll_id</code>, which should
#  be passed to the <code class="literal">scroll</code> API in order to retrieve the next batch of
#  results.</p>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.scroll(
#      scroll="1m",
#      scroll_id="DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==",
#  )
#  print(resp)</pre>
#  </div>
#  <div class="pre_wrapper lang-go alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-go alternative">res, err := es.Scroll(
#  	es.Scroll.WithBody(strings.NewReader(`{
#  	  "scroll": "1m",
#  	  "scroll_id": "DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ=="
#  	}`)),
#  	es.Scroll.WithPretty(),
#  )
#  fmt.Println(res, err)</pre>
#  </div>
#  <div class="pre_wrapper lang-js alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-js alternative">const response = await client.scroll({
#    scroll: "1m",
#    scroll_id: "DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==",
#  });
#  console.log(response);</pre>
#  </div>
#  <a id="add240aa149d8b11139947502b279ee0"></a>
#  <div class="pre_wrapper lang-console default has-python has-go has-js">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console default has-python has-go has-js">POST /_search/scroll                                                               <a id="CO57-1"></a><i class="conum" data-value="1"></i>
#  {
#    "scroll" : "1m",                                                                 <a id="CO57-2"></a><i class="conum" data-value="2"></i>
#    "scroll_id" : "DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==" <a id="CO57-3"></a><i class="conum" data-value="3"></i>
#  }</pre>
#  </div>
#  <div class="console_widget has-python has-go has-js" data-snippet="snippets/132.console"></div>
#  <div class="calloutlist default has-python has-go has-js lang-console">
#  <table border="0" summary="Callout list">
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO57-1"><i class="conum" data-value="1"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p><code class="literal">GET</code> or <code class="literal">POST</code> can be used and the URL should not include the <code class="literal">index</code>
#  name — this is specified in the original <code class="literal">search</code> request instead.</p>
#  </td>
#  </tr>
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO57-2"><i class="conum" data-value="2"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>The <code class="literal">scroll</code> parameter tells Elasticsearch to keep the search context open
#  for another <code class="literal">1m</code>.</p>
#  </td>
#  </tr>
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO57-3"><i class="conum" data-value="3"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>The <code class="literal">scroll_id</code> parameter</p>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <p>The <code class="literal">size</code> parameter allows you to configure the maximum number of hits to be
#  returned with each batch of results. Each call to the <code class="literal">scroll</code> API returns the
#  next batch of results until there are no more results left to return, ie the
#  <code class="literal">hits</code> array is empty.</p>
#  <div class="important admon">
#  <div class="icon"></div>
#  <div class="admon_content">
#  <p>The initial search request and each subsequent scroll request each
#  return a <code class="literal">_scroll_id</code>. While the <code class="literal">_scroll_id</code> may change between requests, it doesn’t
#  always change — in any case, only the most recently received <code class="literal">_scroll_id</code> should be used.</p>
#  </div>
#  </div>
#  <div class="note admon">
#  <div class="icon"></div>
#  <div class="admon_content">
#  <p>If the request specifies aggregations, only the initial search response
#  will contain the aggregations results.</p>
#  </div>
#  </div>
#  <div class="note admon">
#  <div class="icon"></div>
#  <div class="admon_content">
#  <p>Scroll requests have optimizations that make them faster when the sort
#  order is <code class="literal">_doc</code>. If you want to iterate over all documents regardless of the
#  order, this is the most efficient option:</p>
#  </div>
#  </div>
#  <div class="pre_wrapper lang-php alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-php alternative">$params = [
#      'body' =&gt; [
#          'sort' =&gt; [
#              '_doc',
#          ],
#      ],
#  ];
#  $response = $client-&gt;search($params);</pre>
#  </div>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#      scroll="1m",
#      sort=[
#          "_doc"
#      ],
#  )
#  print(resp)</pre>
#  </div>
#  <div class="pre_wrapper lang-ruby alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-ruby alternative">response = client.search(
#    scroll: '1m',
#    body: {
#      sort: [
#        '_doc'
#      ]
#    }
#  )
#  puts response</pre>
#  </div>
#  <div class="pre_wrapper lang-go alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-go alternative">res, err := es.Search(
#  	es.Search.WithBody(strings.NewReader(`{
#  	  "sort": [
#  	    "_doc"
#  	  ]
#  	}`)),
#  	es.Search.WithScroll(time.Duration(60000000000)),
#  	es.Search.WithPretty(),
#  )
#  fmt.Println(res, err)</pre>
#  </div>
#  <div class="pre_wrapper lang-js alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#    scroll: "1m",
#    sort: ["_doc"],
#  });
#  console.log(response);</pre>
#  </div>
#  <a id="d5dcddc6398b473b6ad9bce5c6adf986"></a>
#  <div class="pre_wrapper lang-console default has-php has-python has-ruby has-go has-js">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console default has-php has-python has-ruby has-go has-js">GET /_search?scroll=1m
#  {
#    "sort": [
#      "_doc"
#    ]
#  }</pre>
#  </div>
#  <div class="console_widget has-php has-python has-ruby has-go has-js" data-snippet="snippets/133.console"></div>
#  <div class="position-relative"><h4><a id="scroll-search-context"></a>Keeping the search context alive</h4><a class="edit_me" href="https://github.com/elastic/elasticsearch/edit/8.15/docs/reference/search/search-your-data/paginate-search-results.asciidoc" rel="nofollow" title="Edit this page on GitHub">edit</a></div>
#  <p>A scroll returns all the documents which matched the search at the time of the
#  initial search request. It ignores any subsequent changes to these documents.
#  The <code class="literal">scroll_id</code> identifies a <em>search context</em> which keeps track of everything
#  that Elasticsearch needs to return the correct documents. The search context is created
#  by the initial request and kept alive by subsequent requests.</p>
#  <p>The <code class="literal">scroll</code> parameter (passed to the <code class="literal">search</code> request and to every <code class="literal">scroll</code>
#  request) tells Elasticsearch how long it should keep the search context alive.
#  Its value (e.g. <code class="literal">1m</code>, see <a class="xref" href="api-conventions.html#time-units" title="Time units">Time units</a>) does not need to be long enough to
#  process all data — it just needs to be long enough to process the previous
#  batch of results. Each <code class="literal">scroll</code> request (with the <code class="literal">scroll</code> parameter) sets a
#  new expiry time. If a <code class="literal">scroll</code> request doesn’t pass in the <code class="literal">scroll</code>
#  parameter, then the search context will be freed as part of <em>that</em> <code class="literal">scroll</code>
#  request.</p>
#  <p>Normally, the background merge process optimizes the index by merging together
#  smaller segments to create new, bigger segments. Once the smaller segments are
#  no longer needed they are deleted. This process continues during scrolling, but
#  an open search context prevents the old segments from being deleted since they
#  are still in use.</p>
#  <div class="tip admon">
#  <div class="icon"></div>
#  <div class="admon_content">
#  <p>Keeping older segments alive means that more disk space and file handles
#  are needed. Ensure that you have configured your nodes to have ample free file
#  handles. See <a class="xref" href="file-descriptors.html" title="File Descriptors">File Descriptors</a>.</p>
#  </div>
#  </div>
#  <p>Additionally, if a segment contains deleted or updated documents then the
#  search context must keep track of whether each document in the segment was live
#  at the time of the initial search request. Ensure that your nodes have
#  sufficient heap space if you have many open scrolls on an index that is subject
#  to ongoing deletes or updates.</p>
#  <div class="note admon">
#  <div class="icon"></div>
#  <div class="admon_content">
#  <p>To prevent against issues caused by having too many scrolls open, the
#  user is not allowed to open scrolls past a certain limit. By default, the
#  maximum number of open scrolls is 500. This limit can be updated with the
#  <code class="literal">search.max_open_scroll_context</code> cluster setting.</p>
#  </div>
#  </div>
#  <p>You can check how many search contexts are open with the
#  <a class="xref" href="cluster-nodes-stats.html" title="Nodes stats API">nodes stats API</a>:</p>
#  <div class="pre_wrapper lang-php alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-php alternative">$params = [
#      'metric' =&gt; 'indices',
#      'index_metric' =&gt; 'search',
#  ];
#  $response = $client-&gt;nodes()-&gt;stats($params);</pre>
#  </div>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.nodes.stats(
#      metric="indices",
#      index_metric="search",
#  )
#  print(resp)</pre>
#  </div>
#  <div class="pre_wrapper lang-ruby alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-ruby alternative">response = client.nodes.stats(
#    metric: 'indices',
#    index_metric: 'search'
#  )
# ...
#  {
#    "scroll_id" : [
#      "DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==",
#      "DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAAABFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAAAxZrUllkUVlCa1NqNmRMaUhiQlZkMWFBAAAAAAAAAAIWa1JZZFFZQmtTajZkTGlIYkJWZDFhQQAAAAAAAAAFFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAABBZrUllkUVlCa1NqNmRMaUhiQlZkMWFB"
#    ]
#  }</pre>
#  </div>
#  <div class="console_widget has-python has-ruby has-go has-js" data-snippet="snippets/136.console"></div>
#  <p>All search contexts can be cleared with the <code class="literal">_all</code> parameter:</p>
#  <div class="pre_wrapper lang-php alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-php alternative">$params = [
#      'scroll_id' =&gt; '_all',
#  ];
#  $response = $client-&gt;clearScroll($params);</pre>
#  </div>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.clear_scroll(
#      scroll_id="_all",
#  )
#  print(resp)</pre>
#  </div>
#  <div class="pre_wrapper lang-ruby alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-ruby alternative">response = client.clear_scroll(
#    scroll_id: '_all'
#  )
#  puts response</pre>
#  </div>
#  <div class="pre_wrapper lang-go alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-go alternative">res, err := es.ClearScroll(
#  	es.ClearScroll.WithScrollID("_all"),
#  )
#  fmt.Println(res, err)</pre>
#  </div>
#  <div class="pre_wrapper lang-js alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-js alternative">const response = await client.clearScroll({
#    scroll_id: "_all",
#  });
#  console.log(response);</pre>
#  </div>
#  <a id="c2c21e2824fbf6b7198ede30419da82b"></a>
#  <div class="pre_wrapper lang-console default has-php has-python has-ruby has-go has-js">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console default has-php has-python has-ruby has-go has-js">DELETE /_search/scroll/_all</pre>
#  </div>
#  <div class="console_widget has-php has-python has-ruby has-go has-js" data-snippet="snippets/137.console"></div>
#  <p>The <code class="literal">scroll_id</code> can also be passed as a query string parameter or in the request body.
#  Multiple scroll IDs can be passed as comma separated values:</p>
#  <div class="pre_wrapper lang-php alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-php alternative">$params = [
#      'scroll_id' =&gt; 'DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==,DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAAABFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAAAxZrUllkUVlCa1NqNmRMaUhiQlZkMWFBAAAAAAAAAAIWa1JZZFFZQmtTajZkTGlIYkJWZDFhQQAAAAAAAAAFFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAABBZrUllkUVlCa1NqNmRMaUhiQlZkMWFB',
#  ];
#  $response = $client-&gt;clearScroll($params);</pre>
#  </div>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.clear_scroll(
#      scroll_id="DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==,DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAAABFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAAAxZrUllkUVlCa1NqNmRMaUhiQlZkMWFBAAAAAAAAAAIWa1JZZFFZQmtTajZkTGlIYkJWZDFhQQAAAAAAAAAFFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAABBZrUllkUVlCa1NqNmRMaUhiQlZkMWFB",
#  )
#  print(resp)</pre>
#  </div>
#  <div class="pre_wrapper lang-ruby alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-ruby alternative">response = client.clear_scroll(
#    scroll_id: 'DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==,DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAAABFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAAAxZrUllkUVlCa1NqNmRMaUhiQlZkMWFBAAAAAAAAAAIWa1JZZFFZQmtTajZkTGlIYkJWZDFhQQAAAAAAAAAFFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAABBZrUllkUVlCa1NqNmRMaUhiQlZkMWFB'
#  )
#  puts response</pre>
#  </div>
#  <div class="pre_wrapper lang-go alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-go alternative">res, err := es.ClearScroll(
#  	es.ClearScroll.WithScrollID("DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==", "DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAAABFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAAAxZrUllkUVlCa1NqNmRMaUhiQlZkMWFBAAAAAAAAAAIWa1JZZFFZQmtTajZkTGlIYkJWZDFhQQAAAAAAAAAFFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAABBZrUllkUVlCa1NqNmRMaUhiQlZkMWFB"),
#  )
#  fmt.Println(res, err)</pre>
#  </div>
#  <div class="pre_wrapper lang-js alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-js alternative">const response = await client.clearScroll({
#    scroll_id:
#      "DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==,DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAAABFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAAAxZrUllkUVlCa1NqNmRMaUhiQlZkMWFBAAAAAAAAAAIWa1JZZFFZQmtTajZkTGlIYkJWZDFhQQAAAAAAAAAFFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAABBZrUllkUVlCa1NqNmRMaUhiQlZkMWFB",
#  });
#  console.log(response);</pre>
#  </div>
#  <a id="b94cee0f74f57742b3948f9b784dfdd4"></a>
#  <div class="pre_wrapper lang-console default has-php has-python has-ruby has-go has-js">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console default has-php has-python has-ruby has-go has-js">DELETE /_search/scroll/DXF1ZXJ5QW5kRmV0Y2gBAAAAAAAAAD4WYm9laVYtZndUQlNsdDcwakFMNjU1QQ==,DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAAABFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAAAxZrUllkUVlCa1NqNmRMaUhiQlZkMWFBAAAAAAAAAAIWa1JZZFFZQmtTajZkTGlIYkJWZDFhQQAAAAAAAAAFFmtSWWRRWUJrU2o2ZExpSGJCVmQxYUEAAAAAAAAABBZrUllkUVlCa1NqNmRMaUhiQlZkMWFB</pre>
#  </div>
#  <div class="console_widget has-php has-python has-ruby has-go has-js" data-snippet="snippets/138.console"></div>
#  <div class="position-relative"><h4><a id="slice-scroll"></a>Sliced scroll</h4><a class="edit_me" href="https://github.com/elastic/elasticsearch/edit/8.15/docs/reference/search/search-your-data/paginate-search-results.asciidoc" rel="nofollow" title="Edit this page on GitHub">edit</a></div>
#  <p>When paging through a large number of documents, it can be helpful to split the search into multiple slices
#  to consume them independently:</p>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#      index="my-index-000001",
#      scroll="1m",
#      slice={
#          "id": 0,
#          "max": 2
#      },
#      query={
#          "match": {
#              "message": "foo"
#          }
#      },
#  )
#  print(resp)
#
#  resp1 = client.search(
#      index="my-index-000001",
#      scroll="1m",
#      slice={
#          "id": 1,
#          "max": 2
#      },
#      query={
#          "match": {
#              "message": "foo"
#          }
#      },
#  )
#  print(resp1)</pre>
#  </div>
#  <div class="pre_wrapper lang-ruby alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-ruby alternative">response = client.search(
#    index: 'my-index-000001',
#    scroll: '1m',
#    body: {
#      slice: {
#        id: 0,
#        max: 2
#      },
#      query: {
#        match: {
#          message: 'foo'
#        }
#      }
#    }
#  )
#  puts response
#
#  response = client.search(
#    index: 'my-index-000001',
#    scroll: '1m',
#    body: {
#      slice: {
#        id: 1,
#        max: 2
#      },
#      query: {
#        match: {
#          message: 'foo'
#        }
#      }
#    }
#  )
#  puts response</pre>
#  </div>
#  <div class="pre_wrapper lang-js alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#    index: "my-index-000001",
#    scroll: "1m",
#    slice: {
#      id: 0,
#      max: 2,
#    },
#    query: {
#      match: {
#        message: "foo",
#      },
#    },
#  });
#  console.log(response);
#
#  const response1 = await client.search({
#    index: "my-index-000001",
#    scroll: "1m",
#    slice: {
#      id: 1,
#      max: 2,
#    },
#    query: {
#      match: {
#        message: "foo",
#      },
#    },
#  });
#  console.log(response1);</pre>
#  </div>
#  <a id="3758b8f2ab9f6f28a764ee6c42c85766"></a>
#  <div class="pre_wrapper lang-console default has-python has-ruby has-js">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console default has-python has-ruby has-js">GET /my-index-000001/_search?scroll=1m
#  {
#    "slice": {
#      "id": 0,                      <a id="CO58-1"></a><i class="conum" data-value="1"></i>
#      "max": 2                      <a id="CO58-2"></a><i class="conum" data-value="2"></i>
#    },
#    "query": {
#      "match": {
#        "message": "foo"
#      }
#    }
#  }
#  GET /my-index-000001/_search?scroll=1m
#  {
#    "slice": {
#      "id": 1,
#      "max": 2
#    },
#    "query": {
#      "match": {
#        "message": "foo"
#      }
#    }
#  }</pre>
#  </div>
#  <div class="console_widget has-python has-ruby has-js" data-snippet="snippets/139.console"></div>
#  <div class="calloutlist default has-python has-ruby has-js lang-console">
#  <table border="0" summary="Callout list">
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO58-1"><i class="conum" data-value="1"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>The id of the slice</p>
#  </td>
#  </tr>
#  <tr>
#  <td align="left" valign="top" width="5%">
#  <p><a href="#CO58-2"><i class="conum" data-value="2"></i></a></p>
#  </td>
#  <td align="left" valign="top">
#  <p>The maximum number of slices</p>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <p>The result from the first request returned documents that belong to the first slice (id: 0) and
#  the result from the second request returned documents that belong to the second slice. Since the
#  maximum number of slices is set to 2 the union of the results of the two requests is equivalent
#  to the results of a scroll query without slicing. By default the splitting is done first on the
#  shards, then locally on each shard using the <code class="literal">_id</code> field. The local splitting follows the formula
#  <code class="literal">slice(doc) = floorMod(hashCode(doc._id), max))</code>.</p>
#  <p>Each scroll is independent and can be processed in parallel like any scroll request.</p>
#  <div class="note admon">
#  <div class="icon"></div>
#  <div class="admon_content">
#  <p>If the number of slices is bigger than the number of shards the slice filter is very slow on
#  the first calls, it has a complexity of O(N) and a memory cost equals to N bits per slice where N
#  is the total number of documents in the shard. After few calls the filter should be cached and
#  subsequent calls should be faster but you should limit the number of sliced query you perform in
#  parallel to avoid the memory explosion.</p>
#  </div>
#  </div>
#  <p>The <a class="xref" href="point-in-time-api.html" title="Point in time API">point-in-time</a> API supports a more efficient partitioning strategy and
#  does not suffer from this problem. When possible, it’s recommended to use a point-in-time search
#  with slicing instead of a scroll.</p>
#  <p>Another way to avoid this high cost is to use the <code class="literal">doc_values</code> of another field to do the slicing.
#  The field must have the following properties:</p>
#  <div class="ulist itemizedlist">
#  <ul class="itemizedlist">
#  <li class="listitem">
#  The field is numeric.
#  </li>
#  <li class="listitem">
#  <code class="literal">doc_values</code> are enabled on that field
#  </li>
#  <li class="listitem">
#  Every document should contain a single value. If a document has multiple values for the specified field, the first value is used.
#  </li>
#  <li class="listitem">
#  The value for each document should be set once when the document is created and never updated. This ensures that each
#  slice gets deterministic results.
#  </li>
#  <li class="listitem">
#  The cardinality of the field should be high. This ensures that each slice gets approximately the same amount of documents.
#  </li>
#  </ul>
#  </div>
#  <div class="pre_wrapper lang-python alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-python alternative">resp = client.search(
#      index="my-index-000001",
#      scroll="1m",
#      slice={
#          "field": "@timestamp",
#          "id": 0,
#          "max": 10
#      },
#      query={
#          "match": {
#              "message": "foo"
#          }
#      },
#  )
#  print(resp)</pre>
#  </div>
#  <div class="pre_wrapper lang-ruby alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-ruby alternative">response = client.search(
#    index: 'my-index-000001',
#    scroll: '1m',
#    body: {
#      slice: {
#        field: '@timestamp',
#        id: 0,
#        max: 10
#      },
#      query: {
#        match: {
#          message: 'foo'
#        }
#      }
#    }
#  )
#  puts response</pre>
#  </div>
#  <div class="pre_wrapper lang-js alternative">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-js alternative">const response = await client.search({
#    index: "my-index-000001",
#    scroll: "1m",
#    slice: {
#      field: "@timestamp",
#      id: 0,
#      max: 10,
#    },
#    query: {
#      match: {
#        message: "foo",
#      },
#    },
#  });
#  console.log(response);</pre>
#  </div>
#  <a id="187733e50c60350f3f75921bea3b72c2"></a>
#  <div class="pre_wrapper lang-console default has-python has-ruby has-js">
#  <div class="console_code_copy" title="Copy to clipboard"></div>
#  <pre class="programlisting prettyprint lang-console default has-python has-ruby has-js">GET /my-index-000001/_search?scroll=1m
#  {
#    "slice": {
#      "field": "@timestamp",
#      "id": 0,
#      "max": 10
#    },
#    "query": {
#      "match": {
#        "message": "foo"
#      }
#    }
#  }</pre>
#  </div>
#  <div class="console_widget has-python has-ruby has-js" data-snippet="snippets/140.console"></div>
#  <p>For append only time-based indices, the <code class="literal">timestamp</code> field can be used safely.</p>
#  </div>
#  </div>
#  </div><div class="navfooter">
#  <span class="prev">
#  <a href="sort-search-results.html">« Sort search results</a>
#  </span>
#  <span class="next">
#  <a href="search-fields.html">Retrieve selected fields from a search »</a>
#  </span>
#  </div>
#  <!-- end body -->
#  </div>
#  <div class="col-12 order-3 col-lg-2 order-lg-3 h-almost-full-lg sticky-top-lg" id="right_col">
#  <div id="sticky_content">
#  <!-- The OTP is appended here -->
#  <div class="row">
#  <div class="col-0 col-md-4 col-lg-0" id="bottom_left_col"></div>
#  <div class="col-12 col-md-8 col-lg-12">
#  <div id="rtpcontainer">
#  <div class="mktg-promo" id="most-popular">
#  <p class="aside-heading">Most Popular</p>
#  <div class="pb-2">
#  <p class="media-type">Video</p>
#  <a href="https://www.elastic.co/webinars/getting-started-elasticsearch?page=docs&amp;placement=top-video">
#  <p class="mb-0">Get Started with Elasticsearch</p>
#  </a>
#  </div>
#  <div class="pb-2">
#  <p class="media-type">Video</p>
#  <a href="https://www.elastic.co/webinars/getting-started-kibana?page=docs&amp;placement=top-video">
#  <p class="mb-0">Intro to Kibana</p>
#  </a>
#  </div>
#  <div class="pb-2">
#  <p class="media-type">Video</p>
#  <a href="https://www.elastic.co/webinars/introduction-elk-stack?page=docs&amp;placement=top-video">
#  <p class="mb-0">ELK for Logs &amp; Metrics</p>
#  </a>
#  </div>
#  </div>
#  </div>
#  <!-- Feedback widget -->
#  <div id="feedbackWidgetContainer"></div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>
#  </div>,
#  '\n',
#  <div id="elastic-footer"></div>,
#  '\n',
#  <script src="https://www.elastic.co/elastic-footer.js"></script>,
#  '\n',
#  ' Footer Section end',
#  '\n']

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL and headers for the request
url = "https://www.elastic.co/guide/en/elasticsearch/reference/current/toc.html"
headers = {
    "sec-ch-ua-platform": "\"Windows\"",
    "Referer": "https://www.elastic.co/guide/en/elasticsearch/reference/current/search-with-elasticsearch.html",
    "sec-ch-ua": "\"Chromium\";v=\"130\", \"Google Chrome\";v=\"130\", \"Not?A_Brand\";v=\"99\"",
    "sec-ch-ua-mobile": "?0",
    "X-Requested-With": "XMLHttpRequest",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36",
    "Accept": "*/*",
    "DNT": "1"
}

# Fetch the TOC HTML content
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# Find all TOC links
toc_links = []
for link in soup.select(".toc a[href]"):
    title = link.get_text(strip=True)
    href = link["href"]
    toc_links.append((title, href))

# Display the TOC links
for title, href in toc_links:
    print(f"{title}: {href}")
# Out:
# Elasticsearch basics: elasticsearch-intro.html
# What is Elasticsearch?: elasticsearch-intro-what-is-es.html
# Run Elasticsearch: elasticsearch-intro-deploy.html
# Indices and documents: documents-indices.html
# Add data to Elasticsearch: es-ingestion-overview.html
# Search and analyze data: search-analyze.html
# Get ready for production: scalability.html
# Quick starts: quickstart.html
# Basics: Index and search using APIs: getting-started.html
# Basics: Full-text search and filtering: full-text-filter-tutorial.html
# Set up Elasticsearch: setup.html
# Run Elasticsearch locally: run-elasticsearch-locally.html
# Installing Elasticsearch: install-elasticsearch.html
# Install Elasticsearch from archive on Linux or MacOS: targz.html
# Install Elasticsearch with.zipon Windows: zip-windows.html
# Install Elasticsearch with Debian Package: deb.html
# Install Elasticsearch with RPM: rpm.html
# Install Elasticsearch with Docker: docker.html
# Configuring Elasticsearch: settings.html
# Important Elasticsearch configuration: important-settings.html
# Secure settings: secure-settings.html
# Auditing settings: auditing-settings.html
# Circuit breaker settings: circuit-breaker.html
# Cluster-level shard allocation and routing settings: modules-cluster.html
# Miscellaneous cluster settings: misc-cluster-settings.html
# Cross-cluster replication settings: ccr-settings.html
# Discovery and cluster formation settings: modules-discovery-settings.html
# Field data cache settings: modules-fielddata.html
# Health Diagnostic settings: health-diagnostic-settings.html
# Index lifecycle management settings: ilm-settings.html
# Data stream lifecycle settings: data-stream-lifecycle-settings.html
# Index management settings: index-management-settings.html
# Index recovery settings: recovery.html
# Indexing buffer settings: indexing-buffer.html
# License settings: license-settings.html
# Local gateway settings: modules-gateway.html
# Logging: logging.html
# Machine learning settings: ml-settings.html
# Inference settings: inference-settings.html
# Monitoring settings: monitoring-settings.html
# Nodes: modules-node.html
# Networking: modules-network.html
# Node query cache settings: query-cache.html
# Search settings: search-settings.html
# Security settings: security-settings.html
# Shard allocation, relocation, and recovery: shard-allocation-relocation-recovery.html
# Shard request cache settings: shard-request-cache.html
# Snapshot and restore settings: snapshot-settings.html
# Transforms settings: transform-settings.html
# Thread pools: modules-threadpool.html
# Watcher settings: notification-settings.html
# Advanced configuration: advanced-configuration.html
# Important system configuration: system-config.html
# Configuring system settings: setting-system-settings.html
# Disable swapping: setup-configuration-memory.html
# File Descriptors: file-descriptors.html
# Virtual memory: vm-max-map-count.html
# Number of threads: max-number-of-threads.html
# DNS cache settings: networkaddress-cache-ttl.html
# Ensure JNA temporary directory permits executables: executable-jna-tmpdir.html
# TCP retransmission timeout: system-config-tcpretries.html
# Bootstrap Checks: bootstrap-checks.html
# Heap size check: _heap_size_check.html
# File descriptor check: _file_descriptor_check.html
# Memory lock check: _memory_lock_check.html
# Maximum number of threads check: max-number-threads-check.html
# Max file size check: _max_file_size_check.html
# Maximum size virtual memory check: max-size-virtual-memory-check.html
# Maximum map count check: _maximum_map_count_check.html
# Client JVM check: _client_jvm_check.html
# Use serial collector check: _use_serial_collector_check.html
# System call filter check: _system_call_filter_check.html
# OnError and OnOutOfMemoryError checks: _onerror_and_onoutofmemoryerror_checks.html
# Early-access check: _early_access_check.html
# All permission check: _all_permission_check.html
# Discovery configuration check: _discovery_configuration_check.html
# Bootstrap Checks for X-Pack: bootstrap-checks-xpack.html
# Starting Elasticsearch: starting-elasticsearch.html
# Stopping Elasticsearch: stopping-elasticsearch.html
# Discovery and cluster formation: modules-discovery.html
# Discovery: discovery-hosts-providers.html
# Quorum-based decision making: modules-discovery-quorums.html
# Voting configurations: modules-discovery-voting.html
# Bootstrapping a cluster: modules-discovery-bootstrap-cluster.html
# Publishing the cluster state: cluster-state-publishing.html
# Cluster fault detection: cluster-fault-detection.html
# Add and remove nodes in your cluster: add-elasticsearch-nodes.html
# Full-cluster restart and rolling restart: restart-cluster.html
# Remote clusters: remote-clusters.html
# Add remote clusters using API key authentication: remote-clusters-api-key.html
# Add remote clusters using TLS certificate authentication: remote-clusters-cert.html
# Migrate from certificate to API key authentication: remote-clusters-migrate.html
# Remote cluster settings: remote-clusters-settings.html
# Troubleshooting: remote-clusters-troubleshooting.html
# Plugins: modules-plugins.html
# Search your data: search-with-elasticsearch.html
# The search API: search-your-data.html
# Sort search results: sort-search-results.html
# Paginate search results: paginate-search-results.html
# Retrieve selected fields: search-fields.html
# Search multiple data streams and indices: search-multiple-indices.html
# Collapse search results: collapse-search-results.html
# Filter search results: filter-search-results.html
# Highlighting: highlighting.html
# Long-running searches: async-search-intro.html
# Near real-time search: near-real-time.html
# Retrieve inner hits: inner-hits.html
# Search shard routing: search-shard-routing.html
# Searching with query rules: search-using-query-rules.html
# Search templates: search-template.html
# Retrievers: retrievers-overview.html
# kNN search: knn-search.html
# Semantic search: semantic-search.html
# Semantic search with `semantic_text`: semantic-search-semantic-text.html
# Hybrid search with `semantic_text`: semantic-text-hybrid-search.html
# Semantic search with the inference API: semantic-search-inference.html
# Semantic search with ELSER: semantic-search-elser.html
# Using Cohere with Elasticsearch: cohere-es.html
# Semantic search with deployed model: semantic-search-deployed-nlp-model.html
# Bring your own dense vectors: bring-your-own-vectors.html
# Search across clusters: modules-cross-cluster-search.html
# Search with synonyms: search-with-synonyms.html
# Search Applications: search-application-overview.html
# Search API and templates: search-application-api.html
# Security: search-application-security.html
# Search Application client guide: search-application-client.html
# Search analytics: behavioral-analytics-overview.html
# Get started: behavioral-analytics-start.html
# Set up CORs: behavioral-analytics-cors.html
# View events: behavioral-analytics-event.html
# Events reference: behavioral-analytics-event-reference.html
# API overview: behavioral-analytics-api.html
# Re-ranking: re-ranking-overview.html
# Semantic re-ranking: semantic-reranking.html
# Learning To Rank: learning-to-rank.html
# Deploy and manage LTR models: learning-to-rank-model-training.html
# Search using LTR: learning-to-rank-search-usage.html
# Index modules: index-modules.html
# Analysis: index-modules-analysis.html
# Index Shard Allocation: index-modules-allocation.html
# Index-level shard allocation filtering: shard-allocation-filtering.html
# Delaying allocation when a node leaves: delayed-allocation.html
# Index recovery prioritization: recovery-prioritization.html
# Total shards per node: allocation-total-shards.html
# Index-level data tier allocation filtering: data-tier-shard-filtering.html
# Index blocks: index-modules-blocks.html
# Mapper: index-modules-mapper.html
# Merge: index-modules-merge.html
# Similarity module: index-modules-similarity.html
# Slow Log: index-modules-slowlog.html
# Store: index-modules-store.html
# Preloading data into the file system cache: preload-data-to-file-system-cache.html
# Translog: index-modules-translog.html
# History retention: index-modules-history-retention.html
# Index Sorting: index-modules-index-sorting.html
# Use index sorting to speed up conjunctions: index-modules-index-sorting-conjunctions.html
# Indexing pressure: index-modules-indexing-pressure.html
# Index templates: index-templates.html
# Simulate multi-component templates: simulate-multi-component-templates.html
# Config ignore_missing_component_templates: ignore_missing_component_templates.html
# Usage example: _usage_example.html
# Aliases: aliases.html
# Mapping: mapping.html
# Dynamic mapping: dynamic-mapping.html
# Dynamic field mapping: dynamic-field-mapping.html
# Dynamic templates: dynamic-templates.html
# Explicit mapping: explicit-mapping.html
# Runtime fields: runtime.html
# Map a runtime field: runtime-mapping-fields.html
# Define runtime fields in a search request: runtime-search-request.html
# Override field values at query time: runtime-override-values.html
# Retrieve a runtime field: runtime-retrieving-fields.html
# Index a runtime field: runtime-indexed.html
# Explore your data with runtime fields: runtime-examples.html
# Field data types: mapping-types.html
# Aggregate metric: aggregate-metric-double.html
# Alias: field-alias.html
# Arrays: array.html
# Binary: binary.html
# Boolean: boolean.html
# Completion: completion.html
# Date: date.html
# Date nanoseconds: date_nanos.html
# Dense vector: dense-vector.html
# Flattened: flattened.html
# Geopoint: geo-point.html
# Geoshape: geo-shape.html
# Histogram: histogram.html
# IP: ip.html
# Join: parent-join.html
# Keyword: keyword.html
# Nested: nested.html
# Numeric: number.html
# Object: object.html
# Percolator: percolator.html
# Point: point.html
# Range: range.html
# Rank feature: rank-feature.html
# Rank features: rank-features.html
# Search-as-you-type: search-as-you-type.html
# Semantic text: semantic-text.html
# Shape: shape.html
# Sparse vector: sparse-vector.html
# Text: text.html
# Token count: token-count.html
# Unsigned long: unsigned-long.html
# Version: version.html
# Metadata fields: mapping-fields.html
# _doc_countfield: mapping-doc-count-field.html
# _field_namesfield: mapping-field-names-field.html
# _ignoredfield: mapping-ignored-field.html
# _idfield: mapping-id-field.html
# _indexfield: mapping-index-field.html
# _metafield: mapping-meta-field.html
# _routingfield: mapping-routing-field.html
# _sourcefield: mapping-source-field.html
# _tierfield: mapping-tier-field.html
# Mapping parameters: mapping-params.html
# analyzer: analyzer.html
# coerce: coerce.html
# copy_to: copy-to.html
# doc_values: doc-values.html
# dynamic: dynamic.html
# eager_global_ordinals: eager-global-ordinals.html
# enabled: enabled.html
# format: mapping-date-format.html
# ignore_above: ignore-above.html
# ignore_malformed: ignore-malformed.html
# index: mapping-index.html
# index_options: index-options.html
# index_phrases: index-phrases.html
# index_prefixes: index-prefixes.html
# meta: mapping-field-meta.html
# fields: multi-fields.html
# normalizer: normalizer.html
# norms: norms.html
# null_value: null-value.html
# position_increment_gap: position-increment-gap.html
# properties: properties.html
# search_analyzer: search-analyzer.html
# similarity: similarity.html
# store: mapping-store.html
# subobjects: subobjects.html
# term_vector: term-vector.html
# Mapping limit settings: mapping-settings-limit.html
# Removal of mapping types: removal-of-types.html
# Text analysis: analysis.html
# Overview: analysis-overview.html
# Concepts: analysis-concepts.html
# Anatomy of an analyzer: analyzer-anatomy.html
# Index and search analysis: analysis-index-search-time.html
# Stemming: stemming.html
# Token graphs: token-graphs.html
# Configure text analysis: configure-text-analysis.html
# Test an analyzer: test-analyzer.html
# Configuring built-in analyzers: configuring-analyzers.html
# Create a custom analyzer: analysis-custom-analyzer.html
# Specify an analyzer: specify-analyzer.html
# Built-in analyzer reference: analysis-analyzers.html
# Fingerprint: analysis-fingerprint-analyzer.html
# Keyword: analysis-keyword-analyzer.html
# Language: analysis-lang-analyzer.html
# Pattern: analysis-pattern-analyzer.html
# Simple: analysis-simple-analyzer.html
# Standard: analysis-standard-analyzer.html
# Stop: analysis-stop-analyzer.html
# Whitespace: analysis-whitespace-analyzer.html
# Tokenizer reference: analysis-tokenizers.html
# Character group: analysis-chargroup-tokenizer.html
# Classic: analysis-classic-tokenizer.html
# Edge n-gram: analysis-edgengram-tokenizer.html
# Keyword: analysis-keyword-tokenizer.html
# Letter: analysis-letter-tokenizer.html
# Lowercase: analysis-lowercase-tokenizer.html
# N-gram: analysis-ngram-tokenizer.html
# Path hierarchy: analysis-pathhierarchy-tokenizer.html
# Pattern: analysis-pattern-tokenizer.html
# Simple pattern: analysis-simplepattern-tokenizer.html
# Simple pattern split: analysis-simplepatternsplit-tokenizer.html
# Standard: analysis-standard-tokenizer.html
# Thai: analysis-thai-tokenizer.html
# UAX URL email: analysis-uaxurlemail-tokenizer.html
# Whitespace: analysis-whitespace-tokenizer.html
# Token filter reference: analysis-tokenfilters.html
# Apostrophe: analysis-apostrophe-tokenfilter.html
# ASCII folding: analysis-asciifolding-tokenfilter.html
# CJK bigram: analysis-cjk-bigram-tokenfilter.html
# CJK width: analysis-cjk-width-tokenfilter.html
# Classic: analysis-classic-tokenfilter.html
# Common grams: analysis-common-grams-tokenfilter.html
# Conditional: analysis-condition-tokenfilter.html
# Decimal digit: analysis-decimal-digit-tokenfilter.html
# Delimited payload: analysis-delimited-payload-tokenfilter.html
# Dictionary decompounder: analysis-dict-decomp-tokenfilter.html
# Edge n-gram: analysis-edgengram-tokenfilter.html
# Elision: analysis-elision-tokenfilter.html
# Fingerprint: analysis-fingerprint-tokenfilter.html
# Flatten graph: analysis-flatten-graph-tokenfilter.html
# Hunspell: analysis-hunspell-tokenfilter.html
# Hyphenation decompounder: analysis-hyp-decomp-tokenfilter.html
# Keep types: analysis-keep-types-tokenfilter.html
# Keep words: analysis-keep-words-tokenfilter.html
# Keyword marker: analysis-keyword-marker-tokenfilter.html
# Keyword repeat: analysis-keyword-repeat-tokenfilter.html
# KStem: analysis-kstem-tokenfilter.html
# Length: analysis-length-tokenfilter.html
# Limit token count: analysis-limit-token-count-tokenfilter.html
# Lowercase: analysis-lowercase-tokenfilter.html
# MinHash: analysis-minhash-tokenfilter.html
# Multiplexer: analysis-multiplexer-tokenfilter.html
# N-gram: analysis-ngram-tokenfilter.html
# Normalization: analysis-normalization-tokenfilter.html
# Pattern capture: analysis-pattern-capture-tokenfilter.html
# Pattern replace: analysis-pattern_replace-tokenfilter.html
# Phonetic: analysis-phonetic-tokenfilter.html
# Porter stem: analysis-porterstem-tokenfilter.html
# Predicate script: analysis-predicatefilter-tokenfilter.html
# Remove duplicates: analysis-remove-duplicates-tokenfilter.html
# Reverse: analysis-reverse-tokenfilter.html
# Shingle: analysis-shingle-tokenfilter.html
# Snowball: analysis-snowball-tokenfilter.html
# Stemmer: analysis-stemmer-tokenfilter.html
# Stemmer override: analysis-stemmer-override-tokenfilter.html
# Stop: analysis-stop-tokenfilter.html
# Synonym: analysis-synonym-tokenfilter.html
# Synonym graph: analysis-synonym-graph-tokenfilter.html
# Trim: analysis-trim-tokenfilter.html
# Truncate: analysis-truncate-tokenfilter.html
# Unique: analysis-unique-tokenfilter.html
# Uppercase: analysis-uppercase-tokenfilter.html
# Word delimiter: analysis-word-delimiter-tokenfilter.html
# Word delimiter graph: analysis-word-delimiter-graph-tokenfilter.html
# Character filters reference: analysis-charfilters.html
# HTML strip: analysis-htmlstrip-charfilter.html
# Mapping: analysis-mapping-charfilter.html
# Pattern replace: analysis-pattern-replace-charfilter.html
# Normalizers: analysis-normalizers.html
# Ingest pipelines: ingest.html
# Example: Parse logs: common-log-format-example.html
# Enrich your data: ingest-enriching-data.html
# Set up an enrich processor: enrich-setup.html
# Example: Enrich your data based on geolocation: geo-match-enrich-policy-type.html
# Example: Enrich your data based on exact values: match-enrich-policy-type.html
# Example: Enrich your data by matching a value to a range: range-enrich-policy-type.html
# Processor reference: processors.html
# Append: append-processor.html
# Attachment: attachment.html
# Bytes: bytes-processor.html
# Circle: ingest-circle-processor.html
# Community ID: community-id-processor.html
# Convert: convert-processor.html
# CSV: csv-processor.html
# Date: date-processor.html
# Date index name: date-index-name-processor.html
# Dissect: dissect-processor.html
# Dot expander: dot-expand-processor.html
# Drop: drop-processor.html
# Enrich: enrich-processor.html
# Fail: fail-processor.html
# Fingerprint: fingerprint-processor.html
# Foreach: foreach-processor.html
# Geo-grid: ingest-geo-grid-processor.html
# GeoIP: geoip-processor.html
# Grok: grok-processor.html
# Gsub: gsub-processor.html
# HTML strip: htmlstrip-processor.html
# Inference: inference-processor.html
# Join: join-processor.html
# JSON: json-processor.html
# KV: kv-processor.html
# Lowercase: lowercase-processor.html
# Network direction: network-direction-processor.html
# Pipeline: pipeline-processor.html
# Redact: redact-processor.html
# Registered domain: registered-domain-processor.html
# Remove: remove-processor.html
# Rename: rename-processor.html
# Reroute: reroute-processor.html
# Script: script-processor.html
# Set: set-processor.html
# Set security user: ingest-node-set-security-user-processor.html
# Sort: sort-processor.html
# Split: split-processor.html
# Trim: trim-processor.html
# Uppercase: uppercase-processor.html
# URL decode: urldecode-processor.html
# URI parts: uri-parts-processor.html
# User agent: user-agent-processor.html
# Ingest pipelines in Search: ingest-pipeline-search.html
# Inference processing: ingest-pipeline-search-inference.html
# NLP tutorial: nlp-example.html
# Data streams: data-streams.html
# Set up a data stream: set-up-a-data-stream.html
# Use a data stream: use-a-data-stream.html
# Modify a data stream: modify-data-streams.html
# Time series data stream (TSDS): tsds.html
# Set up a TSDS: set-up-tsds.html
# Time series index settings: tsds-index-settings.html
# Downsampling a time series data stream: downsampling.html
# Run downsampling with ILM: downsampling-ilm.html
# Run downsampling manually: downsampling-manual.html
# Reindex a TSDS: tsds-reindex.html
# Logs data stream: logs-data-stream.html
# Data stream lifecycle: data-stream-lifecycle.html
# Tutorial: Create a data stream with a lifecycle: tutorial-manage-new-data-stream.html
# Tutorial: Update existing data stream: tutorial-manage-existing-data-stream.html
# Tutorial: Migrate ILM managed data stream to data stream lifecycle: tutorial-migrate-data-stream-from-ilm-to-dsl.html
# Data management: data-management.html
# ILM: Manage the index lifecycle: index-lifecycle-management.html
# Tutorial: Customize built-in policies: example-using-index-lifecycle-policy.html
# Tutorial: Automate rollover: getting-started-index-lifecycle-management.html
# Index management in Kibana: index-mgmt.html
# Overview: overview-index-lifecycle-management.html
# Concepts: ilm-concepts.html
# Index lifecycle: ilm-index-lifecycle.html
# Rollover: index-rollover.html
# Policy updates: update-lifecycle-policy.html
# Index lifecycle actions: ilm-actions.html
# Allocate: ilm-allocate.html
# Delete: ilm-delete.html
# Force merge: ilm-forcemerge.html
# Migrate: ilm-migrate.html
# Read only: ilm-readonly.html
# Rollover: ilm-rollover.html
# Downsample: ilm-downsample.html
# Searchable snapshot: ilm-searchable-snapshot.html
# Set priority: ilm-set-priority.html
# Shrink: ilm-shrink.html
# Unfollow: ilm-unfollow.html
# Wait for snapshot: ilm-wait-for-snapshot.html
# Configure a lifecycle policy: set-up-lifecycle-policy.html
# Migrate index allocation filters to node roles: migrate-index-allocation-filters.html
# Troubleshooting index lifecycle management errors: index-lifecycle-error-handling.html
# Start and stop index lifecycle management: start-stop-ilm.html
# Manage existing indices: ilm-with-existing-indices.html
# Skip rollover: skipping-rollover.html
# Restore a managed data stream or index: index-lifecycle-and-snapshots.html
# Data tiers: data-tiers.html
# Roll up or transform your data: data-rollup-transform.html
# Rolling up historical data: xpack-rollup.html
# Overview: rollup-overview.html
# API quick reference: rollup-api-quickref.html
# Getting started: rollup-getting-started.html
# Understanding groups: rollup-understanding-groups.html
# Rollup aggregation limitations: rollup-agg-limitations.html
# Rollup search limitations: rollup-search-limitations.html
# Migrating to downsampling: rollup-migrating-to-downsampling.html
# Transforming data: transforms.html
# Overview: transform-overview.html
# Setup: transform-setup.html
# When to use transforms: transform-usage.html
# Generating alerts for transforms: transform-alerts.html
# Transforms at scale: transform-scale.html
# How checkpoints work: transform-checkpoints.html
# API quick reference: transform-api-quickref.html
# Tutorial: Transforming the eCommerce sample data: ecommerce-transforms.html
# Examples: transform-examples.html
# Painless examples: transform-painless-examples.html
# Limitations: transform-limitations.html
# Query DSL: query-dsl.html
# Query and filter context: query-filter-context.html
# Compound queries: compound-queries.html
# Boolean: query-dsl-bool-query.html
# Boosting: query-dsl-boosting-query.html
# Constant score: query-dsl-constant-score-query.html
# Disjunction max: query-dsl-dis-max-query.html
# Function score: query-dsl-function-score-query.html
# Full text queries: full-text-queries.html
# Intervals: query-dsl-intervals-query.html
# Match: query-dsl-match-query.html
# Match boolean prefix: query-dsl-match-bool-prefix-query.html
# Match phrase: query-dsl-match-query-phrase.html
# Match phrase prefix: query-dsl-match-query-phrase-prefix.html
# Combined fields: query-dsl-combined-fields-query.html
# Multi-match: query-dsl-multi-match-query.html
# Query string: query-dsl-query-string-query.html
# Simple query string: query-dsl-simple-query-string-query.html
# Geo queries: geo-queries.html
# Geo-bounding box: query-dsl-geo-bounding-box-query.html
# Geo-distance: query-dsl-geo-distance-query.html
# Geo-grid: query-dsl-geo-grid-query.html
# Geo-polygon: query-dsl-geo-polygon-query.html
# Geoshape: query-dsl-geo-shape-query.html
# Shape queries: shape-queries.html
# Shape: query-dsl-shape-query.html
# Joining queries: joining-queries.html
# Nested: query-dsl-nested-query.html
# Has child: query-dsl-has-child-query.html
# Has parent: query-dsl-has-parent-query.html
# Parent ID: query-dsl-parent-id-query.html
# Match all: query-dsl-match-all-query.html
# Span queries: span-queries.html
# Span containing: query-dsl-span-containing-query.html
# Span field masking: query-dsl-span-field-masking-query.html
# Span first: query-dsl-span-first-query.html
# Span multi-term: query-dsl-span-multi-term-query.html
# Span near: query-dsl-span-near-query.html
# Span not: query-dsl-span-not-query.html
# Span or: query-dsl-span-or-query.html
# Span term: query-dsl-span-term-query.html
# Span within: query-dsl-span-within-query.html
# Vector queries: vector-queries.html
# Knn: query-dsl-knn-query.html
# Sparse vector: query-dsl-sparse-vector-query.html
# Semantic: query-dsl-semantic-query.html
# Text expansion: query-dsl-text-expansion-query.html
# Weighted tokens: query-dsl-weighted-tokens-query.html
# Specialized queries: specialized-queries.html
# Distance feature: query-dsl-distance-feature-query.html
# More like this: query-dsl-mlt-query.html
# Percolate: query-dsl-percolate-query.html
# Rank feature: query-dsl-rank-feature-query.html
# Script: query-dsl-script-query.html
# Script score: query-dsl-script-score-query.html
# Wrapper: query-dsl-wrapper-query.html
# Pinned Query: query-dsl-pinned-query.html
# Rule: query-dsl-rule-query.html
# Term-level queries: term-level-queries.html
# Exists: query-dsl-exists-query.html
# Fuzzy: query-dsl-fuzzy-query.html
# IDs: query-dsl-ids-query.html
# Prefix: query-dsl-prefix-query.html
# Range: query-dsl-range-query.html
# Regexp: query-dsl-regexp-query.html
# Term: query-dsl-term-query.html
# Terms: query-dsl-terms-query.html
# Terms set: query-dsl-terms-set-query.html
# Wildcard: query-dsl-wildcard-query.html
# minimum_should_matchparameter: query-dsl-minimum-should-match.html
# rewriteparameter: query-dsl-multi-term-rewrite.html
# Regular expression syntax: regexp-syntax.html
# EQL: eql.html
# Syntax reference: eql-syntax.html
# Function reference: eql-function-ref.html
# Pipe reference: eql-pipe-ref.html
# Example: Detect threats with EQL: eql-ex-threat-detection.html
# ES|QL: esql.html
# Getting started: esql-getting-started.html
# ES|QL reference: esql-language.html
# Syntax reference: esql-syntax.html
# Commands: esql-commands.html
# Functions and operators: esql-functions-operators.html
# Metadata fields: esql-metadata-fields.html
# Multivalued fields: esql-multivalued-fields.html
# Data processing with DISSECT and GROK: esql-process-data-with-dissect-and-grok.html
# Data enrichment: esql-enrich-data.html
# Implicit casting: esql-implicit-casting.html
# Using ES|QL: esql-using.html
# REST API: esql-rest.html
# Using ES|QL in Kibana: esql-kibana.html
# Using ES|QL in Elastic Security: esql-elastic-security.html
# Using ES|QL to query multiple indices: esql-multi-index.html
# Using ES|QL across clusters: esql-cross-clusters.html
# Task management: esql-task-management.html
# Limitations: esql-limitations.html
# Examples: esql-examples.html
# SQL: xpack-sql.html
# Overview: sql-overview.html
# Getting Started with SQL: sql-getting-started.html
# Conventions and Terminology: sql-concepts.html
# Mapping concepts across SQL and Elasticsearch: _mapping_concepts_across_sql_and_elasticsearch.html
# Security: sql-security.html
# SQL REST API: sql-rest.html
# Overview: sql-rest-overview.html
# Response Data Formats: sql-rest-format.html
# Paginating through a large response: sql-pagination.html
# Filtering using Elasticsearch Query DSL: sql-rest-filtering.html
# Columnar results: sql-rest-columnar.html
# Passing parameters to a query: sql-rest-params.html
# Use runtime fields: sql-runtime-fields.html
# Run an async SQL search: sql-async.html
# SQL Translate API: sql-translate.html
# SQL CLI: sql-cli.html
# SQL JDBC: sql-jdbc.html
# API usage: _api_usage.html
# SQL ODBC: sql-odbc.html
# Driver installation: sql-odbc-installation.html
# Configuration: sql-odbc-setup.html
# SQL Client Applications: sql-client-apps.html
# DBeaver: sql-client-apps-dbeaver.html
# DbVisualizer: sql-client-apps-dbvis.html
# Microsoft Excel: sql-client-apps-excel.html
# Microsoft Power BI Desktop: sql-client-apps-powerbi.html
# Microsoft PowerShell: sql-client-apps-ps1.html
# MicroStrategy Desktop: sql-client-apps-microstrat.html
# Qlik Sense Desktop: sql-client-apps-qlik.html
# SQuirreL SQL: sql-client-apps-squirrel.html
# SQL Workbench/J: sql-client-apps-workbench.html
# Tableau Desktop: sql-client-apps-tableau-desktop.html
# Tableau Server: sql-client-apps-tableau-server.html
# SQL Language: sql-spec.html
# Lexical Structure: sql-lexical-structure.html
# SQL Commands: sql-commands.html
# DESCRIBE TABLE: sql-syntax-describe-table.html
# SELECT: sql-syntax-select.html
# SHOW CATALOGS: sql-syntax-show-catalogs.html
# SHOW COLUMNS: sql-syntax-show-columns.html
# SHOW FUNCTIONS: sql-syntax-show-functions.html
# SHOW TABLES: sql-syntax-show-tables.html
# Data Types: sql-data-types.html
# Index patterns: sql-index-patterns.html
# Frozen Indices: sql-index-frozen.html
# Functions and Operators: sql-functions.html
# Comparison Operators: sql-operators.html
# Logical Operators: sql-operators-logical.html
# Math Operators: sql-operators-math.html
# Cast Operators: sql-operators-cast.html
# LIKE and RLIKE Operators: sql-like-rlike-operators.html
# Aggregate Functions: sql-functions-aggs.html
# Grouping Functions: sql-functions-grouping.html
# Date/Time and Interval Functions and Operators: sql-functions-datetime.html
# Full-Text Search Functions: sql-functions-search.html
# Mathematical Functions: sql-functions-math.html
# String Functions: sql-functions-string.html
# Type Conversion Functions: sql-functions-type-conversion.html
# Geo Functions: sql-functions-geo.html
# Conditional Functions And Expressions: sql-functions-conditional.html
# System Functions: sql-functions-system.html
# Reserved keywords: sql-syntax-reserved.html
# SQL Limitations: sql-limitations.html
# Scripting: modules-scripting.html
# Painless scripting language: modules-scripting-painless.html
# How to write scripts: modules-scripting-using.html
# Scripts, caching, and search speed: scripts-and-search-speed.html
# Dissecting data: dissect.html
# Grokking grok: grok.html
# Access fields in a document: script-fields-api.html
# Common scripting use cases: common-script-uses.html
# Field extraction: scripting-field-extraction.html
# Accessing document fields and special variables: modules-scripting-fields.html
# Scripting and security: modules-scripting-security.html
# Lucene expressions language: modules-scripting-expression.html
# Advanced scripts using script engines: modules-scripting-engine.html
# Aggregations: search-aggregations.html
# Bucket aggregations: search-aggregations-bucket.html
# Adjacency matrix: search-aggregations-bucket-adjacency-matrix-aggregation.html
# Auto-interval date histogram: search-aggregations-bucket-autodatehistogram-aggregation.html
# Categorize text: search-aggregations-bucket-categorize-text-aggregation.html
# Children: search-aggregations-bucket-children-aggregation.html
# Composite: search-aggregations-bucket-composite-aggregation.html
# Date histogram: search-aggregations-bucket-datehistogram-aggregation.html
# Date range: search-aggregations-bucket-daterange-aggregation.html
# Diversified sampler: search-aggregations-bucket-diversified-sampler-aggregation.html
# Filter: search-aggregations-bucket-filter-aggregation.html
# Filters: search-aggregations-bucket-filters-aggregation.html
# Frequent item sets: search-aggregations-bucket-frequent-item-sets-aggregation.html
# Geo-distance: search-aggregations-bucket-geodistance-aggregation.html
# Geohash grid: search-aggregations-bucket-geohashgrid-aggregation.html
# Geohex grid: search-aggregations-bucket-geohexgrid-aggregation.html
# Geotile grid: search-aggregations-bucket-geotilegrid-aggregation.html
# Global: search-aggregations-bucket-global-aggregation.html
# Histogram: search-aggregations-bucket-histogram-aggregation.html
# IP prefix: search-aggregations-bucket-ipprefix-aggregation.html
# IP range: search-aggregations-bucket-iprange-aggregation.html
# Missing: search-aggregations-bucket-missing-aggregation.html
# Multi Terms: search-aggregations-bucket-multi-terms-aggregation.html
# Nested: search-aggregations-bucket-nested-aggregation.html
# Parent: search-aggregations-bucket-parent-aggregation.html
# Random sampler: search-aggregations-random-sampler-aggregation.html
# Range: search-aggregations-bucket-range-aggregation.html
# Rare terms: search-aggregations-bucket-rare-terms-aggregation.html
# Reverse nested: search-aggregations-bucket-reverse-nested-aggregation.html
# Sampler: search-aggregations-bucket-sampler-aggregation.html
# Significant terms: search-aggregations-bucket-significantterms-aggregation.html
# Significant text: search-aggregations-bucket-significanttext-aggregation.html
# Terms: search-aggregations-bucket-terms-aggregation.html
# Time series: search-aggregations-bucket-time-series-aggregation.html
# Variable width histogram: search-aggregations-bucket-variablewidthhistogram-aggregation.html
# Subtleties of bucketing range fields: search-aggregations-bucket-range-field-note.html
# Metrics aggregations: search-aggregations-metrics.html
# Avg: search-aggregations-metrics-avg-aggregation.html
# Boxplot: search-aggregations-metrics-boxplot-aggregation.html
# Cardinality: search-aggregations-metrics-cardinality-aggregation.html
# Extended stats: search-aggregations-metrics-extendedstats-aggregation.html
# Geo-bounds: search-aggregations-metrics-geobounds-aggregation.html
# Geo-centroid: search-aggregations-metrics-geocentroid-aggregation.html
# Geo-line: search-aggregations-metrics-geo-line.html
# Cartesian-bounds: search-aggregations-metrics-cartesian-bounds-aggregation.html
# Cartesian-centroid: search-aggregations-metrics-cartesian-centroid-aggregation.html
# Matrix stats: search-aggregations-matrix-stats-aggregation.html
# Max: search-aggregations-metrics-max-aggregation.html
# Median absolute deviation: search-aggregations-metrics-median-absolute-deviation-aggregation.html
# Min: search-aggregations-metrics-min-aggregation.html
# Percentile ranks: search-aggregations-metrics-percentile-rank-aggregation.html
# Percentiles: search-aggregations-metrics-percentile-aggregation.html
# Rate: search-aggregations-metrics-rate-aggregation.html
# Scripted metric: search-aggregations-metrics-scripted-metric-aggregation.html
# Stats: search-aggregations-metrics-stats-aggregation.html
# String stats: search-aggregations-metrics-string-stats-aggregation.html
# Sum: search-aggregations-metrics-sum-aggregation.html
# T-test: search-aggregations-metrics-ttest-aggregation.html
# Top hits: search-aggregations-metrics-top-hits-aggregation.html
# Top metrics: search-aggregations-metrics-top-metrics.html
# Value count: search-aggregations-metrics-valuecount-aggregation.html
# Weighted avg: search-aggregations-metrics-weight-avg-aggregation.html
# Pipeline aggregations: search-aggregations-pipeline.html
# Average bucket: search-aggregations-pipeline-avg-bucket-aggregation.html
# Bucket script: search-aggregations-pipeline-bucket-script-aggregation.html
# Bucket count K-S test: search-aggregations-bucket-count-ks-test-aggregation.html
# Bucket correlation: search-aggregations-bucket-correlation-aggregation.html
# Bucket selector: search-aggregations-pipeline-bucket-selector-aggregation.html
# Bucket sort: search-aggregations-pipeline-bucket-sort-aggregation.html
# Change point: search-aggregations-change-point-aggregation.html
# Cumulative cardinality: search-aggregations-pipeline-cumulative-cardinality-aggregation.html
# Cumulative sum: search-aggregations-pipeline-cumulative-sum-aggregation.html
# Derivative: search-aggregations-pipeline-derivative-aggregation.html
# Extended stats bucket: search-aggregations-pipeline-extended-stats-bucket-aggregation.html
# Inference bucket: search-aggregations-pipeline-inference-bucket-aggregation.html
# Max bucket: search-aggregations-pipeline-max-bucket-aggregation.html
# Min bucket: search-aggregations-pipeline-min-bucket-aggregation.html
# Moving function: search-aggregations-pipeline-movfn-aggregation.html
# Moving percentiles: search-aggregations-pipeline-moving-percentiles-aggregation.html
# Normalize: search-aggregations-pipeline-normalize-aggregation.html
# Percentiles bucket: search-aggregations-pipeline-percentiles-bucket-aggregation.html
# Serial differencing: search-aggregations-pipeline-serialdiff-aggregation.html
# Stats bucket: search-aggregations-pipeline-stats-bucket-aggregation.html
# Sum bucket: search-aggregations-pipeline-sum-bucket-aggregation.html
# Geospatial analysis: geospatial-analysis.html
# Watcher: xpack-alerting.html
# Getting started with Watcher: watcher-getting-started.html
# How Watcher works: how-watcher-works.html
# Encrypting sensitive data in Watcher: encrypting-data.html
# Inputs: input.html
# Simple input: input-simple.html
# Search input: input-search.html
# HTTP input: input-http.html
# Chain input: input-chain.html
# Triggers: trigger.html
# Schedule trigger: trigger-schedule.html
# Conditions: condition.html
# Always condition: condition-always.html
# Never condition: condition-never.html
# Compare condition: condition-compare.html
# Array compare condition: condition-array-compare.html
# Script condition: condition-script.html
# Actions: actions.html
# Running an action for each element in an array: action-foreach.html
# Adding conditions to actions: action-conditions.html
# Email action: actions-email.html
# Webhook action: actions-webhook.html
# Index action: actions-index.html
# Logging action: actions-logging.html
# Slack action: actions-slack.html
# PagerDuty action: actions-pagerduty.html
# Jira action: actions-jira.html
# Transforms: transform.html
# Search payload transform: transform-search.html
# Script payload transform: transform-script.html
# Chain payload transform: transform-chain.html
# Managing watches: managing-watches.html
# Example watches: example-watches.html
# Watching the status of an Elasticsearch cluster: watch-cluster-status.html
# Limitations: watcher-limitations.html
# Monitor a cluster: monitor-elasticsearch-cluster.html
# Overview: monitoring-overview.html
# How it works: how-monitoring-works.html
# Monitoring in a production environment: monitoring-production.html
# Collecting monitoring data with Elastic Agent: configuring-elastic-agent.html
# Collecting monitoring data with Metricbeat: configuring-metricbeat.html
# Collecting log data with Filebeat: configuring-filebeat.html
# Configuring data streams/indices for monitoring: config-monitoring-indices.html
# Configuring data streams created by Elastic Agent: config-monitoring-data-streams-elastic-agent.html
# Configuring data streams created by Metricbeat 8: config-monitoring-data-streams-metricbeat-8.html
# Configuring indices created by Metricbeat 7 or internal collection: config-monitoring-indices-metricbeat-7-internal-collection.html
# Legacy collection methods: collecting-monitoring-data.html
# Collectors: es-monitoring-collectors.html
# Exporters: es-monitoring-exporters.html
# Local exporters: local-exporter.html
# HTTP exporters: http-exporter.html
# Pausing data collection: pause-export.html
# Secure the Elastic Stack: secure-cluster.html
# Elasticsearch security principles: es-security-principles.html
# Start the Elastic Stack with security enabled automatically: configuring-stack-security.html
# Manually configure security: manually-configure-security.html
# Set up minimal security: security-minimal-setup.html
# Set up basic security: security-basic-setup.html
# Set up basic security plus HTTPS: security-basic-setup-https.html
# Setting passwords for native and built-in users: change-passwords-native-users.html
# Enabling cipher suites for stronger encryption: ciphers.html
# Supported SSL/TLS versions by JDK version: jdk-tls-versions.html
# Security files: security-files.html
# FIPS 140-2: fips-140-compliance.html
# Updating node security certificates: update-node-certs.html
# With the same CA: update-node-certs-same.html
# With a different CA: update-node-certs-different.html
# User authentication: setting-up-authentication.html
# Built-in users: built-in-users.html
# Service accounts: service-accounts.html
# Internal users: internal-users.html
# Token-based authentication services: token-authentication-services.html
# User profiles: user-profile.html
# Realms: realms.html
# Realm chains: realm-chains.html
# Security domains: security-domain.html
# Active Directory user authentication: active-directory-realm.html
# File-based user authentication: file-realm.html
# LDAP user authentication: ldap-realm.html
# Native user authentication: native-realm.html
# OpenID Connect authentication: oidc-realm.html
# PKI user authentication: pki-realm.html
# SAML authentication: saml-realm.html
# Kerberos authentication: kerberos-realm.html
# JWT authentication: jwt-auth-realm.html
# Integrating with other authentication systems: custom-realms.html
# Enabling anonymous access: anonymous-access.html
# Looking up users without authentication: user-lookup.html
# Controlling the user cache: controlling-user-cache.html
# Configuring SAML single-sign-on on the Elastic Stack: saml-guide-stack.html
# Configuring single sign-on to the Elastic Stack using OpenID Connect: oidc-guide.html
# User authorization: authorization.html
# Built-in roles: built-in-roles.html
# Defining roles: defining-roles.html
# Role restriction: role-restriction.html
# Security privileges: security-privileges.html
# Document level security: document-level-security.html
# Field level security: field-level-security.html
# Granting privileges for data streams and aliases: securing-aliases.html
# Mapping users and groups to roles: mapping-roles.html
# Setting up field and document level security: field-and-document-access-control.html
# Submitting requests on behalf of other users: run-as-privilege.html
# Configuring authorization delegation: configuring-authorization-delegation.html
# Customizing roles and authorization: custom-roles-authorization.html
# Enable audit logging: enable-audit-logging.html
# Audit events: audit-event-types.html
# Logfile audit output: audit-log-output.html
# Logfile audit events ignore policies: audit-log-ignore-policy.html
# Auditing search queries: auditing-search-queries.html
# Restricting connections with IP filtering: ip-filtering.html
# Securing clients and integrations: security-clients-integrations.html
# HTTP/REST clients and security: http-clients.html
# ES-Hadoop and Security: hadoop.html
# Monitoring and security: secure-monitoring.html
# Operator privileges: operator-privileges.html
# Configure operator privileges: configure-operator-privileges.html
# Operator-only functionality: operator-only-functionality.html
# Operator privileges for snapshot and restore: operator-only-snapshot-and-restore.html
# Troubleshooting: security-troubleshooting.html
# Some settings are not returned via the nodes settings API: security-trb-settings.html
# Authorization exceptions: security-trb-roles.html
# Users command fails due to extra arguments: security-trb-extraargs.html
# Users are frequently locked out of Active Directory: trouble-shoot-active-directory.html
# Certificate verification fails for curl on Mac: trb-security-maccurl.html
# SSLHandshakeException causes connections to fail: trb-security-sslhandshake.html
# Common SSL/TLS exceptions: trb-security-ssl.html
# Common Kerberos exceptions: trb-security-kerberos.html
# Common SAML issues: trb-security-saml.html
# Internal Server Error in Kibana: trb-security-internalserver.html
# Setup-passwords command fails due to connection failure: trb-security-setup.html
# Failures due to relocation of the configuration files: trb-security-path.html
# Limitations: security-limitations.html
# Set up a cluster for high availability: high-availability.html
# Designing for resilience: high-availability-cluster-design.html
# Resilience in small clusters: high-availability-cluster-small-clusters.html
# Resilience in larger clusters: high-availability-cluster-design-large-clusters.html
# Cross-cluster replication: xpack-ccr.html
# Set up cross-cluster replication: ccr-getting-started-tutorial.html
# Manage cross-cluster replication: ccr-managing.html
# Manage auto-follow patterns: ccr-auto-follow.html
# Upgrading clusters: ccr-upgrading.html
# Uni-directional disaster recovery: ccr-disaster-recovery-uni-directional-tutorial.html
# Bi-directional disaster recovery: ccr-disaster-recovery-bi-directional-tutorial.html
# How to: how-to.html
# General recommendations: general-recommendations.html
# Recipes: recipes.html
# Mixing exact search with stemming: mixing-exact-search-with-stemming.html
# Getting consistent scoring: consistent-scoring.html
# Incorporating static relevance signals into the score: static-scoring-signals.html
# Tune for indexing speed: tune-for-indexing-speed.html
# Tune for search speed: tune-for-search-speed.html
# Tune approximate kNN search: tune-knn-search.html
# Tune for disk usage: tune-for-disk-usage.html
# Size your shards: size-your-shards.html
# Use Elasticsearch for time series data: use-elasticsearch-for-time-series-data.html
# Autoscaling: xpack-autoscaling.html
# Autoscaling deciders: autoscaling-deciders.html
# Reactive storage decider: autoscaling-reactive-storage-decider.html
# Proactive storage decider: autoscaling-proactive-storage-decider.html
# Frozen shards decider: autoscaling-frozen-shards-decider.html
# Frozen storage decider: autoscaling-frozen-storage-decider.html
# Frozen existence decider: autoscaling-frozen-existence-decider.html
# Machine learning decider: autoscaling-machine-learning-decider.html
# Fixed decider: autoscaling-fixed-decider.html
# Snapshot and restore: snapshot-restore.html
# Register a repository: snapshots-register-repository.html
# Azure repository: repository-azure.html
# Google Cloud Storage repository: repository-gcs.html
# S3 repository: repository-s3.html
# Shared file system repository: snapshots-filesystem-repository.html
# Read-only URL repository: snapshots-read-only-repository.html
# Source-only repository: snapshots-source-only-repository.html
# Create a snapshot: snapshots-take-snapshot.html
# Restore a snapshot: snapshots-restore-snapshot.html
# Searchable snapshots: searchable-snapshots.html
# REST APIs: rest-apis.html
# API conventions: api-conventions.html
# Common options: common-options.html
# REST API compatibility: rest-api-compatibility.html
# Autoscaling APIs: autoscaling-apis.html
# Create or update autoscaling policy: autoscaling-put-autoscaling-policy.html
# Get autoscaling capacity: autoscaling-get-autoscaling-capacity.html
# Delete autoscaling policy: autoscaling-delete-autoscaling-policy.html
# Get autoscaling policy: autoscaling-get-autoscaling-policy.html
# Behavioral Analytics APIs: behavioral-analytics-apis.html
# Put Analytics Collection: put-analytics-collection.html
# Delete Analytics Collection: delete-analytics-collection.html
# List Analytics Collections: list-analytics-collection.html
# Post Analytics Collection Event: post-analytics-collection-event.html
# Compact and aligned text (CAT) APIs: cat.html
# cat aliases: cat-alias.html
# cat allocation: cat-allocation.html
# cat anomaly detectors: cat-anomaly-detectors.html
# cat component templates: cat-component-templates.html
# cat count: cat-count.html
# cat data frame analytics: cat-dfanalytics.html
# cat datafeeds: cat-datafeeds.html
# cat fielddata: cat-fielddata.html
# cat health: cat-health.html
# cat indices: cat-indices.html
# cat master: cat-master.html
# cat nodeattrs: cat-nodeattrs.html
# cat nodes: cat-nodes.html
# cat pending tasks: cat-pending-tasks.html
# cat plugins: cat-plugins.html
# cat recovery: cat-recovery.html
# cat repositories: cat-repositories.html
# cat segments: cat-segments.html
# cat shards: cat-shards.html
# cat snapshots: cat-snapshots.html
# cat task management: cat-tasks.html
# cat templates: cat-templates.html
# cat thread pool: cat-thread-pool.html
# cat trained model: cat-trained-model.html
# cat transforms: cat-transforms.html
# Cluster APIs: cluster.html
# Cluster allocation explain: cluster-allocation-explain.html
# Cluster get settings: cluster-get-settings.html
# Cluster health: cluster-health.html
# Health: health-api.html
# Cluster reroute: cluster-reroute.html
# Cluster state: cluster-state.html
# Cluster stats: cluster-stats.html
# Cluster update settings: cluster-update-settings.html
# Nodes feature usage: cluster-nodes-usage.html
# Nodes hot threads: cluster-nodes-hot-threads.html
# Nodes info: cluster-nodes-info.html
# Prevalidate node removal: prevalidate-node-removal-api.html
# Nodes reload secure settings: cluster-nodes-reload-secure-settings.html
# Nodes stats: cluster-nodes-stats.html
# Cluster Info: cluster-info.html
# Pending cluster tasks: cluster-pending.html
# Remote cluster info: cluster-remote-info.html
# Task management: tasks.html
# Voting configuration exclusions: voting-config-exclusions.html
# Create or update desired nodes: update-desired-nodes.html
# Get desired nodes: get-desired-nodes.html
# Delete desired nodes: delete-desired-nodes.html
# Get desired balance: get-desired-balance.html
# Reset desired balance: delete-desired-balance.html
# Cross-cluster replication APIs: ccr-apis.html
# Get CCR stats: ccr-get-stats.html
# Create follower: ccr-put-follow.html
# Pause follower: ccr-post-pause-follow.html
# Resume follower: ccr-post-resume-follow.html
# Unfollow: ccr-post-unfollow.html
# Forget follower: ccr-post-forget-follower.html
# Get follower stats: ccr-get-follow-stats.html
# Get follower info: ccr-get-follow-info.html
# Create auto-follow pattern: ccr-put-auto-follow-pattern.html
# Delete auto-follow pattern: ccr-delete-auto-follow-pattern.html
# Get auto-follow pattern: ccr-get-auto-follow-pattern.html
# Pause auto-follow pattern: ccr-pause-auto-follow-pattern.html
# Resume auto-follow pattern: ccr-resume-auto-follow-pattern.html
# Connector APIs: connector-apis.html
# Create connector: create-connector-api.html
# Delete connector: delete-connector-api.html
# Get connector: get-connector-api.html
# List connectors: list-connector-api.html
# Update connector API key id: update-connector-api-key-id-api.html
# Update connector configuration: update-connector-configuration-api.html
# Update connector index name: update-connector-index-name-api.html
# Update connector features: update-connector-features-api.html
# Update connector filtering: update-connector-filtering-api.html
# Update connector name and description: update-connector-name-description-api.html
# Update connector pipeline: update-connector-pipeline-api.html
# Update connector scheduling: update-connector-scheduling-api.html
# ...
# Suggesters: search-suggesters.html
# Multi search: search-multi-search.html
# Count: search-count.html
# Validate: search-validate.html
# Terms enum: search-terms-enum.html
# Explain: search-explain.html
# Profile: search-profile.html
# Field capabilities: search-field-caps.html
# Ranking evaluation: search-rank-eval.html
# Vector tile search: search-vector-tile-api.html
# Search Application APIs: search-application-apis.html
# Put Search Application: put-search-application.html
# Get Search Application: get-search-application.html
# List Search Applications: list-search-applications.html
# Delete Search Application: delete-search-application.html
# Search Application Search: search-application-search.html
# Render Search Application Query: search-application-render-query.html
# Searchable snapshots APIs: searchable-snapshots-apis.html
# Mount snapshot: searchable-snapshots-api-mount-snapshot.html
# Cache stats: searchable-snapshots-api-cache-stats.html
# Searchable snapshot statistics: searchable-snapshots-api-stats.html
# Clear cache: searchable-snapshots-api-clear-cache.html
# Security APIs: security-api.html
# Authenticate: security-api-authenticate.html
# Change passwords: security-api-change-password.html
# Clear cache: security-api-clear-cache.html
# Clear roles cache: security-api-clear-role-cache.html
# Clear privileges cache: security-api-clear-privilege-cache.html
# Clear API key cache: security-api-clear-api-key-cache.html
# Clear service account token caches: security-api-clear-service-token-caches.html
# Create API keys: security-api-create-api-key.html
# Create or update application privileges: security-api-put-privileges.html
# Create or update role mappings: security-api-put-role-mapping.html
# Create or update roles: security-api-put-role.html
# Bulk create or update roles API: security-api-bulk-put-role.html
# Bulk delete roles API: security-api-bulk-delete-role.html
# Create or update users: security-api-put-user.html
# Create service account tokens: security-api-create-service-token.html
# Delegate PKI authentication: security-api-delegate-pki-authentication.html
# Delete application privileges: security-api-delete-privilege.html
# Delete role mappings: security-api-delete-role-mapping.html
# Delete roles: security-api-delete-role.html
# Delete service account token: security-api-delete-service-token.html
# Delete users: security-api-delete-user.html
# Disable users: security-api-disable-user.html
# Enable users: security-api-enable-user.html
# Enroll Kibana: security-api-kibana-enrollment.html
# Enroll node: security-api-node-enrollment.html
# Get API key information: security-api-get-api-key.html
# Get application privileges: security-api-get-privileges.html
# Get builtin privileges: security-api-get-builtin-privileges.html
# Get role mappings: security-api-get-role-mapping.html
# Get roles: security-api-get-role.html
# Query Role: security-api-query-role.html
# Get service accounts: security-api-get-service-accounts.html
# Get service account credentials: security-api-get-service-credentials.html
# Get Security settings: security-api-get-settings.html
# Get token: security-api-get-token.html
# Get user privileges: security-api-get-user-privileges.html
# Get users: security-api-get-user.html
# Grant API keys: security-api-grant-api-key.html
# Has privileges: security-api-has-privileges.html
# Invalidate API key: security-api-invalidate-api-key.html
# Invalidate token: security-api-invalidate-token.html
# OpenID Connect prepare authentication: security-api-oidc-prepare-authentication.html
# OpenID Connect authenticate: security-api-oidc-authenticate.html
# OpenID Connect logout: security-api-oidc-logout.html
# Query API key information: security-api-query-api-key.html
# Query User: security-api-query-user.html
# Update API key: security-api-update-api-key.html
# Update Security settings: security-api-update-settings.html
# Bulk update API keys: security-api-bulk-update-api-keys.html
# SAML prepare authentication: security-api-saml-prepare-authentication.html
# SAML authenticate: security-api-saml-authenticate.html
# SAML logout: security-api-saml-logout.html
# SAML invalidate: security-api-saml-invalidate.html
# SAML complete logout: security-api-saml-complete-logout.html
# SAML service provider metadata: security-api-saml-sp-metadata.html
# SSL certificate: security-api-ssl.html
# Activate user profile: security-api-activate-user-profile.html
# Disable user profile: security-api-disable-user-profile.html
# Enable user profile: security-api-enable-user-profile.html
# Get user profiles: security-api-get-user-profile.html
# Suggest user profile: security-api-suggest-user-profile.html
# Update user profile data: security-api-update-user-profile-data.html
# Has privileges user profile: security-api-has-privileges-user-profile.html
# Create Cross-Cluster API key: security-api-create-cross-cluster-api-key.html
# Update Cross-Cluster API key: security-api-update-cross-cluster-api-key.html
# Snapshot and restore APIs: snapshot-restore-apis.html
# Create or update snapshot repository: put-snapshot-repo-api.html
# Verify snapshot repository: verify-snapshot-repo-api.html
# Repository analysis: repo-analysis-api.html
# Get snapshot repository: get-snapshot-repo-api.html
# Delete snapshot repository: delete-snapshot-repo-api.html
# Clean up snapshot repository: clean-up-snapshot-repo-api.html
# Clone snapshot: clone-snapshot-api.html
# Create snapshot: create-snapshot-api.html
# Get snapshot: get-snapshot-api.html
# Get snapshot status: get-snapshot-status-api.html
# Restore snapshot: restore-snapshot-api.html
# Delete snapshot: delete-snapshot-api.html
# Snapshot lifecycle management APIs: snapshot-lifecycle-management-api.html
# Create or update policy: slm-api-put-policy.html
# Get policy: slm-api-get-policy.html
# Delete policy: slm-api-delete-policy.html
# Execute snapshot lifecycle policy: slm-api-execute-lifecycle.html
# Execute snapshot retention policy: slm-api-execute-retention.html
# Get snapshot lifecycle management status: slm-api-get-status.html
# Get snapshot lifecycle stats: slm-api-get-stats.html
# Start snapshot lifecycle management: slm-api-start.html
# Stop snapshot lifecycle management: slm-api-stop.html
# SQL APIs: sql-apis.html
# Clear SQL cursor: clear-sql-cursor-api.html
# Delete async SQL search: delete-async-sql-search-api.html
# Get async SQL search: get-async-sql-search-api.html
# Get async SQL search status: get-async-sql-search-status-api.html
# SQL search: sql-search-api.html
# SQL translate: sql-translate-api.html
# Synonyms APIs: synonyms-apis.html
# Create or update synonyms set: put-synonyms-set.html
# Get synonyms set: get-synonyms-set.html
# List synonyms sets: list-synonyms-sets.html
# Delete synonyms set: delete-synonyms-set.html
# Create or update synonym rule: put-synonym-rule.html
# Get synonym rule: get-synonym-rule.html
# Delete synonym rule: delete-synonym-rule.html
# Text structure APIs: text-structure-apis.html
# Find field structure API: find-field-structure.html
# Find messages structure API: find-message-structure.html
# Find text structure API: find-structure.html
# Test Grok pattern: test-grok-pattern.html
# Transform APIs: transform-apis.html
# Create transform: put-transform.html
# Delete transform: delete-transform.html
# Get transforms: get-transform.html
# Get transform statistics: get-transform-stats.html
# Preview transform: preview-transform.html
# Reset transform: reset-transform.html
# Schedule now transform: schedule-now-transform.html
# Start transform: start-transform.html
# Stop transforms: stop-transform.html
# Update transform: update-transform.html
# Upgrade transforms: upgrade-transforms.html
# Usage API: usage-api.html
# Watcher APIs: watcher-api.html
# Ack watch: watcher-api-ack-watch.html
# Activate watch: watcher-api-activate-watch.html
# Deactivate watch: watcher-api-deactivate-watch.html
# Delete watch: watcher-api-delete-watch.html
# Execute watch: watcher-api-execute-watch.html
# Get watch: watcher-api-get-watch.html
# Get Watcher stats: watcher-api-stats.html
# Query watches: watcher-api-query-watches.html
# Create or update watch: watcher-api-put-watch.html
# Update Watcher settings: watcher-api-update-settings.html
# Get Watcher settings: watcher-api-get-settings.html
# Start watch service: watcher-api-start.html
# Stop watch service: watcher-api-stop.html
# Definitions: api-definitions.html
# Role mapping resources: role-mapping-resources.html
# Command line tools: commands.html
# elasticsearch-certgen: certgen.html
# elasticsearch-certutil: certutil.html
# elasticsearch-create-enrollment-token: create-enrollment-token.html
# elasticsearch-croneval: elasticsearch-croneval.html
# elasticsearch-keystore: elasticsearch-keystore.html
# elasticsearch-node: node-tool.html
# elasticsearch-reconfigure-node: reconfigure-node.html
# elasticsearch-reset-password: reset-password.html
# elasticsearch-saml-metadata: saml-metadata.html
# elasticsearch-service-tokens: service-tokens-command.html
# elasticsearch-setup-passwords: setup-passwords.html
# elasticsearch-shard: shard-tool.html
# elasticsearch-syskeygen: syskeygen.html
# elasticsearch-users: users-command.html
# Troubleshooting: troubleshooting.html
# Fix common cluster issues: fix-common-cluster-issues.html
# Watermark errors: fix-watermark-errors.html
# Circuit breaker errors: circuit-breaker-errors.html
# High CPU usage: high-cpu-usage.html
# High JVM memory pressure: high-jvm-memory-pressure.html
# Red or yellow cluster health status: red-yellow-cluster-status.html
# Rejected requests: rejected-requests.html
# Task queue backlog: task-queue-backlog.html
# Mapping explosion: mapping-explosion.html
# Hot spotting: hotspotting.html
# Diagnose unassigned shards: diagnose-unassigned-shards.html
# Add a missing tier to the system: add-tier.html
# Allow Elasticsearch to allocate the data in the system: allow-all-cluster-allocation.html
# Allow Elasticsearch to allocate the index: allow-all-index-allocation.html
# Indices mix index allocation filters with data tiers node roles to move through data tiers: troubleshoot-migrate-to-tiers.html
# Not enough nodes to allocate all shard replicas: increase-tier-capacity.html
# Total number of shards for an index on a single node exceeded: increase-shard-limit.html
# Total number of shards per node has been reached: increase-cluster-shard-limit.html
# Troubleshooting corruption: corruption-troubleshooting.html
# Fix data nodes out of disk: fix-data-node-out-of-disk.html
# Increase the disk capacity of data nodes: increase-capacity-data-node.html
# Decrease the disk usage of data nodes: decrease-disk-usage-data-node.html
# Fix master nodes out of disk: fix-master-node-out-of-disk.html
# Fix other role nodes out of disk: fix-other-node-out-of-disk.html
# Start index lifecycle management: start-ilm.html
# Start Snapshot Lifecycle Management: start-slm.html
# Restore from snapshot: restore-from-snapshot.html
# Troubleshooting broken repositories: add-repository.html
# Diagnosing corrupted repositories: diagnosing-corrupted-repositories.html
# Diagnosing unknown repositories: diagnosing-unknown-repositories.html
# Diagnosing invalid repositories: diagnosing-invalid-repositories.html
# Addressing repeated snapshot policy failures: repeated-snapshot-failures.html
# Troubleshooting an unstable cluster: troubleshooting-unstable-cluster.html
# Troubleshooting discovery: discovery-troubleshooting.html
# Troubleshooting monitoring: monitoring-troubleshooting.html
# Troubleshooting transforms: transform-troubleshooting.html
# Troubleshooting Watcher: watcher-troubleshooting.html
# Troubleshooting searches: troubleshooting-searches.html
# Troubleshooting shards capacity health issues: troubleshooting-shards-capacity-issues.html
# Troubleshooting an unbalanced cluster: troubleshooting-unbalanced-cluster.html
# Capture diagnostics: diagnostic.html
# Upgrade Elasticsearch: setup-upgrade.html
# Archived settings: archived-settings.html
# Reading indices from older Elasticsearch versions: archive-indices.html
# Migration guide: breaking-changes.html
# 8.15: migrating-8.15.html
# 8.14: migrating-8.14.html
# 8.13: migrating-8.13.html
# 8.12: migrating-8.12.html
# 8.11: migrating-8.11.html
# 8.10: migrating-8.10.html
# 8.9: migrating-8.9.html
# 8.8: migrating-8.8.html
# 8.7: migrating-8.7.html
# 8.6: migrating-8.6.html
# 8.5: migrating-8.5.html
# 8.4: migrating-8.4.html
# 8.3: migrating-8.3.html
# 8.2: migrating-8.2.html
# 8.1: migrating-8.1.html
# 8.0: migrating-8.0.html
# Java time migration guide: migrate-to-java-time.html
# Transient settings migration guide: transient-settings-migration-guide.html
# What’s new in 8.15: release-highlights.html
# Release notes: es-release-notes.html
# Elasticsearch version 8.15.3: release-notes-8.15.3.html
# Elasticsearch version 8.15.2: release-notes-8.15.2.html
# Elasticsearch version 8.15.1: release-notes-8.15.1.html
# Elasticsearch version 8.15.0: release-notes-8.15.0.html
# Elasticsearch version 8.14.3: release-notes-8.14.3.html
# Elasticsearch version 8.14.2: release-notes-8.14.2.html
# Elasticsearch version 8.14.1: release-notes-8.14.1.html
# Elasticsearch version 8.14.0: release-notes-8.14.0.html
# Elasticsearch version 8.13.4: release-notes-8.13.4.html
# Elasticsearch version 8.13.3: release-notes-8.13.3.html
# Elasticsearch version 8.13.2: release-notes-8.13.2.html
# Bug fixes: _bug_fixes.html
# Elasticsearch version 8.13.1: release-notes-8.13.1.html
# Bug fixes: _bug_fixes_2.html
# Elasticsearch version 8.13.0: release-notes-8.13.0.html
# Elasticsearch version 8.12.2: release-notes-8.12.2.html
# Elasticsearch version 8.12.1: release-notes-8.12.1.html
# Elasticsearch version 8.12.0: release-notes-8.12.0.html
# Elasticsearch version 8.11.4: release-notes-8.11.4.html
# Elasticsearch version 8.11.3: release-notes-8.11.3.html
# Elasticsearch version 8.11.2: release-notes-8.11.2.html
# Elasticsearch version 8.11.1: release-notes-8.11.1.html
# Elasticsearch version 8.11.0: release-notes-8.11.0.html
# Elasticsearch version 8.10.4: release-notes-8.10.4.html
# Elasticsearch version 8.10.3: release-notes-8.10.3.html
# Elasticsearch version 8.10.2: release-notes-8.10.2.html
# Elasticsearch version 8.10.1: release-notes-8.10.1.html
# Elasticsearch version 8.10.0: release-notes-8.10.0.html
# Elasticsearch version 8.9.2: release-notes-8.9.2.html
# Elasticsearch version 8.9.1: release-notes-8.9.1.html
# Elasticsearch version 8.9.0: release-notes-8.9.0.html
# Elasticsearch version 8.8.2: release-notes-8.8.2.html
# Elasticsearch version 8.8.1: release-notes-8.8.1.html
# Elasticsearch version 8.8.0: release-notes-8.8.0.html
# Elasticsearch version 8.7.1: release-notes-8.7.1.html
# Elasticsearch version 8.7.0: release-notes-8.7.0.html
# Elasticsearch version 8.6.2: release-notes-8.6.2.html
# Elasticsearch version 8.6.1: release-notes-8.6.1.html
# Elasticsearch version 8.6.0: release-notes-8.6.0.html
# Elasticsearch version 8.5.3: release-notes-8.5.3.html
# Elasticsearch version 8.5.2: release-notes-8.5.2.html
# Elasticsearch version 8.5.1: release-notes-8.5.1.html
# Elasticsearch version 8.5.0: release-notes-8.5.0.html
# Elasticsearch version 8.4.3: release-notes-8.4.3.html
# Elasticsearch version 8.4.2: release-notes-8.4.2.html
# Elasticsearch version 8.4.1: release-notes-8.4.1.html
# Elasticsearch version 8.4.0: release-notes-8.4.0.html
# Elasticsearch version 8.3.3: release-notes-8.3.3.html
# Elasticsearch version 8.3.2: release-notes-8.3.2.html
# Elasticsearch version 8.3.1: release-notes-8.3.1.html
# Elasticsearch version 8.3.0: release-notes-8.3.0.html
# Elasticsearch version 8.2.3: release-notes-8.2.3.html
# Elasticsearch version 8.2.2: release-notes-8.2.2.html
# Elasticsearch version 8.2.1: release-notes-8.2.1.html
# Elasticsearch version 8.2.0: release-notes-8.2.0.html
# Elasticsearch version 8.1.3: release-notes-8.1.3.html
# Elasticsearch version 8.1.2: release-notes-8.1.2.html
# Elasticsearch version 8.1.1: release-notes-8.1.1.html
# Elasticsearch version 8.1.0: release-notes-8.1.0.html
# Elasticsearch version 8.0.1: release-notes-8.0.1.html
# Elasticsearch version 8.0.0: release-notes-8.0.0.html
# Elasticsearch version 8.0.0-rc2: release-notes-8.0.0-rc2.html
# Elasticsearch version 8.0.0-rc1: release-notes-8.0.0-rc1.html
# Elasticsearch version 8.0.0-beta1: release-notes-8.0.0-beta1.html
# Elasticsearch version 8.0.0-alpha2: release-notes-8.0.0-alpha2.html
# Elasticsearch version 8.0.0-alpha1: release-notes-8.0.0-alpha1.html
# Dependencies and versions: dependencies-versions.html

# %%
toc_links
# Out:
# [('Elasticsearch basics', 'elasticsearch-intro.html'),
#  ('What is Elasticsearch?', 'elasticsearch-intro-what-is-es.html'),
#  ('Run Elasticsearch', 'elasticsearch-intro-deploy.html'),
#  ('Indices and documents', 'documents-indices.html'),
#  ('Add data to Elasticsearch', 'es-ingestion-overview.html'),
#  ('Search and analyze data', 'search-analyze.html'),
#  ('Get ready for production', 'scalability.html'),
#  ('Quick starts', 'quickstart.html'),
#  ('Basics: Index and search using APIs', 'getting-started.html'),
#  ('Basics: Full-text search and filtering', 'full-text-filter-tutorial.html'),
#  ('Set up Elasticsearch', 'setup.html'),
#  ('Run Elasticsearch locally', 'run-elasticsearch-locally.html'),
#  ('Installing Elasticsearch', 'install-elasticsearch.html'),
#  ('Install Elasticsearch from archive on Linux or MacOS', 'targz.html'),
#  ('Install Elasticsearch with.zipon Windows', 'zip-windows.html'),
#  ('Install Elasticsearch with Debian Package', 'deb.html'),
#  ('Install Elasticsearch with RPM', 'rpm.html'),
#  ('Install Elasticsearch with Docker', 'docker.html'),
#  ('Configuring Elasticsearch', 'settings.html'),
#  ('Important Elasticsearch configuration', 'important-settings.html'),
#  ('Secure settings', 'secure-settings.html'),
#  ('Auditing settings', 'auditing-settings.html'),
#  ('Circuit breaker settings', 'circuit-breaker.html'),
#  ('Cluster-level shard allocation and routing settings',
#   'modules-cluster.html'),
#  ('Miscellaneous cluster settings', 'misc-cluster-settings.html'),
#  ('Cross-cluster replication settings', 'ccr-settings.html'),
#  ('Discovery and cluster formation settings',
#   'modules-discovery-settings.html'),
#  ('Field data cache settings', 'modules-fielddata.html'),
#  ('Health Diagnostic settings', 'health-diagnostic-settings.html'),
#  ('Index lifecycle management settings', 'ilm-settings.html'),
#  ('Data stream lifecycle settings', 'data-stream-lifecycle-settings.html'),
#  ('Index management settings', 'index-management-settings.html'),
#  ('Index recovery settings', 'recovery.html'),
#  ('Indexing buffer settings', 'indexing-buffer.html'),
#  ('License settings', 'license-settings.html'),
#  ('Local gateway settings', 'modules-gateway.html'),
#  ('Logging', 'logging.html'),
#  ('Machine learning settings', 'ml-settings.html'),
#  ('Inference settings', 'inference-settings.html'),
#  ('Monitoring settings', 'monitoring-settings.html'),
#  ('Nodes', 'modules-node.html'),
#  ('Networking', 'modules-network.html'),
#  ('Node query cache settings', 'query-cache.html'),
#  ('Search settings', 'search-settings.html'),
#  ('Security settings', 'security-settings.html'),
#  ('Shard allocation, relocation, and recovery',
#   'shard-allocation-relocation-recovery.html'),
#  ('Shard request cache settings', 'shard-request-cache.html'),
#  ('Snapshot and restore settings', 'snapshot-settings.html'),
#  ('Transforms settings', 'transform-settings.html'),
#  ('Thread pools', 'modules-threadpool.html'),
#  ('Watcher settings', 'notification-settings.html'),
#  ('Advanced configuration', 'advanced-configuration.html'),
#  ('Important system configuration', 'system-config.html'),
#  ('Configuring system settings', 'setting-system-settings.html'),
#  ('Disable swapping', 'setup-configuration-memory.html'),
#  ('File Descriptors', 'file-descriptors.html'),
#  ('Virtual memory', 'vm-max-map-count.html'),
#  ('Number of threads', 'max-number-of-threads.html'),
#  ('DNS cache settings', 'networkaddress-cache-ttl.html'),
#  ('Ensure JNA temporary directory permits executables',
#   'executable-jna-tmpdir.html'),
#  ('TCP retransmission timeout', 'system-config-tcpretries.html'),
#  ('Bootstrap Checks', 'bootstrap-checks.html'),
#  ('Heap size check', '_heap_size_check.html'),
#  ('File descriptor check', '_file_descriptor_check.html'),
#  ('Memory lock check', '_memory_lock_check.html'),
#  ('Maximum number of threads check', 'max-number-threads-check.html'),
#  ('Max file size check', '_max_file_size_check.html'),
#  ('Maximum size virtual memory check', 'max-size-virtual-memory-check.html'),
#  ('Maximum map count check', '_maximum_map_count_check.html'),
#  ('Client JVM check', '_client_jvm_check.html'),
#  ('Use serial collector check', '_use_serial_collector_check.html'),
#  ('System call filter check', '_system_call_filter_check.html'),
#  ('OnError and OnOutOfMemoryError checks',
#   '_onerror_and_onoutofmemoryerror_checks.html'),
#  ('Early-access check', '_early_access_check.html'),
#  ('All permission check', '_all_permission_check.html'),
#  ('Discovery configuration check', '_discovery_configuration_check.html'),
#  ('Bootstrap Checks for X-Pack', 'bootstrap-checks-xpack.html'),
#  ('Starting Elasticsearch', 'starting-elasticsearch.html'),
#  ('Stopping Elasticsearch', 'stopping-elasticsearch.html'),
#  ('Discovery and cluster formation', 'modules-discovery.html'),
#  ('Discovery', 'discovery-hosts-providers.html'),
#  ('Quorum-based decision making', 'modules-discovery-quorums.html'),
#  ('Voting configurations', 'modules-discovery-voting.html'),
#  ('Bootstrapping a cluster', 'modules-discovery-bootstrap-cluster.html'),
#  ('Publishing the cluster state', 'cluster-state-publishing.html'),
#  ('Cluster fault detection', 'cluster-fault-detection.html'),
#  ('Add and remove nodes in your cluster', 'add-elasticsearch-nodes.html'),
#  ('Full-cluster restart and rolling restart', 'restart-cluster.html'),
#  ('Remote clusters', 'remote-clusters.html'),
#  ('Add remote clusters using API key authentication',
#   'remote-clusters-api-key.html'),
#  ('Add remote clusters using TLS certificate authentication',
#   'remote-clusters-cert.html'),
#  ('Migrate from certificate to API key authentication',
#   'remote-clusters-migrate.html'),
#  ('Remote cluster settings', 'remote-clusters-settings.html'),
#  ('Troubleshooting', 'remote-clusters-troubleshooting.html'),
#  ('Plugins', 'modules-plugins.html'),
#  ('Search your data', 'search-with-elasticsearch.html'),
#  ('The search API', 'search-your-data.html'),
#  ('Sort search results', 'sort-search-results.html'),
#  ('Paginate search results', 'paginate-search-results.html'),
#  ('Retrieve selected fields', 'search-fields.html'),
#  ('Search multiple data streams and indices', 'search-multiple-indices.html'),
#  ('Collapse search results', 'collapse-search-results.html'),
#  ('Filter search results', 'filter-search-results.html'),
#  ('Highlighting', 'highlighting.html'),
#  ('Long-running searches', 'async-search-intro.html'),
#  ('Near real-time search', 'near-real-time.html'),
#  ('Retrieve inner hits', 'inner-hits.html'),
#  ('Search shard routing', 'search-shard-routing.html'),
#  ('Searching with query rules', 'search-using-query-rules.html'),
#  ('Search templates', 'search-template.html'),
#  ('Retrievers', 'retrievers-overview.html'),
#  ('kNN search', 'knn-search.html'),
#  ('Semantic search', 'semantic-search.html'),
#  ('Semantic search with `semantic_text`',
#   'semantic-search-semantic-text.html'),
#  ('Hybrid search with `semantic_text`', 'semantic-text-hybrid-search.html'),
#  ('Semantic search with the inference API', 'semantic-search-inference.html'),
#  ('Semantic search with ELSER', 'semantic-search-elser.html'),
#  ('Using Cohere with Elasticsearch', 'cohere-es.html'),
#  ('Semantic search with deployed model',
#   'semantic-search-deployed-nlp-model.html'),
#  ('Bring your own dense vectors', 'bring-your-own-vectors.html'),
#  ('Search across clusters', 'modules-cross-cluster-search.html'),
#  ('Search with synonyms', 'search-with-synonyms.html'),
#  ('Search Applications', 'search-application-overview.html'),
#  ('Search API and templates', 'search-application-api.html'),
#  ('Security', 'search-application-security.html'),
#  ('Search Application client guide', 'search-application-client.html'),
#  ('Search analytics', 'behavioral-analytics-overview.html'),
#  ('Get started', 'behavioral-analytics-start.html'),
#  ('Set up CORs', 'behavioral-analytics-cors.html'),
#  ('View events', 'behavioral-analytics-event.html'),
#  ('Events reference', 'behavioral-analytics-event-reference.html'),
#  ('API overview', 'behavioral-analytics-api.html'),
#  ('Re-ranking', 're-ranking-overview.html'),
#  ('Semantic re-ranking', 'semantic-reranking.html'),
#  ('Learning To Rank', 'learning-to-rank.html'),
#  ('Deploy and manage LTR models', 'learning-to-rank-model-training.html'),
#  ('Search using LTR', 'learning-to-rank-search-usage.html'),
#  ('Index modules', 'index-modules.html'),
#  ('Analysis', 'index-modules-analysis.html'),
#  ('Index Shard Allocation', 'index-modules-allocation.html'),
#  ('Index-level shard allocation filtering', 'shard-allocation-filtering.html'),
#  ('Delaying allocation when a node leaves', 'delayed-allocation.html'),
#  ('Index recovery prioritization', 'recovery-prioritization.html'),
#  ('Total shards per node', 'allocation-total-shards.html'),
#  ('Index-level data tier allocation filtering',
#   'data-tier-shard-filtering.html'),
#  ('Index blocks', 'index-modules-blocks.html'),
#  ('Mapper', 'index-modules-mapper.html'),
#  ('Merge', 'index-modules-merge.html'),
#  ('Similarity module', 'index-modules-similarity.html'),
#  ('Slow Log', 'index-modules-slowlog.html'),
#  ('Store', 'index-modules-store.html'),
#  ('Preloading data into the file system cache',
#   'preload-data-to-file-system-cache.html'),
#  ('Translog', 'index-modules-translog.html'),
#  ('History retention', 'index-modules-history-retention.html'),
#  ('Index Sorting', 'index-modules-index-sorting.html'),
#  ('Use index sorting to speed up conjunctions',
#   'index-modules-index-sorting-conjunctions.html'),
#  ('Indexing pressure', 'index-modules-indexing-pressure.html'),
#  ('Index templates', 'index-templates.html'),
#  ('Simulate multi-component templates',
#   'simulate-multi-component-templates.html'),
#  ('Config ignore_missing_component_templates',
#   'ignore_missing_component_templates.html'),
#  ('Usage example', '_usage_example.html'),
#  ('Aliases', 'aliases.html'),
#  ('Mapping', 'mapping.html'),
#  ('Dynamic mapping', 'dynamic-mapping.html'),
#  ('Dynamic field mapping', 'dynamic-field-mapping.html'),
#  ('Dynamic templates', 'dynamic-templates.html'),
#  ('Explicit mapping', 'explicit-mapping.html'),
#  ('Runtime fields', 'runtime.html'),
#  ('Map a runtime field', 'runtime-mapping-fields.html'),
#  ('Define runtime fields in a search request', 'runtime-search-request.html'),
#  ('Override field values at query time', 'runtime-override-values.html'),
#  ('Retrieve a runtime field', 'runtime-retrieving-fields.html'),
#  ('Index a runtime field', 'runtime-indexed.html'),
#  ('Explore your data with runtime fields', 'runtime-examples.html'),
#  ('Field data types', 'mapping-types.html'),
#  ('Aggregate metric', 'aggregate-metric-double.html'),
#  ('Alias', 'field-alias.html'),
#  ('Arrays', 'array.html'),
#  ('Binary', 'binary.html'),
#  ('Boolean', 'boolean.html'),
#  ('Completion', 'completion.html'),
#  ('Date', 'date.html'),
#  ('Date nanoseconds', 'date_nanos.html'),
#  ('Dense vector', 'dense-vector.html'),
#  ('Flattened', 'flattened.html'),
#  ('Geopoint', 'geo-point.html'),
#  ('Geoshape', 'geo-shape.html'),
#  ('Histogram', 'histogram.html'),
#  ('IP', 'ip.html'),
#  ('Join', 'parent-join.html'),
#  ('Keyword', 'keyword.html'),
#  ('Nested', 'nested.html'),
#  ('Numeric', 'number.html'),
#  ('Object', 'object.html'),
#  ('Percolator', 'percolator.html'),
#  ('Point', 'point.html'),
#  ('Range', 'range.html'),
#  ('Rank feature', 'rank-feature.html'),
#  ('Rank features', 'rank-features.html'),
#  ('Search-as-you-type', 'search-as-you-type.html'),
#  ('Semantic text', 'semantic-text.html'),
#  ('Shape', 'shape.html'),
#  ('Sparse vector', 'sparse-vector.html'),
#  ('Text', 'text.html'),
#  ('Token count', 'token-count.html'),
#  ('Unsigned long', 'unsigned-long.html'),
#  ('Version', 'version.html'),
#  ('Metadata fields', 'mapping-fields.html'),
#  ('_doc_countfield', 'mapping-doc-count-field.html'),
#  ('_field_namesfield', 'mapping-field-names-field.html'),
#  ('_ignoredfield', 'mapping-ignored-field.html'),
#  ('_idfield', 'mapping-id-field.html'),
#  ('_indexfield', 'mapping-index-field.html'),
#  ('_metafield', 'mapping-meta-field.html'),
#  ('_routingfield', 'mapping-routing-field.html'),
#  ('_sourcefield', 'mapping-source-field.html'),
#  ('_tierfield', 'mapping-tier-field.html'),
#  ('Mapping parameters', 'mapping-params.html'),
#  ('analyzer', 'analyzer.html'),
#  ('coerce', 'coerce.html'),
#  ('copy_to', 'copy-to.html'),
#  ('doc_values', 'doc-values.html'),
#  ('dynamic', 'dynamic.html'),
#  ('eager_global_ordinals', 'eager-global-ordinals.html'),
#  ('enabled', 'enabled.html'),
#  ('format', 'mapping-date-format.html'),
#  ('ignore_above', 'ignore-above.html'),
#  ('ignore_malformed', 'ignore-malformed.html'),
#  ('index', 'mapping-index.html'),
#  ('index_options', 'index-options.html'),
#  ('index_phrases', 'index-phrases.html'),
#  ('index_prefixes', 'index-prefixes.html'),
#  ('meta', 'mapping-field-meta.html'),
#  ('fields', 'multi-fields.html'),
#  ('normalizer', 'normalizer.html'),
#  ('norms', 'norms.html'),
#  ('null_value', 'null-value.html'),
#  ('position_increment_gap', 'position-increment-gap.html'),
#  ('properties', 'properties.html'),
#  ('search_analyzer', 'search-analyzer.html'),
#  ('similarity', 'similarity.html'),
#  ('store', 'mapping-store.html'),
#  ('subobjects', 'subobjects.html'),
#  ('term_vector', 'term-vector.html'),
#  ('Mapping limit settings', 'mapping-settings-limit.html'),
#  ('Removal of mapping types', 'removal-of-types.html'),
#  ('Text analysis', 'analysis.html'),
#  ('Overview', 'analysis-overview.html'),
#  ('Concepts', 'analysis-concepts.html'),
#  ('Anatomy of an analyzer', 'analyzer-anatomy.html'),
#  ('Index and search analysis', 'analysis-index-search-time.html'),
#  ('Stemming', 'stemming.html'),
#  ('Token graphs', 'token-graphs.html'),
#  ('Configure text analysis', 'configure-text-analysis.html'),
#  ('Test an analyzer', 'test-analyzer.html'),
#  ('Configuring built-in analyzers', 'configuring-analyzers.html'),
#  ('Create a custom analyzer', 'analysis-custom-analyzer.html'),
#  ('Specify an analyzer', 'specify-analyzer.html'),
#  ('Built-in analyzer reference', 'analysis-analyzers.html'),
#  ('Fingerprint', 'analysis-fingerprint-analyzer.html'),
#  ('Keyword', 'analysis-keyword-analyzer.html'),
#  ('Language', 'analysis-lang-analyzer.html'),
#  ('Pattern', 'analysis-pattern-analyzer.html'),
#  ('Simple', 'analysis-simple-analyzer.html'),
#  ('Standard', 'analysis-standard-analyzer.html'),
#  ('Stop', 'analysis-stop-analyzer.html'),
#  ('Whitespace', 'analysis-whitespace-analyzer.html'),
#  ('Tokenizer reference', 'analysis-tokenizers.html'),
#  ('Character group', 'analysis-chargroup-tokenizer.html'),
#  ('Classic', 'analysis-classic-tokenizer.html'),
#  ('Edge n-gram', 'analysis-edgengram-tokenizer.html'),
#  ('Keyword', 'analysis-keyword-tokenizer.html'),
#  ('Letter', 'analysis-letter-tokenizer.html'),
#  ('Lowercase', 'analysis-lowercase-tokenizer.html'),
#  ('N-gram', 'analysis-ngram-tokenizer.html'),
#  ('Path hierarchy', 'analysis-pathhierarchy-tokenizer.html'),
#  ('Pattern', 'analysis-pattern-tokenizer.html'),
#  ('Simple pattern', 'analysis-simplepattern-tokenizer.html'),
#  ('Simple pattern split', 'analysis-simplepatternsplit-tokenizer.html'),
#  ('Standard', 'analysis-standard-tokenizer.html'),
#  ('Thai', 'analysis-thai-tokenizer.html'),
#  ('UAX URL email', 'analysis-uaxurlemail-tokenizer.html'),
#  ('Whitespace', 'analysis-whitespace-tokenizer.html'),
#  ('Token filter reference', 'analysis-tokenfilters.html'),
#  ('Apostrophe', 'analysis-apostrophe-tokenfilter.html'),
#  ('ASCII folding', 'analysis-asciifolding-tokenfilter.html'),
#  ('CJK bigram', 'analysis-cjk-bigram-tokenfilter.html'),
#  ('CJK width', 'analysis-cjk-width-tokenfilter.html'),
#  ('Classic', 'analysis-classic-tokenfilter.html'),
#  ('Common grams', 'analysis-common-grams-tokenfilter.html'),
#  ('Conditional', 'analysis-condition-tokenfilter.html'),
#  ('Decimal digit', 'analysis-decimal-digit-tokenfilter.html'),
#  ('Delimited payload', 'analysis-delimited-payload-tokenfilter.html'),
#  ('Dictionary decompounder', 'analysis-dict-decomp-tokenfilter.html'),
#  ('Edge n-gram', 'analysis-edgengram-tokenfilter.html'),
#  ('Elision', 'analysis-elision-tokenfilter.html'),
#  ('Fingerprint', 'analysis-fingerprint-tokenfilter.html'),
#  ('Flatten graph', 'analysis-flatten-graph-tokenfilter.html'),
#  ('Hunspell', 'analysis-hunspell-tokenfilter.html'),
#  ('Hyphenation decompounder', 'analysis-hyp-decomp-tokenfilter.html'),
#  ('Keep types', 'analysis-keep-types-tokenfilter.html'),
#  ('Keep words', 'analysis-keep-words-tokenfilter.html'),
#  ('Keyword marker', 'analysis-keyword-marker-tokenfilter.html'),
#  ('Keyword repeat', 'analysis-keyword-repeat-tokenfilter.html'),
#  ('KStem', 'analysis-kstem-tokenfilter.html'),
#  ('Length', 'analysis-length-tokenfilter.html'),
#  ('Limit token count', 'analysis-limit-token-count-tokenfilter.html'),
#  ('Lowercase', 'analysis-lowercase-tokenfilter.html'),
#  ('MinHash', 'analysis-minhash-tokenfilter.html'),
#  ('Multiplexer', 'analysis-multiplexer-tokenfilter.html'),
#  ('N-gram', 'analysis-ngram-tokenfilter.html'),
#  ('Normalization', 'analysis-normalization-tokenfilter.html'),
#  ('Pattern capture', 'analysis-pattern-capture-tokenfilter.html'),
#  ('Pattern replace', 'analysis-pattern_replace-tokenfilter.html'),
#  ('Phonetic', 'analysis-phonetic-tokenfilter.html'),
#  ('Porter stem', 'analysis-porterstem-tokenfilter.html'),
#  ('Predicate script', 'analysis-predicatefilter-tokenfilter.html'),
#  ('Remove duplicates', 'analysis-remove-duplicates-tokenfilter.html'),
#  ('Reverse', 'analysis-reverse-tokenfilter.html'),
#  ('Shingle', 'analysis-shingle-tokenfilter.html'),
#  ('Snowball', 'analysis-snowball-tokenfilter.html'),
#  ('Stemmer', 'analysis-stemmer-tokenfilter.html'),
#  ('Stemmer override', 'analysis-stemmer-override-tokenfilter.html'),
#  ('Stop', 'analysis-stop-tokenfilter.html'),
#  ('Synonym', 'analysis-synonym-tokenfilter.html'),
#  ('Synonym graph', 'analysis-synonym-graph-tokenfilter.html'),
#  ('Trim', 'analysis-trim-tokenfilter.html'),
#  ('Truncate', 'analysis-truncate-tokenfilter.html'),
#  ('Unique', 'analysis-unique-tokenfilter.html'),
#  ('Uppercase', 'analysis-uppercase-tokenfilter.html'),
#  ('Word delimiter', 'analysis-word-delimiter-tokenfilter.html'),
#  ('Word delimiter graph', 'analysis-word-delimiter-graph-tokenfilter.html'),
#  ('Character filters reference', 'analysis-charfilters.html'),
#  ('HTML strip', 'analysis-htmlstrip-charfilter.html'),
#  ('Mapping', 'analysis-mapping-charfilter.html'),
#  ('Pattern replace', 'analysis-pattern-replace-charfilter.html'),
#  ('Normalizers', 'analysis-normalizers.html'),
#  ('Ingest pipelines', 'ingest.html'),
#  ('Example: Parse logs', 'common-log-format-example.html'),
#  ('Enrich your data', 'ingest-enriching-data.html'),
#  ('Set up an enrich processor', 'enrich-setup.html'),
#  ('Example: Enrich your data based on geolocation',
#   'geo-match-enrich-policy-type.html'),
#  ('Example: Enrich your data based on exact values',
#   'match-enrich-policy-type.html'),
#  ('Example: Enrich your data by matching a value to a range',
#   'range-enrich-policy-type.html'),
#  ('Processor reference', 'processors.html'),
#  ('Append', 'append-processor.html'),
#  ('Attachment', 'attachment.html'),
#  ('Bytes', 'bytes-processor.html'),
#  ('Circle', 'ingest-circle-processor.html'),
#  ('Community ID', 'community-id-processor.html'),
#  ('Convert', 'convert-processor.html'),
#  ('CSV', 'csv-processor.html'),
#  ('Date', 'date-processor.html'),
#  ('Date index name', 'date-index-name-processor.html'),
#  ('Dissect', 'dissect-processor.html'),
#  ('Dot expander', 'dot-expand-processor.html'),
#  ('Drop', 'drop-processor.html'),
#  ('Enrich', 'enrich-processor.html'),
#  ('Fail', 'fail-processor.html'),
#  ('Fingerprint', 'fingerprint-processor.html'),
#  ('Foreach', 'foreach-processor.html'),
#  ('Geo-grid', 'ingest-geo-grid-processor.html'),
#  ('GeoIP', 'geoip-processor.html'),
#  ('Grok', 'grok-processor.html'),
#  ('Gsub', 'gsub-processor.html'),
#  ('HTML strip', 'htmlstrip-processor.html'),
#  ('Inference', 'inference-processor.html'),
#  ('Join', 'join-processor.html'),
#  ('JSON', 'json-processor.html'),
#  ('KV', 'kv-processor.html'),
#  ('Lowercase', 'lowercase-processor.html'),
#  ('Network direction', 'network-direction-processor.html'),
#  ('Pipeline', 'pipeline-processor.html'),
#  ('Redact', 'redact-processor.html'),
#  ('Registered domain', 'registered-domain-processor.html'),
#  ('Remove', 'remove-processor.html'),
#  ('Rename', 'rename-processor.html'),
#  ('Reroute', 'reroute-processor.html'),
#  ('Script', 'script-processor.html'),
#  ('Set', 'set-processor.html'),
#  ('Set security user', 'ingest-node-set-security-user-processor.html'),
#  ('Sort', 'sort-processor.html'),
#  ('Split', 'split-processor.html'),
#  ('Trim', 'trim-processor.html'),
#  ('Uppercase', 'uppercase-processor.html'),
#  ('URL decode', 'urldecode-processor.html'),
#  ('URI parts', 'uri-parts-processor.html'),
#  ('User agent', 'user-agent-processor.html'),
#  ('Ingest pipelines in Search', 'ingest-pipeline-search.html'),
#  ('Inference processing', 'ingest-pipeline-search-inference.html'),
#  ('NLP tutorial', 'nlp-example.html'),
#  ('Data streams', 'data-streams.html'),
#  ('Set up a data stream', 'set-up-a-data-stream.html'),
#  ('Use a data stream', 'use-a-data-stream.html'),
#  ('Modify a data stream', 'modify-data-streams.html'),
#  ('Time series data stream (TSDS)', 'tsds.html'),
#  ('Set up a TSDS', 'set-up-tsds.html'),
#  ('Time series index settings', 'tsds-index-settings.html'),
#  ('Downsampling a time series data stream', 'downsampling.html'),
#  ('Run downsampling with ILM', 'downsampling-ilm.html'),
#  ('Run downsampling manually', 'downsampling-manual.html'),
#  ('Reindex a TSDS', 'tsds-reindex.html'),
#  ('Logs data stream', 'logs-data-stream.html'),
#  ('Data stream lifecycle', 'data-stream-lifecycle.html'),
#  ('Tutorial: Create a data stream with a lifecycle',
#   'tutorial-manage-new-data-stream.html'),
#  ('Tutorial: Update existing data stream',
#   'tutorial-manage-existing-data-stream.html'),
#  ('Tutorial: Migrate ILM managed data stream to data stream lifecycle',
#   'tutorial-migrate-data-stream-from-ilm-to-dsl.html'),
#  ('Data management', 'data-management.html'),
#  ('ILM: Manage the index lifecycle', 'index-lifecycle-management.html'),
#  ('Tutorial: Customize built-in policies',
#   'example-using-index-lifecycle-policy.html'),
#  ('Tutorial: Automate rollover',
#   'getting-started-index-lifecycle-management.html'),
#  ('Index management in Kibana', 'index-mgmt.html'),
#  ('Overview', 'overview-index-lifecycle-management.html'),
#  ('Concepts', 'ilm-concepts.html'),
#  ('Index lifecycle', 'ilm-index-lifecycle.html'),
#  ('Rollover', 'index-rollover.html'),
#  ('Policy updates', 'update-lifecycle-policy.html'),
#  ('Index lifecycle actions', 'ilm-actions.html'),
#  ('Allocate', 'ilm-allocate.html'),
#  ('Delete', 'ilm-delete.html'),
#  ('Force merge', 'ilm-forcemerge.html'),
#  ('Migrate', 'ilm-migrate.html'),
#  ('Read only', 'ilm-readonly.html'),
#  ('Rollover', 'ilm-rollover.html'),
#  ('Downsample', 'ilm-downsample.html'),
#  ('Searchable snapshot', 'ilm-searchable-snapshot.html'),
#  ('Set priority', 'ilm-set-priority.html'),
#  ('Shrink', 'ilm-shrink.html'),
#  ('Unfollow', 'ilm-unfollow.html'),
#  ('Wait for snapshot', 'ilm-wait-for-snapshot.html'),
#  ('Configure a lifecycle policy', 'set-up-lifecycle-policy.html'),
#  ('Migrate index allocation filters to node roles',
#   'migrate-index-allocation-filters.html'),
#  ('Troubleshooting index lifecycle management errors',
#   'index-lifecycle-error-handling.html'),
#  ('Start and stop index lifecycle management', 'start-stop-ilm.html'),
#  ('Manage existing indices', 'ilm-with-existing-indices.html'),
#  ('Skip rollover', 'skipping-rollover.html'),
#  ('Restore a managed data stream or index',
#   'index-lifecycle-and-snapshots.html'),
#  ('Data tiers', 'data-tiers.html'),
#  ('Roll up or transform your data', 'data-rollup-transform.html'),
#  ('Rolling up historical data', 'xpack-rollup.html'),
#  ('Overview', 'rollup-overview.html'),
#  ('API quick reference', 'rollup-api-quickref.html'),
#  ('Getting started', 'rollup-getting-started.html'),
#  ('Understanding groups', 'rollup-understanding-groups.html'),
#  ('Rollup aggregation limitations', 'rollup-agg-limitations.html'),
#  ('Rollup search limitations', 'rollup-search-limitations.html'),
#  ('Migrating to downsampling', 'rollup-migrating-to-downsampling.html'),
#  ('Transforming data', 'transforms.html'),
#  ('Overview', 'transform-overview.html'),
#  ('Setup', 'transform-setup.html'),
#  ('When to use transforms', 'transform-usage.html'),
#  ('Generating alerts for transforms', 'transform-alerts.html'),
#  ('Transforms at scale', 'transform-scale.html'),
#  ('How checkpoints work', 'transform-checkpoints.html'),
#  ('API quick reference', 'transform-api-quickref.html'),
#  ('Tutorial: Transforming the eCommerce sample data',
#   'ecommerce-transforms.html'),
#  ('Examples', 'transform-examples.html'),
#  ('Painless examples', 'transform-painless-examples.html'),
#  ('Limitations', 'transform-limitations.html'),
#  ('Query DSL', 'query-dsl.html'),
#  ('Query and filter context', 'query-filter-context.html'),
#  ('Compound queries', 'compound-queries.html'),
#  ('Boolean', 'query-dsl-bool-query.html'),
#  ('Boosting', 'query-dsl-boosting-query.html'),
#  ('Constant score', 'query-dsl-constant-score-query.html'),
#  ('Disjunction max', 'query-dsl-dis-max-query.html'),
#  ('Function score', 'query-dsl-function-score-query.html'),
#  ('Full text queries', 'full-text-queries.html'),
#  ('Intervals', 'query-dsl-intervals-query.html'),
#  ('Match', 'query-dsl-match-query.html'),
#  ('Match boolean prefix', 'query-dsl-match-bool-prefix-query.html'),
#  ('Match phrase', 'query-dsl-match-query-phrase.html'),
#  ('Match phrase prefix', 'query-dsl-match-query-phrase-prefix.html'),
#  ('Combined fields', 'query-dsl-combined-fields-query.html'),
#  ('Multi-match', 'query-dsl-multi-match-query.html'),
#  ('Query string', 'query-dsl-query-string-query.html'),
#  ('Simple query string', 'query-dsl-simple-query-string-query.html'),
#  ('Geo queries', 'geo-queries.html'),
#  ('Geo-bounding box', 'query-dsl-geo-bounding-box-query.html'),
#  ('Geo-distance', 'query-dsl-geo-distance-query.html'),
#  ('Geo-grid', 'query-dsl-geo-grid-query.html'),
#  ('Geo-polygon', 'query-dsl-geo-polygon-query.html'),
#  ('Geoshape', 'query-dsl-geo-shape-query.html'),
#  ('Shape queries', 'shape-queries.html'),
#  ('Shape', 'query-dsl-shape-query.html'),
#  ('Joining queries', 'joining-queries.html'),
#  ('Nested', 'query-dsl-nested-query.html'),
#  ('Has child', 'query-dsl-has-child-query.html'),
#  ('Has parent', 'query-dsl-has-parent-query.html'),
#  ('Parent ID', 'query-dsl-parent-id-query.html'),
#  ('Match all', 'query-dsl-match-all-query.html'),
#  ('Span queries', 'span-queries.html'),
#  ('Span containing', 'query-dsl-span-containing-query.html'),
#  ('Span field masking', 'query-dsl-span-field-masking-query.html'),
#  ('Span first', 'query-dsl-span-first-query.html'),
#  ('Span multi-term', 'query-dsl-span-multi-term-query.html'),
#  ('Span near', 'query-dsl-span-near-query.html'),
#  ('Span not', 'query-dsl-span-not-query.html'),
#  ('Span or', 'query-dsl-span-or-query.html'),
#  ('Span term', 'query-dsl-span-term-query.html'),
#  ('Span within', 'query-dsl-span-within-query.html'),
#  ('Vector queries', 'vector-queries.html'),
#  ('Knn', 'query-dsl-knn-query.html'),
#  ('Sparse vector', 'query-dsl-sparse-vector-query.html'),
#  ('Semantic', 'query-dsl-semantic-query.html'),
#  ('Text expansion', 'query-dsl-text-expansion-query.html'),
#  ('Weighted tokens', 'query-dsl-weighted-tokens-query.html'),
#  ('Specialized queries', 'specialized-queries.html'),
#  ('Distance feature', 'query-dsl-distance-feature-query.html'),
#  ('More like this', 'query-dsl-mlt-query.html'),
#  ('Percolate', 'query-dsl-percolate-query.html'),
#  ('Rank feature', 'query-dsl-rank-feature-query.html'),
#  ('Script', 'query-dsl-script-query.html'),
#  ('Script score', 'query-dsl-script-score-query.html'),
#  ('Wrapper', 'query-dsl-wrapper-query.html'),
#  ('Pinned Query', 'query-dsl-pinned-query.html'),
#  ('Rule', 'query-dsl-rule-query.html'),
#  ('Term-level queries', 'term-level-queries.html'),
#  ('Exists', 'query-dsl-exists-query.html'),
#  ('Fuzzy', 'query-dsl-fuzzy-query.html'),
#  ('IDs', 'query-dsl-ids-query.html'),
#  ('Prefix', 'query-dsl-prefix-query.html'),
#  ('Range', 'query-dsl-range-query.html'),
#  ('Regexp', 'query-dsl-regexp-query.html'),
#  ('Term', 'query-dsl-term-query.html'),
#  ('Terms', 'query-dsl-terms-query.html'),
#  ('Terms set', 'query-dsl-terms-set-query.html'),
#  ('Wildcard', 'query-dsl-wildcard-query.html'),
#  ('minimum_should_matchparameter', 'query-dsl-minimum-should-match.html'),
#  ('rewriteparameter', 'query-dsl-multi-term-rewrite.html'),
#  ('Regular expression syntax', 'regexp-syntax.html'),
#  ('EQL', 'eql.html'),
#  ('Syntax reference', 'eql-syntax.html'),
#  ('Function reference', 'eql-function-ref.html'),
#  ('Pipe reference', 'eql-pipe-ref.html'),
#  ('Example: Detect threats with EQL', 'eql-ex-threat-detection.html'),
#  ('ES|QL', 'esql.html'),
#  ('Getting started', 'esql-getting-started.html'),
#  ('ES|QL reference', 'esql-language.html'),
#  ('Syntax reference', 'esql-syntax.html'),
#  ('Commands', 'esql-commands.html'),
#  ('Functions and operators', 'esql-functions-operators.html'),
#  ('Metadata fields', 'esql-metadata-fields.html'),
#  ('Multivalued fields', 'esql-multivalued-fields.html'),
#  ('Data processing with DISSECT and GROK',
#   'esql-process-data-with-dissect-and-grok.html'),
#  ('Data enrichment', 'esql-enrich-data.html'),
#  ('Implicit casting', 'esql-implicit-casting.html'),
#  ('Using ES|QL', 'esql-using.html'),
#  ('REST API', 'esql-rest.html'),
#  ('Using ES|QL in Kibana', 'esql-kibana.html'),
#  ('Using ES|QL in Elastic Security', 'esql-elastic-security.html'),
#  ('Using ES|QL to query multiple indices', 'esql-multi-index.html'),
#  ('Using ES|QL across clusters', 'esql-cross-clusters.html'),
#  ('Task management', 'esql-task-management.html'),
#  ('Limitations', 'esql-limitations.html'),
#  ('Examples', 'esql-examples.html'),
#  ('SQL', 'xpack-sql.html'),
#  ('Overview', 'sql-overview.html'),
#  ('Getting Started with SQL', 'sql-getting-started.html'),
#  ('Conventions and Terminology', 'sql-concepts.html'),
#  ('Mapping concepts across SQL and Elasticsearch',
#   '_mapping_concepts_across_sql_and_elasticsearch.html'),
#  ('Security', 'sql-security.html'),
#  ('SQL REST API', 'sql-rest.html'),
#  ('Overview', 'sql-rest-overview.html'),
#  ('Response Data Formats', 'sql-rest-format.html'),
#  ('Paginating through a large response', 'sql-pagination.html'),
#  ('Filtering using Elasticsearch Query DSL', 'sql-rest-filtering.html'),
#  ('Columnar results', 'sql-rest-columnar.html'),
#  ('Passing parameters to a query', 'sql-rest-params.html'),
#  ('Use runtime fields', 'sql-runtime-fields.html'),
#  ('Run an async SQL search', 'sql-async.html'),
#  ('SQL Translate API', 'sql-translate.html'),
#  ('SQL CLI', 'sql-cli.html'),
#  ('SQL JDBC', 'sql-jdbc.html'),
#  ('API usage', '_api_usage.html'),
#  ('SQL ODBC', 'sql-odbc.html'),
#  ('Driver installation', 'sql-odbc-installation.html'),
#  ('Configuration', 'sql-odbc-setup.html'),
#  ('SQL Client Applications', 'sql-client-apps.html'),
#  ('DBeaver', 'sql-client-apps-dbeaver.html'),
#  ('DbVisualizer', 'sql-client-apps-dbvis.html'),
#  ('Microsoft Excel', 'sql-client-apps-excel.html'),
#  ('Microsoft Power BI Desktop', 'sql-client-apps-powerbi.html'),
#  ('Microsoft PowerShell', 'sql-client-apps-ps1.html'),
#  ('MicroStrategy Desktop', 'sql-client-apps-microstrat.html'),
#  ('Qlik Sense Desktop', 'sql-client-apps-qlik.html'),
#  ('SQuirreL SQL', 'sql-client-apps-squirrel.html'),
#  ('SQL Workbench/J', 'sql-client-apps-workbench.html'),
#  ('Tableau Desktop', 'sql-client-apps-tableau-desktop.html'),
#  ('Tableau Server', 'sql-client-apps-tableau-server.html'),
#  ('SQL Language', 'sql-spec.html'),
#  ('Lexical Structure', 'sql-lexical-structure.html'),
#  ('SQL Commands', 'sql-commands.html'),
#  ('DESCRIBE TABLE', 'sql-syntax-describe-table.html'),
#  ('SELECT', 'sql-syntax-select.html'),
#  ('SHOW CATALOGS', 'sql-syntax-show-catalogs.html'),
#  ('SHOW COLUMNS', 'sql-syntax-show-columns.html'),
#  ('SHOW FUNCTIONS', 'sql-syntax-show-functions.html'),
#  ('SHOW TABLES', 'sql-syntax-show-tables.html'),
#  ('Data Types', 'sql-data-types.html'),
#  ('Index patterns', 'sql-index-patterns.html'),
#  ('Frozen Indices', 'sql-index-frozen.html'),
#  ('Functions and Operators', 'sql-functions.html'),
#  ('Comparison Operators', 'sql-operators.html'),
#  ('Logical Operators', 'sql-operators-logical.html'),
#  ('Math Operators', 'sql-operators-math.html'),
#  ('Cast Operators', 'sql-operators-cast.html'),
#  ('LIKE and RLIKE Operators', 'sql-like-rlike-operators.html'),
#  ('Aggregate Functions', 'sql-functions-aggs.html'),
#  ('Grouping Functions', 'sql-functions-grouping.html'),
#  ('Date/Time and Interval Functions and Operators',
#   'sql-functions-datetime.html'),
#  ('Full-Text Search Functions', 'sql-functions-search.html'),
#  ('Mathematical Functions', 'sql-functions-math.html'),
#  ('String Functions', 'sql-functions-string.html'),
#  ('Type Conversion Functions', 'sql-functions-type-conversion.html'),
#  ('Geo Functions', 'sql-functions-geo.html'),
#  ('Conditional Functions And Expressions', 'sql-functions-conditional.html'),
#  ('System Functions', 'sql-functions-system.html'),
#  ('Reserved keywords', 'sql-syntax-reserved.html'),
#  ('SQL Limitations', 'sql-limitations.html'),
#  ('Scripting', 'modules-scripting.html'),
#  ('Painless scripting language', 'modules-scripting-painless.html'),
#  ('How to write scripts', 'modules-scripting-using.html'),
#  ('Scripts, caching, and search speed', 'scripts-and-search-speed.html'),
#  ('Dissecting data', 'dissect.html'),
#  ('Grokking grok', 'grok.html'),
#  ('Access fields in a document', 'script-fields-api.html'),
#  ('Common scripting use cases', 'common-script-uses.html'),
#  ('Field extraction', 'scripting-field-extraction.html'),
#  ('Accessing document fields and special variables',
#   'modules-scripting-fields.html'),
#  ('Scripting and security', 'modules-scripting-security.html'),
#  ('Lucene expressions language', 'modules-scripting-expression.html'),
#  ('Advanced scripts using script engines', 'modules-scripting-engine.html'),
#  ('Aggregations', 'search-aggregations.html'),
#  ('Bucket aggregations', 'search-aggregations-bucket.html'),
#  ('Adjacency matrix',
#   'search-aggregations-bucket-adjacency-matrix-aggregation.html'),
#  ('Auto-interval date histogram',
#   'search-aggregations-bucket-autodatehistogram-aggregation.html'),
#  ('Categorize text',
#   'search-aggregations-bucket-categorize-text-aggregation.html'),
#  ('Children', 'search-aggregations-bucket-children-aggregation.html'),
#  ('Composite', 'search-aggregations-bucket-composite-aggregation.html'),
#  ('Date histogram',
#   'search-aggregations-bucket-datehistogram-aggregation.html'),
#  ('Date range', 'search-aggregations-bucket-daterange-aggregation.html'),
#  ('Diversified sampler',
#   'search-aggregations-bucket-diversified-sampler-aggregation.html'),
#  ('Filter', 'search-aggregations-bucket-filter-aggregation.html'),
#  ('Filters', 'search-aggregations-bucket-filters-aggregation.html'),
#  ('Frequent item sets',
#   'search-aggregations-bucket-frequent-item-sets-aggregation.html'),
#  ('Geo-distance', 'search-aggregations-bucket-geodistance-aggregation.html'),
#  ('Geohash grid', 'search-aggregations-bucket-geohashgrid-aggregation.html'),
#  ('Geohex grid', 'search-aggregations-bucket-geohexgrid-aggregation.html'),
#  ('Geotile grid', 'search-aggregations-bucket-geotilegrid-aggregation.html'),
#  ('Global', 'search-aggregations-bucket-global-aggregation.html'),
#  ('Histogram', 'search-aggregations-bucket-histogram-aggregation.html'),
#  ('IP prefix', 'search-aggregations-bucket-ipprefix-aggregation.html'),
#  ('IP range', 'search-aggregations-bucket-iprange-aggregation.html'),
#  ('Missing', 'search-aggregations-bucket-missing-aggregation.html'),
#  ('Multi Terms', 'search-aggregations-bucket-multi-terms-aggregation.html'),
#  ('Nested', 'search-aggregations-bucket-nested-aggregation.html'),
#  ('Parent', 'search-aggregations-bucket-parent-aggregation.html'),
#  ('Random sampler', 'search-aggregations-random-sampler-aggregation.html'),
#  ('Range', 'search-aggregations-bucket-range-aggregation.html'),
#  ('Rare terms', 'search-aggregations-bucket-rare-terms-aggregation.html'),
#  ('Reverse nested',
#   'search-aggregations-bucket-reverse-nested-aggregation.html'),
#  ('Sampler', 'search-aggregations-bucket-sampler-aggregation.html'),
#  ('Significant terms',
#   'search-aggregations-bucket-significantterms-aggregation.html'),
#  ('Significant text',
#   'search-aggregations-bucket-significanttext-aggregation.html'),
#  ('Terms', 'search-aggregations-bucket-terms-aggregation.html'),
#  ('Time series', 'search-aggregations-bucket-time-series-aggregation.html'),
#  ('Variable width histogram',
#   'search-aggregations-bucket-variablewidthhistogram-aggregation.html'),
#  ('Subtleties of bucketing range fields',
#   'search-aggregations-bucket-range-field-note.html'),
#  ('Metrics aggregations', 'search-aggregations-metrics.html'),
#  ('Avg', 'search-aggregations-metrics-avg-aggregation.html'),
#  ('Boxplot', 'search-aggregations-metrics-boxplot-aggregation.html'),
#  ('Cardinality', 'search-aggregations-metrics-cardinality-aggregation.html'),
#  ('Extended stats',
#   'search-aggregations-metrics-extendedstats-aggregation.html'),
#  ('Geo-bounds', 'search-aggregations-metrics-geobounds-aggregation.html'),
#  ('Geo-centroid', 'search-aggregations-metrics-geocentroid-aggregation.html'),
#  ('Geo-line', 'search-aggregations-metrics-geo-line.html'),
#  ('Cartesian-bounds',
#   'search-aggregations-metrics-cartesian-bounds-aggregation.html'),
#  ('Cartesian-centroid',
#   'search-aggregations-metrics-cartesian-centroid-aggregation.html'),
#  ('Matrix stats', 'search-aggregations-matrix-stats-aggregation.html'),
#  ('Max', 'search-aggregations-metrics-max-aggregation.html'),
#  ('Median absolute deviation',
#   'search-aggregations-metrics-median-absolute-deviation-aggregation.html'),
#  ('Min', 'search-aggregations-metrics-min-aggregation.html'),
#  ('Percentile ranks',
#   'search-aggregations-metrics-percentile-rank-aggregation.html'),
#  ('Percentiles', 'search-aggregations-metrics-percentile-aggregation.html'),
#  ('Rate', 'search-aggregations-metrics-rate-aggregation.html'),
#  ('Scripted metric',
#   'search-aggregations-metrics-scripted-metric-aggregation.html'),
#  ('Stats', 'search-aggregations-metrics-stats-aggregation.html'),
#  ('String stats', 'search-aggregations-metrics-string-stats-aggregation.html'),
#  ('Sum', 'search-aggregations-metrics-sum-aggregation.html'),
#  ('T-test', 'search-aggregations-metrics-ttest-aggregation.html'),
#  ('Top hits', 'search-aggregations-metrics-top-hits-aggregation.html'),
#  ('Top metrics', 'search-aggregations-metrics-top-metrics.html'),
#  ('Value count', 'search-aggregations-metrics-valuecount-aggregation.html'),
#  ('Weighted avg', 'search-aggregations-metrics-weight-avg-aggregation.html'),
#  ('Pipeline aggregations', 'search-aggregations-pipeline.html'),
#  ('Average bucket',
#   'search-aggregations-pipeline-avg-bucket-aggregation.html'),
#  ('Bucket script',
#   'search-aggregations-pipeline-bucket-script-aggregation.html'),
#  ('Bucket count K-S test',
#   'search-aggregations-bucket-count-ks-test-aggregation.html'),
#  ('Bucket correlation',
#   'search-aggregations-bucket-correlation-aggregation.html'),
#  ('Bucket selector',
#   'search-aggregations-pipeline-bucket-selector-aggregation.html'),
#  ('Bucket sort', 'search-aggregations-pipeline-bucket-sort-aggregation.html'),
#  ('Change point', 'search-aggregations-change-point-aggregation.html'),
#  ('Cumulative cardinality',
#   'search-aggregations-pipeline-cumulative-cardinality-aggregation.html'),
#  ('Cumulative sum',
#   'search-aggregations-pipeline-cumulative-sum-aggregation.html'),
#  ('Derivative', 'search-aggregations-pipeline-derivative-aggregation.html'),
#  ('Extended stats bucket',
#   'search-aggregations-pipeline-extended-stats-bucket-aggregation.html'),
#  ('Inference bucket',
#   'search-aggregations-pipeline-inference-bucket-aggregation.html'),
#  ('Max bucket', 'search-aggregations-pipeline-max-bucket-aggregation.html'),
#  ('Min bucket', 'search-aggregations-pipeline-min-bucket-aggregation.html'),
#  ('Moving function', 'search-aggregations-pipeline-movfn-aggregation.html'),
#  ('Moving percentiles',
#   'search-aggregations-pipeline-moving-percentiles-aggregation.html'),
#  ('Normalize', 'search-aggregations-pipeline-normalize-aggregation.html'),
#  ('Percentiles bucket',
#   'search-aggregations-pipeline-percentiles-bucket-aggregation.html'),
#  ('Serial differencing',
#   'search-aggregations-pipeline-serialdiff-aggregation.html'),
#  ('Stats bucket',
#   'search-aggregations-pipeline-stats-bucket-aggregation.html'),
#  ('Sum bucket', 'search-aggregations-pipeline-sum-bucket-aggregation.html'),
#  ('Geospatial analysis', 'geospatial-analysis.html'),
#  ('Watcher', 'xpack-alerting.html'),
#  ('Getting started with Watcher', 'watcher-getting-started.html'),
#  ('How Watcher works', 'how-watcher-works.html'),
#  ('Encrypting sensitive data in Watcher', 'encrypting-data.html'),
#  ('Inputs', 'input.html'),
#  ('Simple input', 'input-simple.html'),
#  ('Search input', 'input-search.html'),
#  ('HTTP input', 'input-http.html'),
#  ('Chain input', 'input-chain.html'),
#  ('Triggers', 'trigger.html'),
#  ('Schedule trigger', 'trigger-schedule.html'),
#  ('Conditions', 'condition.html'),
#  ('Always condition', 'condition-always.html'),
#  ('Never condition', 'condition-never.html'),
#  ('Compare condition', 'condition-compare.html'),
#  ('Array compare condition', 'condition-array-compare.html'),
#  ('Script condition', 'condition-script.html'),
#  ('Actions', 'actions.html'),
#  ('Running an action for each element in an array', 'action-foreach.html'),
#  ('Adding conditions to actions', 'action-conditions.html'),
#  ('Email action', 'actions-email.html'),
#  ('Webhook action', 'actions-webhook.html'),
#  ('Index action', 'actions-index.html'),
#  ('Logging action', 'actions-logging.html'),
#  ('Slack action', 'actions-slack.html'),
#  ('PagerDuty action', 'actions-pagerduty.html'),
#  ('Jira action', 'actions-jira.html'),
#  ('Transforms', 'transform.html'),
#  ('Search payload transform', 'transform-search.html'),
#  ('Script payload transform', 'transform-script.html'),
#  ('Chain payload transform', 'transform-chain.html'),
#  ('Managing watches', 'managing-watches.html'),
#  ('Example watches', 'example-watches.html'),
#  ('Watching the status of an Elasticsearch cluster',
#   'watch-cluster-status.html'),
#  ('Limitations', 'watcher-limitations.html'),
#  ('Monitor a cluster', 'monitor-elasticsearch-cluster.html'),
#  ('Overview', 'monitoring-overview.html'),
#  ('How it works', 'how-monitoring-works.html'),
#  ('Monitoring in a production environment', 'monitoring-production.html'),
#  ('Collecting monitoring data with Elastic Agent',
#   'configuring-elastic-agent.html'),
#  ('Collecting monitoring data with Metricbeat', 'configuring-metricbeat.html'),
#  ('Collecting log data with Filebeat', 'configuring-filebeat.html'),
#  ('Configuring data streams/indices for monitoring',
#   'config-monitoring-indices.html'),
#  ('Configuring data streams created by Elastic Agent',
#   'config-monitoring-data-streams-elastic-agent.html'),
#  ('Configuring data streams created by Metricbeat 8',
#   'config-monitoring-data-streams-metricbeat-8.html'),
#  ('Configuring indices created by Metricbeat 7 or internal collection',
#   'config-monitoring-indices-metricbeat-7-internal-collection.html'),
#  ('Legacy collection methods', 'collecting-monitoring-data.html'),
#  ('Collectors', 'es-monitoring-collectors.html'),
#  ('Exporters', 'es-monitoring-exporters.html'),
#  ('Local exporters', 'local-exporter.html'),
#  ('HTTP exporters', 'http-exporter.html'),
#  ('Pausing data collection', 'pause-export.html'),
#  ('Secure the Elastic Stack', 'secure-cluster.html'),
#  ('Elasticsearch security principles', 'es-security-principles.html'),
#  ('Start the Elastic Stack with security enabled automatically',
#   'configuring-stack-security.html'),
#  ('Manually configure security', 'manually-configure-security.html'),
#  ('Set up minimal security', 'security-minimal-setup.html'),
#  ('Set up basic security', 'security-basic-setup.html'),
#  ('Set up basic security plus HTTPS', 'security-basic-setup-https.html'),
#  ('Setting passwords for native and built-in users',
#   'change-passwords-native-users.html'),
#  ('Enabling cipher suites for stronger encryption', 'ciphers.html'),
#  ('Supported SSL/TLS versions by JDK version', 'jdk-tls-versions.html'),
#  ('Security files', 'security-files.html'),
#  ('FIPS 140-2', 'fips-140-compliance.html'),
#  ('Updating node security certificates', 'update-node-certs.html'),
#  ('With the same CA', 'update-node-certs-same.html'),
#  ('With a different CA', 'update-node-certs-different.html'),
#  ('User authentication', 'setting-up-authentication.html'),
#  ('Built-in users', 'built-in-users.html'),
#  ('Service accounts', 'service-accounts.html'),
#  ('Internal users', 'internal-users.html'),
#  ('Token-based authentication services', 'token-authentication-services.html'),
#  ('User profiles', 'user-profile.html'),
#  ('Realms', 'realms.html'),
#  ('Realm chains', 'realm-chains.html'),
#  ('Security domains', 'security-domain.html'),
#  ('Active Directory user authentication', 'active-directory-realm.html'),
#  ('File-based user authentication', 'file-realm.html'),
#  ('LDAP user authentication', 'ldap-realm.html'),
#  ('Native user authentication', 'native-realm.html'),
#  ('OpenID Connect authentication', 'oidc-realm.html'),
#  ('PKI user authentication', 'pki-realm.html'),
#  ('SAML authentication', 'saml-realm.html'),
#  ('Kerberos authentication', 'kerberos-realm.html'),
#  ('JWT authentication', 'jwt-auth-realm.html'),
#  ('Integrating with other authentication systems', 'custom-realms.html'),
#  ('Enabling anonymous access', 'anonymous-access.html'),
#  ('Looking up users without authentication', 'user-lookup.html'),
#  ('Controlling the user cache', 'controlling-user-cache.html'),
#  ('Configuring SAML single-sign-on on the Elastic Stack',
#   'saml-guide-stack.html'),
#  ('Configuring single sign-on to the Elastic Stack using OpenID Connect',
#   'oidc-guide.html'),
#  ('User authorization', 'authorization.html'),
#  ('Built-in roles', 'built-in-roles.html'),
#  ('Defining roles', 'defining-roles.html'),
#  ('Role restriction', 'role-restriction.html'),
#  ('Security privileges', 'security-privileges.html'),
#  ('Document level security', 'document-level-security.html'),
#  ('Field level security', 'field-level-security.html'),
#  ('Granting privileges for data streams and aliases', 'securing-aliases.html'),
#  ('Mapping users and groups to roles', 'mapping-roles.html'),
#  ('Setting up field and document level security',
#   'field-and-document-access-control.html'),
#  ('Submitting requests on behalf of other users', 'run-as-privilege.html'),
#  ('Configuring authorization delegation',
#   'configuring-authorization-delegation.html'),
#  ('Customizing roles and authorization', 'custom-roles-authorization.html'),
#  ('Enable audit logging', 'enable-audit-logging.html'),
#  ('Audit events', 'audit-event-types.html'),
#  ('Logfile audit output', 'audit-log-output.html'),
#  ('Logfile audit events ignore policies', 'audit-log-ignore-policy.html'),
#  ('Auditing search queries', 'auditing-search-queries.html'),
#  ('Restricting connections with IP filtering', 'ip-filtering.html'),
#  ('Securing clients and integrations', 'security-clients-integrations.html'),
#  ('HTTP/REST clients and security', 'http-clients.html'),
#  ('ES-Hadoop and Security', 'hadoop.html'),
#  ('Monitoring and security', 'secure-monitoring.html'),
#  ('Operator privileges', 'operator-privileges.html'),
#  ('Configure operator privileges', 'configure-operator-privileges.html'),
#  ('Operator-only functionality', 'operator-only-functionality.html'),
#  ('Operator privileges for snapshot and restore',
#   'operator-only-snapshot-and-restore.html'),
#  ('Troubleshooting', 'security-troubleshooting.html'),
#  ('Some settings are not returned via the nodes settings API',
#   'security-trb-settings.html'),
#  ('Authorization exceptions', 'security-trb-roles.html'),
#  ('Users command fails due to extra arguments', 'security-trb-extraargs.html'),
#  ('Users are frequently locked out of Active Directory',
#   'trouble-shoot-active-directory.html'),
#  ('Certificate verification fails for curl on Mac',
#   'trb-security-maccurl.html'),
#  ('SSLHandshakeException causes connections to fail',
#   'trb-security-sslhandshake.html'),
#  ('Common SSL/TLS exceptions', 'trb-security-ssl.html'),
#  ('Common Kerberos exceptions', 'trb-security-kerberos.html'),
#  ('Common SAML issues', 'trb-security-saml.html'),
#  ('Internal Server Error in Kibana', 'trb-security-internalserver.html'),
#  ('Setup-passwords command fails due to connection failure',
#   'trb-security-setup.html'),
#  ('Failures due to relocation of the configuration files',
#   'trb-security-path.html'),
#  ('Limitations', 'security-limitations.html'),
#  ('Set up a cluster for high availability', 'high-availability.html'),
#  ('Designing for resilience', 'high-availability-cluster-design.html'),
#  ('Resilience in small clusters',
#   'high-availability-cluster-small-clusters.html'),
#  ('Resilience in larger clusters',
#   'high-availability-cluster-design-large-clusters.html'),
#  ('Cross-cluster replication', 'xpack-ccr.html'),
#  ('Set up cross-cluster replication', 'ccr-getting-started-tutorial.html'),
#  ('Manage cross-cluster replication', 'ccr-managing.html'),
#  ('Manage auto-follow patterns', 'ccr-auto-follow.html'),
#  ('Upgrading clusters', 'ccr-upgrading.html'),
#  ('Uni-directional disaster recovery',
#   'ccr-disaster-recovery-uni-directional-tutorial.html'),
#  ('Bi-directional disaster recovery',
#   'ccr-disaster-recovery-bi-directional-tutorial.html'),
#  ('How to', 'how-to.html'),
#  ('General recommendations', 'general-recommendations.html'),
#  ('Recipes', 'recipes.html'),
#  ('Mixing exact search with stemming',
#   'mixing-exact-search-with-stemming.html'),
#  ('Getting consistent scoring', 'consistent-scoring.html'),
#  ('Incorporating static relevance signals into the score',
#   'static-scoring-signals.html'),
#  ('Tune for indexing speed', 'tune-for-indexing-speed.html'),
#  ('Tune for search speed', 'tune-for-search-speed.html'),
#  ('Tune approximate kNN search', 'tune-knn-search.html'),
#  ('Tune for disk usage', 'tune-for-disk-usage.html'),
#  ('Size your shards', 'size-your-shards.html'),
#  ('Use Elasticsearch for time series data',
#   'use-elasticsearch-for-time-series-data.html'),
#  ('Autoscaling', 'xpack-autoscaling.html'),
#  ('Autoscaling deciders', 'autoscaling-deciders.html'),
#  ('Reactive storage decider', 'autoscaling-reactive-storage-decider.html'),
#  ('Proactive storage decider', 'autoscaling-proactive-storage-decider.html'),
#  ('Frozen shards decider', 'autoscaling-frozen-shards-decider.html'),
#  ('Frozen storage decider', 'autoscaling-frozen-storage-decider.html'),
#  ('Frozen existence decider', 'autoscaling-frozen-existence-decider.html'),
#  ('Machine learning decider', 'autoscaling-machine-learning-decider.html'),
#  ('Fixed decider', 'autoscaling-fixed-decider.html'),
#  ('Snapshot and restore', 'snapshot-restore.html'),
#  ('Register a repository', 'snapshots-register-repository.html'),
#  ('Azure repository', 'repository-azure.html'),
#  ('Google Cloud Storage repository', 'repository-gcs.html'),
#  ('S3 repository', 'repository-s3.html'),
#  ('Shared file system repository', 'snapshots-filesystem-repository.html'),
#  ('Read-only URL repository', 'snapshots-read-only-repository.html'),
#  ('Source-only repository', 'snapshots-source-only-repository.html'),
#  ('Create a snapshot', 'snapshots-take-snapshot.html'),
#  ('Restore a snapshot', 'snapshots-restore-snapshot.html'),
#  ('Searchable snapshots', 'searchable-snapshots.html'),
#  ('REST APIs', 'rest-apis.html'),
#  ('API conventions', 'api-conventions.html'),
#  ('Common options', 'common-options.html'),
#  ('REST API compatibility', 'rest-api-compatibility.html'),
#  ('Autoscaling APIs', 'autoscaling-apis.html'),
#  ('Create or update autoscaling policy',
#   'autoscaling-put-autoscaling-policy.html'),
#  ('Get autoscaling capacity', 'autoscaling-get-autoscaling-capacity.html'),
#  ('Delete autoscaling policy', 'autoscaling-delete-autoscaling-policy.html'),
#  ('Get autoscaling policy', 'autoscaling-get-autoscaling-policy.html'),
#  ('Behavioral Analytics APIs', 'behavioral-analytics-apis.html'),
#  ('Put Analytics Collection', 'put-analytics-collection.html'),
#  ('Delete Analytics Collection', 'delete-analytics-collection.html'),
#  ('List Analytics Collections', 'list-analytics-collection.html'),
#  ('Post Analytics Collection Event', 'post-analytics-collection-event.html'),
#  ('Compact and aligned text (CAT) APIs', 'cat.html'),
#  ('cat aliases', 'cat-alias.html'),
#  ('cat allocation', 'cat-allocation.html'),
#  ('cat anomaly detectors', 'cat-anomaly-detectors.html'),
#  ('cat component templates', 'cat-component-templates.html'),
#  ('cat count', 'cat-count.html'),
#  ('cat data frame analytics', 'cat-dfanalytics.html'),
#  ('cat datafeeds', 'cat-datafeeds.html'),
#  ('cat fielddata', 'cat-fielddata.html'),
#  ('cat health', 'cat-health.html'),
#  ('cat indices', 'cat-indices.html'),
#  ('cat master', 'cat-master.html'),
#  ('cat nodeattrs', 'cat-nodeattrs.html'),
#  ('cat nodes', 'cat-nodes.html'),
#  ('cat pending tasks', 'cat-pending-tasks.html'),
#  ('cat plugins', 'cat-plugins.html'),
#  ('cat recovery', 'cat-recovery.html'),
#  ('cat repositories', 'cat-repositories.html'),
#  ('cat segments', 'cat-segments.html'),
#  ('cat shards', 'cat-shards.html'),
#  ('cat snapshots', 'cat-snapshots.html'),
#  ('cat task management', 'cat-tasks.html'),
#  ('cat templates', 'cat-templates.html'),
#  ('cat thread pool', 'cat-thread-pool.html'),
#  ('cat trained model', 'cat-trained-model.html'),
#  ('cat transforms', 'cat-transforms.html'),
#  ('Cluster APIs', 'cluster.html'),
#  ('Cluster allocation explain', 'cluster-allocation-explain.html'),
#  ('Cluster get settings', 'cluster-get-settings.html'),
#  ('Cluster health', 'cluster-health.html'),
#  ('Health', 'health-api.html'),
#  ('Cluster reroute', 'cluster-reroute.html'),
#  ('Cluster state', 'cluster-state.html'),
#  ('Cluster stats', 'cluster-stats.html'),
#  ('Cluster update settings', 'cluster-update-settings.html'),
#  ('Nodes feature usage', 'cluster-nodes-usage.html'),
#  ('Nodes hot threads', 'cluster-nodes-hot-threads.html'),
#  ('Nodes info', 'cluster-nodes-info.html'),
#  ('Prevalidate node removal', 'prevalidate-node-removal-api.html'),
#  ('Nodes reload secure settings', 'cluster-nodes-reload-secure-settings.html'),
#  ('Nodes stats', 'cluster-nodes-stats.html'),
#  ('Cluster Info', 'cluster-info.html'),
#  ('Pending cluster tasks', 'cluster-pending.html'),
#  ('Remote cluster info', 'cluster-remote-info.html'),
#  ('Task management', 'tasks.html'),
#  ('Voting configuration exclusions', 'voting-config-exclusions.html'),
#  ('Create or update desired nodes', 'update-desired-nodes.html'),
#  ('Get desired nodes', 'get-desired-nodes.html'),
#  ('Delete desired nodes', 'delete-desired-nodes.html'),
#  ('Get desired balance', 'get-desired-balance.html'),
#  ('Reset desired balance', 'delete-desired-balance.html'),
#  ('Cross-cluster replication APIs', 'ccr-apis.html'),
#  ('Get CCR stats', 'ccr-get-stats.html'),
#  ('Create follower', 'ccr-put-follow.html'),
#  ('Pause follower', 'ccr-post-pause-follow.html'),
#  ('Resume follower', 'ccr-post-resume-follow.html'),
#  ('Unfollow', 'ccr-post-unfollow.html'),
#  ('Forget follower', 'ccr-post-forget-follower.html'),
#  ('Get follower stats', 'ccr-get-follow-stats.html'),
#  ('Get follower info', 'ccr-get-follow-info.html'),
#  ('Create auto-follow pattern', 'ccr-put-auto-follow-pattern.html'),
#  ('Delete auto-follow pattern', 'ccr-delete-auto-follow-pattern.html'),
#  ('Get auto-follow pattern', 'ccr-get-auto-follow-pattern.html'),
#  ('Pause auto-follow pattern', 'ccr-pause-auto-follow-pattern.html'),
#  ('Resume auto-follow pattern', 'ccr-resume-auto-follow-pattern.html'),
#  ('Connector APIs', 'connector-apis.html'),
#  ('Create connector', 'create-connector-api.html'),
#  ('Delete connector', 'delete-connector-api.html'),
#  ('Get connector', 'get-connector-api.html'),
#  ('List connectors', 'list-connector-api.html'),
#  ('Update connector API key id', 'update-connector-api-key-id-api.html'),
#  ('Update connector configuration', 'update-connector-configuration-api.html'),
#  ('Update connector index name', 'update-connector-index-name-api.html'),
#  ('Update connector features', 'update-connector-features-api.html'),
#  ('Update connector filtering', 'update-connector-filtering-api.html'),
#  ('Update connector name and description',
#   'update-connector-name-description-api.html'),
#  ('Update connector pipeline', 'update-connector-pipeline-api.html'),
#  ('Update connector scheduling', 'update-connector-scheduling-api.html'),
#  ('Update connector service type', 'update-connector-service-type-api.html'),
#  ('Create connector sync job', 'create-connector-sync-job-api.html'),
#  ('Cancel connector sync job', 'cancel-connector-sync-job-api.html'),
#  ('Delete connector sync job', 'delete-connector-sync-job-api.html'),
#  ('Get connector sync job', 'get-connector-sync-job-api.html'),
#  ('List connector sync jobs', 'list-connector-sync-jobs-api.html'),
#  ('Check in a connector', 'check-in-connector-api.html'),
#  ('Update connector error', 'update-connector-error-api.html'),
#  ('Update connector last sync stats', 'update-connector-last-sync-api.html'),
#  ('Update connector status', 'update-connector-status-api.html'),
#  ('Check in connector sync job', 'check-in-connector-sync-job-api.html'),
#  ('Set connector sync job error', 'set-connector-sync-job-error-api.html'),
#  ('Set connector sync job stats', 'set-connector-sync-job-stats-api.html'),
#  ('Data stream APIs', 'data-stream-apis.html'),
#  ('Create data stream', 'indices-create-data-stream.html'),
#  ...]

# %%
html_content
# Out:
# '<!DOCTYPE html>\n<html lang="en-us">\n  <head>\n    \n<meta charset="UTF-8">\n<title>Paginate search results | Elasticsearch Guide [8.15] | Elastic</title>\n<meta class="elastic" name="content" content="Paginate search results | Elasticsearch Guide [8.15]">\n\n<link rel="home" href="index.html" title="Elasticsearch Guide [8.15]"/>\n<link rel="up" href="search-your-data.html" title="The search API"/>\n<link rel="prev" href="sort-search-results.html" title="Sort search results"/>\n<link rel="next" href="search-fields.html" title="Retrieve selected fields from a search"/>\n<meta class="elastic" name="product_version" content="8.15"/>\n<meta class="elastic" name="product_name" content="Elasticsearch"/>\n<meta class="elastic" name="website_area" content="documentation"/>\n<meta name="DC.type" content="Learn/Docs/Elasticsearch/Reference/8.15"/>\n<meta name="DC.subject" content="Elasticsearch"/>\n<meta name="DC.identifier" content="8.15"/>\n\n    <meta http-equiv="content-type" content="text/html; charset=utf-8" />\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <script src="https://cdn.optimizely.com/js/18132920325.js"></script>\n    <link rel="apple-touch-icon" sizes="57x57" href="/apple-icon-57x57.png">\n    <link rel="apple-touch-icon" sizes="60x60" href="/apple-icon-60x60.png">\n    <link rel="apple-touch-icon" sizes="72x72" href="/apple-icon-72x72.png">\n    <link rel="apple-touch-icon" sizes="76x76" href="/apple-icon-76x76.png">\n    <link rel="apple-touch-icon" sizes="114x114" href="/apple-icon-114x114.png">\n    <link rel="apple-touch-icon" sizes="120x120" href="/apple-icon-120x120.png">\n    <link rel="apple-touch-icon" sizes="144x144" href="/apple-icon-144x144.png">\n    <link rel="apple-touch-icon" sizes="152x152" href="/apple-icon-152x152.png">\n    <link rel="apple-touch-icon" sizes="180x180" href="/apple-icon-180x180.png">\n    <link rel="icon" type="image/png" href="/favicon-32x32.png" sizes="32x32">\n    <link rel="icon" type="image/png" href="/android-chrome-192x192.png" sizes="192x192">\n    <link rel="icon" type="image/png" href="/favicon-96x96.png" sizes="96x96">\n    <link rel="icon" type="image/png" href="/favicon-16x16.png" sizes="16x16">\n    <link rel="manifest" href="/manifest.json">\n    <meta name="apple-mobile-web-app-title" content="Elastic">\n    <meta name="application-name" content="Elastic">\n    <meta name="msapplication-TileColor" content="#ffffff">\n    <meta name="msapplication-TileImage" content="/mstile-144x144.png">\n    <meta name="theme-color" content="#ffffff">\n    <meta name="naver-site-verification" content="936882c1853b701b3cef3721758d80535413dbfd" />\n    <meta name="yandex-verification" content="d8a47e95d0972434" />\n    <meta name="localized" content="true" />\n    <meta name="st:robots" content="follow,index" />\n    <meta property="og:image" content="https://static-www.elastic.co/v3/assets/bltefdd0b53724fa2ce/blt280217a63b82a734/6202d3378b1f312528798412/elastic-logo.svg" />\n    <meta property="og:image:width" content="500" />\n    <meta property="og:image:height" content="172" />\n    <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon">\n    <link rel="icon" href="/favicon.ico" type="image/x-icon">\n    <link rel="apple-touch-icon-precomposed" sizes="64x64" href="/favicon_64x64_16bit.png">\n    <link rel="apple-touch-icon-precomposed" sizes="32x32" href="/favicon_32x32.png">\n    <link rel="apple-touch-icon-precomposed" sizes="16x16" href="/favicon_16x16.png">\n    <!-- Give IE8 a fighting chance -->\n    <!--[if lt IE 9]>\n    <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>\n    <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>\n    <![endif]-->\n    <link rel="stylesheet" type="text/css" href="/guide/static/styles-v1.css" />\n  </head>\n\n  <!--© 2015-2025 Elasticsearch B.V. -->\n  <!-- All Elastic documentation is li ...

# %%
# Parse HTML and convert to plain text
soup = BeautifulSoup(response.text, "html.parser")
plain_text = soup.get_text(separator="\n")

# %%
print(plain_text)
